# %%
# !pip install transformers

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import gc, warnings, random, time, os

from pathlib import Path

from tqdm.notebook import tqdm

warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.optim import Adam, lr_scheduler
from torch.utils.data import Dataset, DataLoader
from transformers import AdamW
from transformers import AutoModel, AutoTokenizer, AutoConfig
from transformers import get_cosine_schedule_with_warmup

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

import seaborn as sns

import gc
gc.enable()

# %% [markdown]
# ### Folders and Dataframes

# %%
DATA_PATH = Path('/home/commonlit/data/')
assert DATA_PATH.exists()
MODELS_PATH = Path('/home/commonlit/models/')
if not MODELS_PATH.exists():
    os.mkdir(MODELS_PATH)
assert MODELS_PATH.exists()

# %%
train_df = pd.read_csv(DATA_PATH/'train-orig.csv')
test_df = pd.read_csv(DATA_PATH/'test.csv')
sample_df = pd.read_csv(DATA_PATH/'sample_submission.csv')

# %%
def remove_unnecessary(df):
    df.drop(df[df['target'] == 0].index, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
remove_unnecessary(train_df)

# %%
train_df
# Out:
#              id                                          url_legal  \
# 0     c12129c31                                                NaN
# 1     85aa80a4c                                                NaN
# 2     b69ac6792                                                NaN
# 3     dd1000b26                                                NaN
# 4     37c1b32fb                                                NaN
# ...         ...                                                ...
# 2828  25ca8f498  https://sites.ehe.osu.edu/beyondpenguins/files...
# 2829  2c26db523  https://en.wikibooks.org/wiki/Wikijunior:The_E...
# 2830  cd19e2350  https://en.wikibooks.org/wiki/Wikijunior:The_E...
# 2831  15e2e9e7a  https://en.wikibooks.org/wiki/Geometry_for_Ele...
# 2832  5b990ba77  https://en.wikibooks.org/wiki/Wikijunior:Biolo...
#
#            license                                            excerpt  \
# 0              NaN  When the young people returned to the ballroom...
# 1              NaN  All through dinner time, Mrs. Fayre was somewh...
# 2              NaN  As Roger had predicted, the snow departed as q...
# 3              NaN  And outside before the palace a great garden w...
# 4              NaN  Once upon a time there were Three Bears who li...
# ...            ...                                                ...
# 2828  CC BY-SA 3.0  When you think of dinosaurs and where they liv...
# 2829  CC BY-SA 3.0  So what is a solid? Solids are usually hard be...
# 2830  CC BY-SA 3.0  The second state of matter we will discuss is ...
# 2831  CC BY-SA 3.0  Solids are shapes that you can actually touch....
# 2832  CC BY-SA 3.0  Animals are made of many cells. They eat thing...
#
#         target  standard_error
# 0    -0.340259        0.464009
# 1    -0.315372        0.480805
# 2    -0.580118        0.476676
# 3    -1.054013        0.450007
# 4     0.247197        0.510845
# ...        ...             ...
# 2828  1.711390        0.646900
# 2829  0.189476        0.535648
# 2830  0.255209        0.483866
# 2831 -0.215279        0.514128
# 2832  0.300779        0.512379
#
# [2833 rows x 6 columns]

# %% [markdown]
# ### Config and Seeding

# %%
class Config(): 
    NUM_FOLDS = 6
    NUM_EPOCHS = 3
    BATCH_SIZE = 16
    MAX_LEN = 248
    EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
    ROBERTA_PATH = 'roberta-large'
    TOKENIZER_PATH = 'roberta-large'
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    SEED = 1000
    NUM_WORKERS = 2
    MODEL_FOLDER = MODELS_PATH
    model_name = 'roberta-large'
    svm_kernels = ['rbf']
    svm_c = 5

cfg = Config()

# %%
if not cfg.MODEL_FOLDER.exists():
    os.mkdir(cfg.MODEL_FOLDER)

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ### Dataset

# %%
def add_bins(train_df, num_bins):
    train_df.loc[:, 'bins'] = pd.cut(train_df['target'], bins=num_bins, labels=False)
    return num_bins

# %%
add_bins(train_df, cfg.NUM_FOLDS)
# Out:
# 6

# %%
train_df.groupby(['bins'])['target'].agg(['count', 'mean'])
# Out:
#       count      mean
# bins
# 0       122 -3.125765
# 1       441 -2.270279
# 2       784 -1.412150
# 3       886 -0.548095
# 4       494  0.289716
# 5       106  1.070237

# %%
tokenizer = AutoTokenizer.from_pretrained(cfg.TOKENIZER_PATH)

# %%
class CommonLitDataset(Dataset):
    def __init__(self, df, tokenizer, inference_only=False):
        super().__init__()
        self.df, self.inference_only = df, inference_only
        self.text = df['excerpt'].tolist()
        self.bins = df['bins']
        if not inference_only:
            self.target = torch.tensor(df['target'].to_numpy(), dtype = torch.float32)
        
        self.encoded = tokenizer.batch_encode_plus(
            self.text,
            padding = 'max_length',
            max_length = cfg.MAX_LEN,
            truncation = True,
            return_attention_mask=True
        )
        
    def __getitem__(self, index):        
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return {'input_ids': input_ids, 'attention_mask': attention_mask}
        else:
            target = self.target[index]
            return {'input_ids': input_ids, 'attention_mask': attention_mask, 'target': target}
    
    def __len__(self):
        return len(self.df)

# %%
sample_ds = CommonLitDataset(train_df, tokenizer)

# %% [markdown]
# ### Model

# %%
class AttentionHead(nn.Module):
    
    def __init__(self, in_features, hidden_dim, num_targets):
        super().__init__()
        self.in_features = in_features
        
        self.hidden_layer = nn.Linear(in_features, hidden_dim)
        self.final_layer = nn.Linear(hidden_dim, num_targets)
        self.out_features = hidden_dim
        
    def forward(self, features):
        att = torch.tanh(self.hidden_layer(features))
        score = self.final_layer(att)
        attention_weights = torch.softmax(score, dim=1)
        return attention_weights

# %%
class CommonLitModel(nn.Module):
    def __init__(self):
        super(CommonLitModel, self).__init__()
        config = AutoConfig.from_pretrained(cfg.ROBERTA_PATH)
        config.update({
            "output_hidden_states": True,
            "hidden_dropout_prob": 0.0,
            "layer_norm_eps": 1e-7
        })
        self.transformer_model = AutoModel.from_pretrained(cfg.ROBERTA_PATH, config=config)
        self.attention = AttentionHead(config.hidden_size, 512, 1)
        self.regressor = nn.Linear(config.hidden_size, 1)
    
    def forward(self, input_ids, attention_mask):
        last_layer_hidden_states = self.transformer_model(input_ids=input_ids, attention_mask=attention_mask)['last_hidden_state']
        weights = self.attention(last_layer_hidden_states)
        context_vector = torch.sum(weights * last_layer_hidden_states, dim=1) 
        return self.regressor(context_vector), context_vector

# %%
sample_model = CommonLitModel()
# Out:
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import re

current_layer = ''
base_lr = 5e-5
layer_map = {}
for i, (name, param) in enumerate(sample_model.named_parameters()):
    if(name.find('.layer') > -1):
        layer_name = re.sub(r'.+\.(layer\.\d+).+', r'\1', name)
        if(current_layer != layer_name):
            current_layer = layer_name
            layer_map[i] = current_layer

# %%
layer_lrs = []
for layer in layer_map.keys():
    if (layer < 133):
        layer_lrs.append((layer, base_lr / 5.0))
    elif layer < 261:
        layer_lrs.append((layer, base_lr))
    elif layer < 325:
        layer_lrs.append((layer, base_lr * 1.5))
    else:
        layer_lrs.append((layer, base_lr * 2))

# %%
layer_lrs
# Out:
# [(5, 1e-05),
#  (21, 1e-05),
#  (37, 1e-05),
#  (53, 1e-05),
#  (69, 1e-05),
#  (85, 1e-05),
#  (101, 1e-05),
#  (117, 1e-05),
#  (133, 5e-05),
#  (149, 5e-05),
#  (165, 5e-05),
#  (181, 5e-05),
#  (197, 5e-05),
#  (213, 5e-05),
#  (229, 5e-05),
#  (245, 5e-05),
#  (261, 7.500000000000001e-05),
#  (277, 7.500000000000001e-05),
#  (293, 7.500000000000001e-05),
#  (309, 7.500000000000001e-05),
#  (325, 0.0001),
#  (341, 0.0001),
#  (357, 0.0001),
#  (373, 0.0001)]

# %%
def find_lr_for_layer(layer_num, layer_lrs):
    lr = layer_lrs[0][1]
    for layer_lr in layer_lrs:
        if layer_num >= layer_lr[0]:
            lr = layer_lr[1]
        else:
            break
    return lr

# %%
for i, (name, param) in enumerate(sample_model.named_parameters()):
    print(i, name, param.size())
# Out:
# 0 transformer_model.embeddings.word_embeddings.weight torch.Size([50265, 1024])
# 1 transformer_model.embeddings.position_embeddings.weight torch.Size([514, 1024])
# 2 transformer_model.embeddings.token_type_embeddings.weight torch.Size([1, 1024])
# 3 transformer_model.embeddings.LayerNorm.weight torch.Size([1024])
# 4 transformer_model.embeddings.LayerNorm.bias torch.Size([1024])
# 5 transformer_model.encoder.layer.0.attention.self.query.weight torch.Size([1024, 1024])
# 6 transformer_model.encoder.layer.0.attention.self.query.bias torch.Size([1024])
# 7 transformer_model.encoder.layer.0.attention.self.key.weight torch.Size([1024, 1024])
# 8 transformer_model.encoder.layer.0.attention.self.key.bias torch.Size([1024])
# 9 transformer_model.encoder.layer.0.attention.self.value.weight torch.Size([1024, 1024])
# 10 transformer_model.encoder.layer.0.attention.self.value.bias torch.Size([1024])
# 11 transformer_model.encoder.layer.0.attention.output.dense.weight torch.Size([1024, 1024])
# 12 transformer_model.encoder.layer.0.attention.output.dense.bias torch.Size([1024])
# 13 transformer_model.encoder.layer.0.attention.output.LayerNorm.weight torch.Size([1024])
# 14 transformer_model.encoder.layer.0.attention.output.LayerNorm.bias torch.Size([1024])
# 15 transformer_model.encoder.layer.0.intermediate.dense.weight torch.Size([4096, 1024])
# 16 transformer_model.encoder.layer.0.intermediate.dense.bias torch.Size([4096])
# 17 transformer_model.encoder.layer.0.output.dense.weight torch.Size([1024, 4096])
# 18 transformer_model.encoder.layer.0.output.dense.bias torch.Size([1024])
# 19 transformer_model.encoder.layer.0.output.LayerNorm.weight torch.Size([1024])
# 20 transformer_model.encoder.layer.0.output.LayerNorm.bias torch.Size([1024])
# 21 transformer_model.encoder.layer.1.attention.self.query.weight torch.Size([1024, 1024])
# 22 transformer_model.encoder.layer.1.attention.self.query.bias torch.Size([1024])
# 23 transformer_model.encoder.layer.1.attention.self.key.weight torch.Size([1024, 1024])
# 24 transformer_model.encoder.layer.1.attention.self.key.bias torch.Size([1024])
# 25 transformer_model.encoder.layer.1.attention.self.value.weight torch.Size([1024, 1024])
# 26 transformer_model.encoder.layer.1.attention.self.value.bias torch.Size([1024])
# 27 transformer_model.encoder.layer.1.attention.output.dense.weight torch.Size([1024, 1024])
# 28 transformer_model.encoder.layer.1.attention.output.dense.bias torch.Size([1024])
# 29 transformer_model.encoder.layer.1.attention.output.LayerNorm.weight torch.Size([1024])
# 30 transformer_model.encoder.layer.1.attention.output.LayerNorm.bias torch.Size([1024])
# 31 transformer_model.encoder.layer.1.intermediate.dense.weight torch.Size([4096, 1024])
# 32 transformer_model.encoder.layer.1.intermediate.dense.bias torch.Size([4096])
# 33 transformer_model.encoder.layer.1.output.dense.weight torch.Size([1024, 4096])
# 34 transformer_model.encoder.layer.1.output.dense.bias torch.Size([1024])
# 35 transformer_model.encoder.layer.1.output.LayerNorm.weight torch.Size([1024])
# 36 transformer_model.encoder.layer.1.output.LayerNorm.bias torch.Size([1024])
# 37 transformer_model.encoder.layer.2.attention.self.query.weight torch.Size([1024, 1024])
# 38 transformer_model.encoder.layer.2.attention.self.query.bias torch.Size([1024])
# 39 transformer_model.encoder.layer.2.attention.self.key.weight torch.Size([1024, 1024])
# 40 transformer_model.encoder.layer.2.attention.self.key.bias torch.Size([1024])
# 41 transformer_model.encoder.layer.2.attention.self.value.weight torch.Size([1024, 1024])
# 42 transformer_model.encoder.layer.2.attention.self.value.bias torch.Size([1024])
# 43 transformer_model.encoder.layer.2.attention.output.dense.weight torch.Size([1024, 1024])
# 44 transformer_model.encoder.layer.2.attention.output.dense.bias torch.Size([1024])
# 45 transformer_model.encoder.layer.2.attention.output.LayerNorm.weight torch.Size([1024])
# 46 transformer_model.encoder.layer.2.attention.output.LayerNorm.bias torch.Size([1024])
# 47 transformer_model.encoder.layer.2.intermediate.dense.weight torch.Size([4096, 1024])
# 48 transformer_model.encoder.layer.2.intermediate.dense.bias torch.Size([4096])
# 49 transformer_model.encoder.layer.2.output.dense.weight torch.Size([1024, 4096])
# 50 transformer_model.encoder.layer.2.output.dense.bias torch.Size([1024])
# 51 transformer_model.encoder.layer.2.output.LayerNorm.weight torch.Size([1024])
# 52 transformer_model.encoder.layer.2.output.LayerNorm.bias torch.Size([1024])
# 53 transformer_model.encoder.layer.3.attention.self.query.weight torch.Size([1024, 1024])
# 54 transformer_model.encoder.layer.3.attention.self.query.bias torch.Size([1024])
# 55 transformer_model.encoder.layer.3.attention.self.key.weight torch.Size([1024, 1024])
# 56 transformer_model.encoder.layer.3.attention.self.key.bias torch.Size([1024])
# 57 transformer_model.encoder.layer.3.attention.self.value.weight torch.Size([1024, 1024])
# 58 transformer_model.encoder.layer.3.attention.self.value.bias torch.Size([1024])
# 59 transformer_model.encoder.layer.3.attention.output.dense.weight torch.Size([1024, 1024])
# 60 transformer_model.encoder.layer.3.attention.output.dense.bias torch.Size([1024])
# 61 transformer_model.encoder.layer.3.attention.output.LayerNorm.weight torch.Size([1024])
# 62 transformer_model.encoder.layer.3.attention.output.LayerNorm.bias torch.Size([1024])
# 63 transformer_model.encoder.layer.3.intermediate.dense.weight torch.Size([4096, 1024])
# 64 transformer_model.encoder.layer.3.intermediate.dense.bias torch.Size([4096])
# 65 transformer_model.encoder.layer.3.output.dense.weight torch.Size([1024, 4096])
# 66 transformer_model.encoder.layer.3.output.dense.bias torch.Size([1024])
# 67 transformer_model.encoder.layer.3.output.LayerNorm.weight torch.Size([1024])
# 68 transformer_model.encoder.layer.3.output.LayerNorm.bias torch.Size([1024])
# 69 transformer_model.encoder.layer.4.attention.self.query.weight torch.Size([1024, 1024])
# 70 transformer_model.encoder.layer.4.attention.self.query.bias torch.Size([1024])
# 71 transformer_model.encoder.layer.4.attention.self.key.weight torch.Size([1024, 1024])
# 72 transformer_model.encoder.layer.4.attention.self.key.bias torch.Size([1024])
# 73 transformer_model.encoder.layer.4.attention.self.value.weight torch.Size([1024, 1024])
# 74 transformer_model.encoder.layer.4.attention.self.value.bias torch.Size([1024])
# 75 transformer_model.encoder.layer.4.attention.output.dense.weight torch.Size([1024, 1024])
# 76 transformer_model.encoder.layer.4.attention.output.dense.bias torch.Size([1024])
# 77 transformer_model.encoder.layer.4.attention.output.LayerNorm.weight torch.Size([1024])
# 78 transformer_model.encoder.layer.4.attention.output.LayerNorm.bias torch.Size([1024])
# 79 transformer_model.encoder.layer.4.intermediate.dense.weight torch.Size([4096, 1024])
# 80 transformer_model.encoder.layer.4.intermediate.dense.bias torch.Size([4096])
# 81 transformer_model.encoder.layer.4.output.dense.weight torch.Size([1024, 4096])
# 82 transformer_model.encoder.layer.4.output.dense.bias torch.Size([1024])
# 83 transformer_model.encoder.layer.4.output.LayerNorm.weight torch.Size([1024])
# 84 transformer_model.encoder.layer.4.output.LayerNorm.bias torch.Size([1024])
# 85 transformer_model.encoder.layer.5.attention.self.query.weight torch.Size([1024, 1024])
# 86 transformer_model.encoder.layer.5.attention.self.query.bias torch.Size([1024])
# 87 transformer_model.encoder.layer.5.attention.self.key.weight torch.Size([1024, 1024])
# 88 transformer_model.encoder.layer.5.attention.self.key.bias torch.Size([1024])
# 89 transformer_model.encoder.layer.5.attention.self.value.weight torch.Size([1024, 1024])
# 90 transformer_model.encoder.layer.5.attention.self.value.bias torch.Size([1024])
# 91 transformer_model.encoder.layer.5.attention.output.dense.weight torch.Size([1024, 1024])
# 92 transformer_model.encoder.layer.5.attention.output.dense.bias torch.Size([1024])
# 93 transformer_model.encoder.layer.5.attention.output.LayerNorm.weight torch.Size([1024])
# 94 transformer_model.encoder.layer.5.attention.output.LayerNorm.bias torch.Size([1024])
# 95 transformer_model.encoder.layer.5.intermediate.dense.weight torch.Size([4096, 1024])
# 96 transformer_model.encoder.layer.5.intermediate.dense.bias torch.Size([4096])
# 97 transformer_model.encoder.layer.5.output.dense.weight torch.Size([1024, 4096])
# 98 transformer_model.encoder.layer.5.output.dense.bias torch.Size([1024])
# 99 transformer_model.encoder.layer.5.output.LayerNorm.weight torch.Size([1024])
# 100 transformer_model.encoder.layer.5.output.LayerNorm.bias torch.Size([1024])
# 101 transformer_model.encoder.layer.6.attention.self.query.weight torch.Size([1024, 1024])
# 102 transformer_model.encoder.layer.6.attention.self.query.bias torch.Size([1024])
# 103 transformer_model.encoder.layer.6.attention.self.key.weight torch.Size([1024, 1024])
# 104 transformer_model.encoder.layer.6.attention.self.key.bias torch.Size([1024])
# 105 transformer_model.encoder.layer.6.attention.self.value.weight torch.Size([1024, 1024])
# 106 transformer_model.encoder.layer.6.attention.self.value.bias torch.Size([1024])
# 107 transformer_model.encoder.layer.6.attention.output.dense.weight torch.Size([1024, 1024])
# 108 transformer_model.encoder.layer.6.attention.output.dense.bias torch.Size([1024])
# 109 transformer_model.encoder.layer.6.attention.output.LayerNorm.weight torch.Size([1024])
# 110 transformer_model.encoder.layer.6.attention.output.LayerNorm.bias torch.Size([1024])
# 111 transformer_model.encoder.layer.6.intermediate.dense.weight torch.Size([4096, 1024])
# 112 transformer_model.encoder.layer.6.intermediate.dense.bias torch.Size([4096])
# 113 transformer_model.encoder.layer.6.output.dense.weight torch.Size([1024, 4096])
# 114 transformer_model.encoder.layer.6.output.dense.bias torch.Size([1024])
# 115 transformer_model.encoder.layer.6.output.LayerNorm.weight torch.Size([1024])
# 116 transformer_model.encoder.layer.6.output.LayerNorm.bias torch.Size([1024])
# 117 transformer_model.encoder.layer.7.attention.self.query.weight torch.Size([1024, 1024])
# 118 transformer_model.encoder.layer.7.attention.self.query.bias torch.Size([1024])
# 119 transformer_model.encoder.layer.7.attention.self.key.weight torch.Size([1024, 1024])
# 120 transformer_model.encoder.layer.7.attention.self.key.bias torch.Size([1024])
# 121 transformer_model.encoder.layer.7.attention.self.value.weight torch.Size([1024, 1024])
# 122 transformer_model.encoder.layer.7.attention.self.value.bias torch.Size([1024])
# 123 transformer_model.encoder.layer.7.attention.output.dense.weight torch.Size([1024, 1024])
# 124 transformer_model.encoder.layer.7.attention.output.dense.bias torch.Size([1024])
# 125 transformer_model.encoder.layer.7.attention.output.LayerNorm.weight torch.Size([1024])
# 126 transformer_model.encoder.layer.7.attention.output.LayerNorm.bias torch.Size([1024])
# 127 transformer_model.encoder.layer.7.intermediate.dense.weight torch.Size([4096, 1024])
# 128 transformer_model.encoder.layer.7.intermediate.dense.bias torch.Size([4096])
# 129 transformer_model.encoder.layer.7.output.dense.weight torch.Size([1024, 4096])
# 130 transformer_model.encoder.layer.7.output.dense.bias torch.Size([1024])
# 131 transformer_model.encoder.layer.7.output.LayerNorm.weight torch.Size([1024])
# 132 transformer_model.encoder.layer.7.output.LayerNorm.bias torch.Size([1024])
# 133 transformer_model.encoder.layer.8.attention.self.query.weight torch.Size([1024, 1024])
# 134 transformer_model.encoder.layer.8.attention.self.query.bias torch.Size([1024])
# 135 transformer_model.encoder.layer.8.attention.self.key.weight torch.Size([1024, 1024])
# 136 transformer_model.encoder.layer.8.attention.self.key.bias torch.Size([1024])
# 137 transformer_model.encoder.layer.8.attention.self.value.weight torch.Size([1024, 1024])
# 138 transformer_model.encoder.layer.8.attention.self.value.bias torch.Size([1024])
# 139 transformer_model.encoder.layer.8.attention.output.dense.weight torch.Size([1024, 1024])
# 140 transformer_model.encoder.layer.8.attention.output.dense.bias torch.Size([1024])
# 141 transformer_model.encoder.layer.8.attention.output.LayerNorm.weight torch.Size([1024])
# 142 transformer_model.encoder.layer.8.attention.output.LayerNorm.bias torch.Size([1024])
# 143 transformer_model.encoder.layer.8.intermediate.dense.weight torch.Size([4096, 1024])
# 144 transformer_model.encoder.layer.8.intermediate.dense.bias torch.Size([4096])
# 145 transformer_model.encoder.layer.8.output.dense.weight torch.Size([1024, 4096])
# 146 transformer_model.encoder.layer.8.output.dense.bias torch.Size([1024])
# 147 transformer_model.encoder.layer.8.output.LayerNorm.weight torch.Size([1024])
# 148 transformer_model.encoder.layer.8.output.LayerNorm.bias torch.Size([1024])
# 149 transformer_model.encoder.layer.9.attention.self.query.weight torch.Size([1024, 1024])
# 150 transformer_model.encoder.layer.9.attention.self.query.bias torch.Size([1024])
# 151 transformer_model.encoder.layer.9.attention.self.key.weight torch.Size([1024, 1024])
# 152 transformer_model.encoder.layer.9.attention.self.key.bias torch.Size([1024])
# 153 transformer_model.encoder.layer.9.attention.self.value.weight torch.Size([1024, 1024])
# 154 transformer_model.encoder.layer.9.attention.self.value.bias torch.Size([1024])
# 155 transformer_model.encoder.layer.9.attention.output.dense.weight torch.Size([1024, 1024])
# 156 transformer_model.encoder.layer.9.attention.output.dense.bias torch.Size([1024])
# 157 transformer_model.encoder.layer.9.attention.output.LayerNorm.weight torch.Size([1024])
# 158 transformer_model.encoder.layer.9.attention.output.LayerNorm.bias torch.Size([1024])
# 159 transformer_model.encoder.layer.9.intermediate.dense.weight torch.Size([4096, 1024])
# 160 transformer_model.encoder.layer.9.intermediate.dense.bias torch.Size([4096])
# 161 transformer_model.encoder.layer.9.output.dense.weight torch.Size([1024, 4096])
# 162 transformer_model.encoder.layer.9.output.dense.bias torch.Size([1024])
# 163 transformer_model.encoder.layer.9.output.LayerNorm.weight torch.Size([1024])
# 164 transformer_model.encoder.layer.9.output.LayerNorm.bias torch.Size([1024])
# 165 transformer_model.encoder.layer.10.attention.self.query.weight torch.Size([1024, 1024])
# 166 transformer_model.encoder.layer.10.attention.self.query.bias torch.Size([1024])
# 167 transformer_model.encoder.layer.10.attention.self.key.weight torch.Size([1024, 1024])
# 168 transformer_model.encoder.layer.10.attention.self.key.bias torch.Size([1024])
# 169 transformer_model.encoder.layer.10.attention.self.value.weight torch.Size([1024, 1024])
# 170 transformer_model.encoder.layer.10.attention.self.value.bias torch.Size([1024])
# 171 transformer_model.encoder.layer.10.attention.output.dense.weight torch.Size([1024, 1024])
# 172 transformer_model.encoder.layer.10.attention.output.dense.bias torch.Size([1024])
# 173 transformer_model.encoder.layer.10.attention.output.LayerNorm.weight torch.Size([1024])
# 174 transformer_model.encoder.layer.10.attention.output.LayerNorm.bias torch.Size([1024])
# 175 transformer_model.encoder.layer.10.intermediate.dense.weight torch.Size([4096, 1024])
# 176 transformer_model.encoder.layer.10.intermediate.dense.bias torch.Size([4096])
# 177 transformer_model.encoder.layer.10.output.dense.weight torch.Size([1024, 4096])
# 178 transformer_model.encoder.layer.10.output.dense.bias torch.Size([1024])
# 179 transformer_model.encoder.layer.10.output.LayerNorm.weight torch.Size([1024])
# 180 transformer_model.encoder.layer.10.output.LayerNorm.bias torch.Size([1024])
# 181 transformer_model.encoder.layer.11.attention.self.query.weight torch.Size([1024, 1024])
# 182 transformer_model.encoder.layer.11.attention.self.query.bias torch.Size([1024])
# 183 transformer_model.encoder.layer.11.attention.self.key.weight torch.Size([1024, 1024])
# 184 transformer_model.encoder.layer.11.attention.self.key.bias torch.Size([1024])
# 185 transformer_model.encoder.layer.11.attention.self.value.weight torch.Size([1024, 1024])
# 186 transformer_model.encoder.layer.11.attention.self.value.bias torch.Size([1024])
# 187 transformer_model.encoder.layer.11.attention.output.dense.weight torch.Size([1024, 1024])
# 188 transformer_model.encoder.layer.11.attention.output.dense.bias torch.Size([1024])
# 189 transformer_model.encoder.layer.11.attention.output.LayerNorm.weight torch.Size([1024])
# 190 transformer_model.encoder.layer.11.attention.output.LayerNorm.bias torch.Size([1024])
# 191 transformer_model.encoder.layer.11.intermediate.dense.weight torch.Size([4096, 1024])
# 192 transformer_model.encoder.layer.11.intermediate.dense.bias torch.Size([4096])
# 193 transformer_model.encoder.layer.11.output.dense.weight torch.Size([1024, 4096])
# 194 transformer_model.encoder.layer.11.output.dense.bias torch.Size([1024])
# 195 transformer_model.encoder.layer.11.output.LayerNorm.weight torch.Size([1024])
# 196 transformer_model.encoder.layer.11.output.LayerNorm.bias torch.Size([1024])
# 197 transformer_model.encoder.layer.12.attention.self.query.weight torch.Size([1024, 1024])
# 198 transformer_model.encoder.layer.12.attention.self.query.bias torch.Size([1024])
# 199 transformer_model.encoder.layer.12.attention.self.key.weight torch.Size([1024, 1024])
# 200 transformer_model.encoder.layer.12.attention.self.key.bias torch.Size([1024])
# 201 transformer_model.encoder.layer.12.attention.self.value.weight torch.Size([1024, 1024])
# 202 transformer_model.encoder.layer.12.attention.self.value.bias torch.Size([1024])
# 203 transformer_model.encoder.layer.12.attention.output.dense.weight torch.Size([1024, 1024])
# 204 transformer_model.encoder.layer.12.attention.output.dense.bias torch.Size([1024])
# 205 transformer_model.encoder.layer.12.attention.output.LayerNorm.weight torch.Size([1024])
# 206 transformer_model.encoder.layer.12.attention.output.LayerNorm.bias torch.Size([1024])
# 207 transformer_model.encoder.layer.12.intermediate.dense.weight torch.Size([4096, 1024])
# 208 transformer_model.encoder.layer.12.intermediate.dense.bias torch.Size([4096])
# 209 transformer_model.encoder.layer.12.output.dense.weight torch.Size([1024, 4096])
# 210 transformer_model.encoder.layer.12.output.dense.bias torch.Size([1024])
# 211 transformer_model.encoder.layer.12.output.LayerNorm.weight torch.Size([1024])
# 212 transformer_model.encoder.layer.12.output.LayerNorm.bias torch.Size([1024])
# 213 transformer_model.encoder.layer.13.attention.self.query.weight torch.Size([1024, 1024])
# 214 transformer_model.encoder.layer.13.attention.self.query.bias torch.Size([1024])
# 215 transformer_model.encoder.layer.13.attention.self.key.weight torch.Size([1024, 1024])
# 216 transformer_model.encoder.layer.13.attention.self.key.bias torch.Size([1024])
# 217 transformer_model.encoder.layer.13.attention.self.value.weight torch.Size([1024, 1024])
# 218 transformer_model.encoder.layer.13.attention.self.value.bias torch.Size([1024])
# 219 transformer_model.encoder.layer.13.attention.output.dense.weight torch.Size([1024, 1024])
# 220 transformer_model.encoder.layer.13.attention.output.dense.bias torch.Size([1024])
# 221 transformer_model.encoder.layer.13.attention.output.LayerNorm.weight torch.Size([1024])
# 222 transformer_model.encoder.layer.13.attention.output.LayerNorm.bias torch.Size([1024])
# 223 transformer_model.encoder.layer.13.intermediate.dense.weight torch.Size([4096, 1024])
# 224 transformer_model.encoder.layer.13.intermediate.dense.bias torch.Size([4096])
# 225 transformer_model.encoder.layer.13.output.dense.weight torch.Size([1024, 4096])
# 226 transformer_model.encoder.layer.13.output.dense.bias torch.Size([1024])
# 227 transformer_model.encoder.layer.13.output.LayerNorm.weight torch.Size([1024])
# 228 transformer_model.encoder.layer.13.output.LayerNorm.bias torch.Size([1024])
# 229 transformer_model.encoder.layer.14.attention.self.query.weight torch.Size([1024, 1024])
# 230 transformer_model.encoder.layer.14.attention.self.query.bias torch.Size([1024])
# 231 transformer_model.encoder.layer.14.attention.self.key.weight torch.Size([1024, 1024])
# 232 transformer_model.encoder.layer.14.attention.self.key.bias torch.Size([1024])
# 233 transformer_model.encoder.layer.14.attention.self.value.weight torch.Size([1024, 1024])
# 234 transformer_model.encoder.layer.14.attention.self.value.bias torch.Size([1024])
# 235 transformer_model.encoder.layer.14.attention.output.dense.weight torch.Size([1024, 1024])
# 236 transformer_model.encoder.layer.14.attention.output.dense.bias torch.Size([1024])
# 237 transformer_model.encoder.layer.14.attention.output.LayerNorm.weight torch.Size([1024])
# 238 transformer_model.encoder.layer.14.attention.output.LayerNorm.bias torch.Size([1024])
# 239 transformer_model.encoder.layer.14.intermediate.dense.weight torch.Size([4096, 1024])
# 240 transformer_model.encoder.layer.14.intermediate.dense.bias torch.Size([4096])
# 241 transformer_model.encoder.layer.14.output.dense.weight torch.Size([1024, 4096])
# 242 transformer_model.encoder.layer.14.output.dense.bias torch.Size([1024])
# 243 transformer_model.encoder.layer.14.output.LayerNorm.weight torch.Size([1024])
# 244 transformer_model.encoder.layer.14.output.LayerNorm.bias torch.Size([1024])
# 245 transformer_model.encoder.layer.15.attention.self.query.weight torch.Size([1024, 1024])
# 246 transformer_model.encoder.layer.15.attention.self.query.bias torch.Size([1024])
# 247 transformer_model.encoder.layer.15.attention.self.key.weight torch.Size([1024, 1024])
# 248 transformer_model.encoder.layer.15.attention.self.key.bias torch.Size([1024])
# 249 transformer_model.encoder.layer.15.attention.self.value.weight torch.Size([1024, 1024])
# 250 transformer_model.encoder.layer.15.attention.self.value.bias torch.Size([1024])
# 251 transformer_model.encoder.layer.15.attention.output.dense.weight torch.Size([1024, 1024])
# 252 transformer_model.encoder.layer.15.attention.output.dense.bias torch.Size([1024])
# 253 transformer_model.encoder.layer.15.attention.output.LayerNorm.weight torch.Size([1024])
# 254 transformer_model.encoder.layer.15.attention.output.LayerNorm.bias torch.Size([1024])
# 255 transformer_model.encoder.layer.15.intermediate.dense.weight torch.Size([4096, 1024])
# 256 transformer_model.encoder.layer.15.intermediate.dense.bias torch.Size([4096])
# 257 transformer_model.encoder.layer.15.output.dense.weight torch.Size([1024, 4096])
# 258 transformer_model.encoder.layer.15.output.dense.bias torch.Size([1024])
# 259 transformer_model.encoder.layer.15.output.LayerNorm.weight torch.Size([1024])
# 260 transformer_model.encoder.layer.15.output.LayerNorm.bias torch.Size([1024])
# 261 transformer_model.encoder.layer.16.attention.self.query.weight torch.Size([1024, 1024])
# 262 transformer_model.encoder.layer.16.attention.self.query.bias torch.Size([1024])
# 263 transformer_model.encoder.layer.16.attention.self.key.weight torch.Size([1024, 1024])
# 264 transformer_model.encoder.layer.16.attention.self.key.bias torch.Size([1024])
# 265 transformer_model.encoder.layer.16.attention.self.value.weight torch.Size([1024, 1024])
# 266 transformer_model.encoder.layer.16.attention.self.value.bias torch.Size([1024])
# 267 transformer_model.encoder.layer.16.attention.output.dense.weight torch.Size([1024, 1024])
# 268 transformer_model.encoder.layer.16.attention.output.dense.bias torch.Size([1024])
# 269 transformer_model.encoder.layer.16.attention.output.LayerNorm.weight torch.Size([1024])
# 270 transformer_model.encoder.layer.16.attention.output.LayerNorm.bias torch.Size([1024])
# 271 transformer_model.encoder.layer.16.intermediate.dense.weight torch.Size([4096, 1024])
# 272 transformer_model.encoder.layer.16.intermediate.dense.bias torch.Size([4096])
# 273 transformer_model.encoder.layer.16.output.dense.weight torch.Size([1024, 4096])
# 274 transformer_model.encoder.layer.16.output.dense.bias torch.Size([1024])
# 275 transformer_model.encoder.layer.16.output.LayerNorm.weight torch.Size([1024])
# 276 transformer_model.encoder.layer.16.output.LayerNorm.bias torch.Size([1024])
# 277 transformer_model.encoder.layer.17.attention.self.query.weight torch.Size([1024, 1024])
# 278 transformer_model.encoder.layer.17.attention.self.query.bias torch.Size([1024])
# 279 transformer_model.encoder.layer.17.attention.self.key.weight torch.Size([1024, 1024])
# 280 transformer_model.encoder.layer.17.attention.self.key.bias torch.Size([1024])
# 281 transformer_model.encoder.layer.17.attention.self.value.weight torch.Size([1024, 1024])
# 282 transformer_model.encoder.layer.17.attention.self.value.bias torch.Size([1024])
# 283 transformer_model.encoder.layer.17.attention.output.dense.weight torch.Size([1024, 1024])
# 284 transformer_model.encoder.layer.17.attention.output.dense.bias torch.Size([1024])
# 285 transformer_model.encoder.layer.17.attention.output.LayerNorm.weight torch.Size([1024])
# 286 transformer_model.encoder.layer.17.attention.output.LayerNorm.bias torch.Size([1024])
# 287 transformer_model.encoder.layer.17.intermediate.dense.weight torch.Size([4096, 1024])
# 288 transformer_model.encoder.layer.17.intermediate.dense.bias torch.Size([4096])
# 289 transformer_model.encoder.layer.17.output.dense.weight torch.Size([1024, 4096])
# 290 transformer_model.encoder.layer.17.output.dense.bias torch.Size([1024])
# 291 transformer_model.encoder.layer.17.output.LayerNorm.weight torch.Size([1024])
# 292 transformer_model.encoder.layer.17.output.LayerNorm.bias torch.Size([1024])
# 293 transformer_model.encoder.layer.18.attention.self.query.weight torch.Size([1024, 1024])
# 294 transformer_model.encoder.layer.18.attention.self.query.bias torch.Size([1024])
# 295 transformer_model.encoder.layer.18.attention.self.key.weight torch.Size([1024, 1024])
# 296 transformer_model.encoder.layer.18.attention.self.key.bias torch.Size([1024])
# 297 transformer_model.encoder.layer.18.attention.self.value.weight torch.Size([1024, 1024])
# 298 transformer_model.encoder.layer.18.attention.self.value.bias torch.Size([1024])
# 299 transformer_model.encoder.layer.18.attention.output.dense.weight torch.Size([1024, 1024])
# 300 transformer_model.encoder.layer.18.attention.output.dense.bias torch.Size([1024])
# 301 transformer_model.encoder.layer.18.attention.output.LayerNorm.weight torch.Size([1024])
# 302 transformer_model.encoder.layer.18.attention.output.LayerNorm.bias torch.Size([1024])
# 303 transformer_model.encoder.layer.18.intermediate.dense.weight torch.Size([4096, 1024])
# 304 transformer_model.encoder.layer.18.intermediate.dense.bias torch.Size([4096])
# 305 transformer_model.encoder.layer.18.output.dense.weight torch.Size([1024, 4096])
# 306 transformer_model.encoder.layer.18.output.dense.bias torch.Size([1024])
# 307 transformer_model.encoder.layer.18.output.LayerNorm.weight torch.Size([1024])
# 308 transformer_model.encoder.layer.18.output.LayerNorm.bias torch.Size([1024])
# 309 transformer_model.encoder.layer.19.attention.self.query.weight torch.Size([1024, 1024])
# 310 transformer_model.encoder.layer.19.attention.self.query.bias torch.Size([1024])
# 311 transformer_model.encoder.layer.19.attention.self.key.weight torch.Size([1024, 1024])
# 312 transformer_model.encoder.layer.19.attention.self.key.bias torch.Size([1024])
# 313 transformer_model.encoder.layer.19.attention.self.value.weight torch.Size([1024, 1024])
# 314 transformer_model.encoder.layer.19.attention.self.value.bias torch.Size([1024])
# 315 transformer_model.encoder.layer.19.attention.output.dense.weight torch.Size([1024, 1024])
# 316 transformer_model.encoder.layer.19.attention.output.dense.bias torch.Size([1024])
# 317 transformer_model.encoder.layer.19.attention.output.LayerNorm.weight torch.Size([1024])
# 318 transformer_model.encoder.layer.19.attention.output.LayerNorm.bias torch.Size([1024])
# 319 transformer_model.encoder.layer.19.intermediate.dense.weight torch.Size([4096, 1024])
# 320 transformer_model.encoder.layer.19.intermediate.dense.bias torch.Size([4096])
# 321 transformer_model.encoder.layer.19.output.dense.weight torch.Size([1024, 4096])
# 322 transformer_model.encoder.layer.19.output.dense.bias torch.Size([1024])
# 323 transformer_model.encoder.layer.19.output.LayerNorm.weight torch.Size([1024])
# 324 transformer_model.encoder.layer.19.output.LayerNorm.bias torch.Size([1024])
# 325 transformer_model.encoder.layer.20.attention.self.query.weight torch.Size([1024, 1024])
# 326 transformer_model.encoder.layer.20.attention.self.query.bias torch.Size([1024])
# 327 transformer_model.encoder.layer.20.attention.self.key.weight torch.Size([1024, 1024])
# 328 transformer_model.encoder.layer.20.attention.self.key.bias torch.Size([1024])
# 329 transformer_model.encoder.layer.20.attention.self.value.weight torch.Size([1024, 1024])
# 330 transformer_model.encoder.layer.20.attention.self.value.bias torch.Size([1024])
# 331 transformer_model.encoder.layer.20.attention.output.dense.weight torch.Size([1024, 1024])
# 332 transformer_model.encoder.layer.20.attention.output.dense.bias torch.Size([1024])
# 333 transformer_model.encoder.layer.20.attention.output.LayerNorm.weight torch.Size([1024])
# 334 transformer_model.encoder.layer.20.attention.output.LayerNorm.bias torch.Size([1024])
# 335 transformer_model.encoder.layer.20.intermediate.dense.weight torch.Size([4096, 1024])
# 336 transformer_model.encoder.layer.20.intermediate.dense.bias torch.Size([4096])
# 337 transformer_model.encoder.layer.20.output.dense.weight torch.Size([1024, 4096])
# 338 transformer_model.encoder.layer.20.output.dense.bias torch.Size([1024])
# 339 transformer_model.encoder.layer.20.output.LayerNorm.weight torch.Size([1024])
# 340 transformer_model.encoder.layer.20.output.LayerNorm.bias torch.Size([1024])
# 341 transformer_model.encoder.layer.21.attention.self.query.weight torch.Size([1024, 1024])
# 342 transformer_model.encoder.layer.21.attention.self.query.bias torch.Size([1024])
# 343 transformer_model.encoder.layer.21.attention.self.key.weight torch.Size([1024, 1024])
# 344 transformer_model.encoder.layer.21.attention.self.key.bias torch.Size([1024])
# 345 transformer_model.encoder.layer.21.attention.self.value.weight torch.Size([1024, 1024])
# 346 transformer_model.encoder.layer.21.attention.self.value.bias torch.Size([1024])
# 347 transformer_model.encoder.layer.21.attention.output.dense.weight torch.Size([1024, 1024])
# 348 transformer_model.encoder.layer.21.attention.output.dense.bias torch.Size([1024])
# 349 transformer_model.encoder.layer.21.attention.output.LayerNorm.weight torch.Size([1024])
# 350 transformer_model.encoder.layer.21.attention.output.LayerNorm.bias torch.Size([1024])
# 351 transformer_model.encoder.layer.21.intermediate.dense.weight torch.Size([4096, 1024])
# 352 transformer_model.encoder.layer.21.intermediate.dense.bias torch.Size([4096])
# 353 transformer_model.encoder.layer.21.output.dense.weight torch.Size([1024, 4096])
# 354 transformer_model.encoder.layer.21.output.dense.bias torch.Size([1024])
# 355 transformer_model.encoder.layer.21.output.LayerNorm.weight torch.Size([1024])
# 356 transformer_model.encoder.layer.21.output.LayerNorm.bias torch.Size([1024])
# 357 transformer_model.encoder.layer.22.attention.self.query.weight torch.Size([1024, 1024])
# 358 transformer_model.encoder.layer.22.attention.self.query.bias torch.Size([1024])
# 359 transformer_model.encoder.layer.22.attention.self.key.weight torch.Size([1024, 1024])
# 360 transformer_model.encoder.layer.22.attention.self.key.bias torch.Size([1024])
# 361 transformer_model.encoder.layer.22.attention.self.value.weight torch.Size([1024, 1024])
# 362 transformer_model.encoder.layer.22.attention.self.value.bias torch.Size([1024])
# 363 transformer_model.encoder.layer.22.attention.output.dense.weight torch.Size([1024, 1024])
# 364 transformer_model.encoder.layer.22.attention.output.dense.bias torch.Size([1024])
# 365 transformer_model.encoder.layer.22.attention.output.LayerNorm.weight torch.Size([1024])
# 366 transformer_model.encoder.layer.22.attention.output.LayerNorm.bias torch.Size([1024])
# 367 transformer_model.encoder.layer.22.intermediate.dense.weight torch.Size([4096, 1024])
# 368 transformer_model.encoder.layer.22.intermediate.dense.bias torch.Size([4096])
# 369 transformer_model.encoder.layer.22.output.dense.weight torch.Size([1024, 4096])
# 370 transformer_model.encoder.layer.22.output.dense.bias torch.Size([1024])
# 371 transformer_model.encoder.layer.22.output.LayerNorm.weight torch.Size([1024])
# 372 transformer_model.encoder.layer.22.output.LayerNorm.bias torch.Size([1024])
# 373 transformer_model.encoder.layer.23.attention.self.query.weight torch.Size([1024, 1024])
# 374 transformer_model.encoder.layer.23.attention.self.query.bias torch.Size([1024])
# 375 transformer_model.encoder.layer.23.attention.self.key.weight torch.Size([1024, 1024])
# 376 transformer_model.encoder.layer.23.attention.self.key.bias torch.Size([1024])
# 377 transformer_model.encoder.layer.23.attention.self.value.weight torch.Size([1024, 1024])
# 378 transformer_model.encoder.layer.23.attention.self.value.bias torch.Size([1024])
# 379 transformer_model.encoder.layer.23.attention.output.dense.weight torch.Size([1024, 1024])
# 380 transformer_model.encoder.layer.23.attention.output.dense.bias torch.Size([1024])
# 381 transformer_model.encoder.layer.23.attention.output.LayerNorm.weight torch.Size([1024])
# 382 transformer_model.encoder.layer.23.attention.output.LayerNorm.bias torch.Size([1024])
# 383 transformer_model.encoder.layer.23.intermediate.dense.weight torch.Size([4096, 1024])
# 384 transformer_model.encoder.layer.23.intermediate.dense.bias torch.Size([4096])
# 385 transformer_model.encoder.layer.23.output.dense.weight torch.Size([1024, 4096])
# 386 transformer_model.encoder.layer.23.output.dense.bias torch.Size([1024])
# 387 transformer_model.encoder.layer.23.output.LayerNorm.weight torch.Size([1024])
# 388 transformer_model.encoder.layer.23.output.LayerNorm.bias torch.Size([1024])
# 389 transformer_model.pooler.dense.weight torch.Size([1024, 1024])
# 390 transformer_model.pooler.dense.bias torch.Size([1024])
# 391 attention.hidden_layer.weight torch.Size([512, 1024])
# 392 attention.hidden_layer.bias torch.Size([512])
# 393 attention.final_layer.weight torch.Size([1, 512])
# 394 attention.final_layer.bias torch.Size([1])
# 395 regressor.weight torch.Size([1, 1024])
# 396 regressor.bias torch.Size([1])

# %%
sample_input_ids = torch.randint(0, 1000, [8, 248])
sample_attention_mask = torch.randint(0, 1000, [8, 248])

# %%
sample_model(sample_input_ids, sample_attention_mask)[1].shape
# Out:
# torch.Size([8, 1024])

# %%
torch.sum(torch.randn([8, 496, 768]), axis=1)
# Out:
# tensor([[ 18.8508,  26.2515, -13.1929,  ..., -26.4566,   2.5122,   9.4570],
#         [-10.2563,  -0.3151,  20.5753,  ..., -38.0424,   0.5961,  16.7331],
#         [  5.8583,  -0.8181,   8.0617,  ..., -26.2186, -30.5536, -12.2386],
#         ...,
#         [-39.3973,  28.7401,   3.3103,  ...,  13.8405,  13.7488,  -8.1065],
#         [ 12.3428,  -5.9347,   2.9950,  ...,  -3.2470,  21.3117,   3.7512],
#         [ 20.6885,   7.5613,  24.6053,  ...,   7.1157, -23.8225,   9.2827]])

# %% [markdown]
# ### Evaluation and Prediction

# %%
def eval_mse(model, data_loader):
    model.eval()
    mse_sum = 0
    mse_loss = nn.MSELoss(reduction='sum')
    
    with torch.no_grad():
        for batch_num, record in enumerate(data_loader):
            input_ids, attention_mask, target = record['input_ids'].to(cfg.DEVICE), record['attention_mask'].to(cfg.DEVICE), record['target'].to(cfg.DEVICE)
            pred, _ = model(input_ids, attention_mask)
            mse_sum += mse_loss(pred.flatten().cpu(), target.cpu())
            
    return mse_sum / len(data_loader.dataset)

# %%
def predict(model, data_loader):
    model.eval()
    result = []
    
    with torch.no_grad():
        for batch_num, record in tqdm(enumerate(data_loader), total=len(data_loader)):
            input_ids, attention_mask = record['input_ids'].to(cfg.DEVICE), record['attention_mask'].to(cfg.DEVICE)
            pred, _ = model(input_ids, attention_mask)
            result.extend(pred.flatten().to("cpu").tolist())
            
    return np.array(result)

# %%
sample_dl = DataLoader(sample_ds, shuffle=False, batch_size=16, num_workers=1)

# %% [markdown]
# ### Optimizer and Sampler

# %%
def create_optimizer(model, base_lr=5e-5):
    named_parameters = list(model.named_parameters())
    
    regressor_param_start = 395
    roberta_parameters = named_parameters[:389]
    attention_parameters = named_parameters[391:regressor_param_start]
    regressor_parameters = named_parameters[regressor_param_start:]
    
    attention_group = [params for (name, params) in attention_parameters]
    regressor_group = [params for (name, params) in regressor_parameters]
    
    parameters = []
    parameters.append({"params": attention_group})
    parameters.append({"params": regressor_group})
    
    for layer_num, (name, params) in enumerate(roberta_parameters):
        weight_decay = 0.0 if 'bias' in name else 0.01
        
        lr = find_lr_for_layer(layer_num, layer_lrs)
            
        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})
        
    return AdamW(parameters)

# %%
sample_optimizer = create_optimizer(sample_model)

# %%
from torch.utils.data import Sampler,SequentialSampler,RandomSampler,SubsetRandomSampler
from collections import Counter

class WeightedSampler(Sampler):
    
    def __init__(self, dataset):
        
        self.indices = list(range(len(dataset)))
        self.num_samples = len(dataset)
        self.label_to_count = dict(Counter(dataset.bins))
        weights = [1/self.label_to_count[i] for i in dataset.bins]
        
        self.weights = torch.tensor(weights,dtype=torch.double)
        
    def __iter__(self):
        count = 0
        index = [self.indices[i] for i in torch.multinomial(self.weights, self.num_samples, replacement=True)]
        while count < self.num_samples:
            yield index[count]
            count += 1
    
    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Training

# %%
def choose_eval_period(val_rmse):
    for rmse, period in cfg.EVAL_SCHEDULE:
        if val_rmse >= rmse:
            return period

# %%
def serialize_best(best_val_rmse, best_epoch, val_rmse, epoch, model, model_path):
    if not best_val_rmse or val_rmse < best_val_rmse:
        best_val_rmse = val_rmse
        best_epoch = epoch
        if not model_path.parent.exists():
            os.makedirs(model_path.parent)
        
        torch.save(model.state_dict(), model_path)
        print(f"New best_val_rmse: {best_val_rmse:0.4}")
    else:       
        print(f"Still best_val_rmse: {best_val_rmse:0.4}",
              f"(from epoch {best_epoch})")
    return best_epoch, best_val_rmse

# %%
class Trainer():
    def __init__(self, model, model_path, train_loader, val_loader, optimizer, scheduler=None, num_epochs=cfg.NUM_EPOCHS):
        self.model, self.model_path, self.train_loader, self.val_loader, self.optimizer, self.scheduler, self.num_epochs = (
            model, model_path, train_loader, val_loader, optimizer, scheduler, num_epochs
        )
            
    def train(self):
        self.model.train()
        mse_loss = nn.MSELoss(reduction='mean')
        
        best_val_rmse = None
        best_epoch = 0
        step = 0
        last_eval_step = 0
        eval_period = cfg.EVAL_SCHEDULE[0][1]    

        start = time.time()
        
        tbar = tqdm(range(self.num_epochs), total=self.num_epochs)
        for epoch in tbar:
            tbar.set_description(f'Epoch: {epoch}')
            val_rmse = None
            for batch_num, record in enumerate(self.train_loader):
                input_ids, attention_mask, target = record['input_ids'].to(cfg.DEVICE), record['attention_mask'].to(cfg.DEVICE), record['target'].to(cfg.DEVICE)
                
                self.optimizer.zero_grad()
                
                pred, _ = self.model(input_ids, attention_mask)
                
                mse = mse_loss(pred.flatten(), target)
                
                mse.backward()
                
                self.optimizer.step()
                if self.scheduler:
                    self.scheduler.step()
                    
                if step >= last_eval_step + eval_period:
                    elapsed_seconds = time.time() - start
                    num_steps = step - last_eval_step
                    print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                    last_eval_step = step
                    
                    val_rmse = np.sqrt(eval_mse(self.model, self.val_loader))
                    print(f"Epoch: {epoch} batch_num: {batch_num}", f"val_rmse: {val_rmse:0.4} ", end='')
                    
                    eval_period = choose_eval_period(val_rmse)
                    best_epoch, best_val_rmse = serialize_best(best_val_rmse, best_epoch, val_rmse, epoch, model, self.model_path)
                    start = time.time()
                
                step += 1
        return best_val_rmse

# %%
kfold = KFold(n_splits=cfg.NUM_FOLDS, random_state=cfg.SEED, shuffle=True)
splits = kfold.split(train_df)

# %%
# %%time

list_val_rmse = []

pbar = tqdm(enumerate(splits), total=cfg.NUM_FOLDS, position=0, leave=True)
for fold, (train_indices, val_indices) in pbar:
    pbar.set_description(f'Fold {fold}')
    model_path = cfg.MODEL_FOLDER/f"{cfg.model_name.replace('/', '_')}_{fold + 1}/model_{fold + 1}.pth"
    
    set_random_seed(cfg.SEED + fold)
    
    tokenizer = AutoTokenizer.from_pretrained(cfg.TOKENIZER_PATH)
    
    train_dataset = CommonLitDataset(train_df.loc[train_indices], tokenizer)    
    val_dataset = CommonLitDataset(train_df.loc[val_indices], tokenizer)
    
    train_loader = DataLoader(train_dataset, batch_size=cfg.BATCH_SIZE,
                              drop_last=False, shuffle=True, num_workers=cfg.NUM_WORKERS)    
    val_loader = DataLoader(val_dataset, batch_size=cfg.BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=cfg.NUM_WORKERS)
    
    set_random_seed(cfg.SEED + fold)
    
    model = CommonLitModel().to(cfg.DEVICE)
        
    optimizer = create_optimizer(model)
    
    scheduler = get_cosine_schedule_with_warmup(optimizer,
                                                num_training_steps=cfg.NUM_EPOCHS * len(train_loader), 
                                                num_warmup_steps=50)
    
    trainer = Trainer(model, model_path, train_loader, val_loader, optimizer, scheduler = scheduler)
    list_val_rmse.append(trainer.train())
    
    tokenizer.save_pretrained(str(model_path.parent))
    del model
    gc.collect()
    
    if cfg.DEVICE == 'cuda':
        torch.cuda.empty_cache()
        
print("\nPerformance estimates:")
print(list_val_rmse)
print("Mean:", np.array(list_val_rmse).mean())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# 16 steps took 13.2 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.917 New best_val_rmse: 0.917
#
# 16 steps took 11.9 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7216 New best_val_rmse: 0.7216
#
# 16 steps took 12.0 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6955 New best_val_rmse: 0.6955
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6864 New best_val_rmse: 0.6864
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.5991 New best_val_rmse: 0.5991
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5459 New best_val_rmse: 0.5459
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5966 Still best_val_rmse: 0.5459 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5586 Still best_val_rmse: 0.5459 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.6762 Still best_val_rmse: 0.5459 (from epoch 0)
#
# 16 steps took 12.4 seconds
# Epoch: 1 batch_num: 12 val_rmse: 0.5641 Still best_val_rmse: 0.5459 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 28 val_rmse: 0.5503 Still best_val_rmse: 0.5459 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 44 val_rmse: 0.5195 New best_val_rmse: 0.5195
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 60 val_rmse: 0.5051 New best_val_rmse: 0.5051
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 76 val_rmse: 0.5136 Still best_val_rmse: 0.5051 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 92 val_rmse: 0.5455 Still best_val_rmse: 0.5051 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 108 val_rmse: 0.5106 Still best_val_rmse: 0.5051 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 124 val_rmse: 0.54 Still best_val_rmse: 0.5051 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 140 val_rmse: 0.5074 Still best_val_rmse: 0.5051 (from epoch 1)
#
# 16 steps took 12.4 seconds
# Epoch: 2 batch_num: 8 val_rmse: 0.49 New best_val_rmse: 0.49
#
# 8 steps took 6.05 seconds
# Epoch: 2 batch_num: 16 val_rmse: 0.4985 Still best_val_rmse: 0.49 (from epoch 2)
#
# 8 steps took 6.04 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4877 New best_val_rmse: 0.4877
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.501 Still best_val_rmse: 0.4877 (from epoch 2)
#
# 16 steps took 12.1 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4866 New best_val_rmse: 0.4866
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.49 Still best_val_rmse: 0.4866 (from epoch 2)
#
# 8 steps took 6.03 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4886 Still best_val_rmse: 0.4866 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4893 Still best_val_rmse: 0.4866 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4891 Still best_val_rmse: 0.4866 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4882 Still best_val_rmse: 0.4866 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4863 New best_val_rmse: 0.4863
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4844 New best_val_rmse: 0.4844
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4827 New best_val_rmse: 0.4827
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4827 New best_val_rmse: 0.4827
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.483 Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4828 Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4844 Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4847 Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4835 Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4834 Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4832 Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.483 Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4825 New best_val_rmse: 0.4825
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4823 New best_val_rmse: 0.4823
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4823 Still best_val_rmse: 0.4823 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4824 Still best_val_rmse: 0.4823 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4824 Still best_val_rmse: 0.4823 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4824 Still best_val_rmse: 0.4823 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4824 Still best_val_rmse: 0.4823 (from epoch 2)
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# 16 steps took 13.5 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9536 New best_val_rmse: 0.9536
#
# 16 steps took 12.0 seconds
# Epoch: 0 batch_num: 32 val_rmse: 1.048 Still best_val_rmse: 0.9536 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6452 New best_val_rmse: 0.6452
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6142 New best_val_rmse: 0.6142
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.8239 Still best_val_rmse: 0.6142 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5846 New best_val_rmse: 0.5846
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.6714 Still best_val_rmse: 0.5846 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.721 Still best_val_rmse: 0.5846 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5402 New best_val_rmse: 0.5402
#
# 16 steps took 12.4 seconds
# Epoch: 1 batch_num: 12 val_rmse: 0.6075 Still best_val_rmse: 0.5402 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 28 val_rmse: 0.5312 New best_val_rmse: 0.5312
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 44 val_rmse: 0.5377 Still best_val_rmse: 0.5312 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 60 val_rmse: 0.5099 New best_val_rmse: 0.5099
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 76 val_rmse: 0.5243 Still best_val_rmse: 0.5099 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 92 val_rmse: 0.5041 New best_val_rmse: 0.5041
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 108 val_rmse: 0.4915 New best_val_rmse: 0.4915
#
# 8 steps took 6.06 seconds
# Epoch: 1 batch_num: 116 val_rmse: 0.4751 New best_val_rmse: 0.4751
#
# 2 steps took 1.5 seconds
# Epoch: 1 batch_num: 118 val_rmse: 0.4755 Still best_val_rmse: 0.4751 (from epoch 1)
#
# 2 steps took 1.5 seconds
# Epoch: 1 batch_num: 120 val_rmse: 0.5114 Still best_val_rmse: 0.4751 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 136 val_rmse: 0.4774 Still best_val_rmse: 0.4751 (from epoch 1)
#
# 2 steps took 1.5 seconds
# Epoch: 1 batch_num: 138 val_rmse: 0.4887 Still best_val_rmse: 0.4751 (from epoch 1)
#
# 4 steps took 3.02 seconds
# Epoch: 1 batch_num: 142 val_rmse: 0.4879 Still best_val_rmse: 0.4751 (from epoch 1)
#
# 4 steps took 3.02 seconds
# Epoch: 1 batch_num: 146 val_rmse: 0.5382 Still best_val_rmse: 0.4751 (from epoch 1)
#
# 16 steps took 12.5 seconds
# Epoch: 2 batch_num: 14 val_rmse: 0.463 New best_val_rmse: 0.463
#
# 1 steps took 0.763 seconds
# Epoch: 2 batch_num: 15 val_rmse: 0.4638 Still best_val_rmse: 0.463 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 16 val_rmse: 0.4656 Still best_val_rmse: 0.463 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 17 val_rmse: 0.4668 Still best_val_rmse: 0.463 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 18 val_rmse: 0.4663 Still best_val_rmse: 0.463 (from epoch 2)
#
# 1 steps took 0.745 seconds
# Epoch: 2 batch_num: 19 val_rmse: 0.467 Still best_val_rmse: 0.463 (from epoch 2)
#
# 1 steps took 0.745 seconds
# Epoch: 2 batch_num: 20 val_rmse: 0.4675 Still best_val_rmse: 0.463 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 21 val_rmse: 0.4649 Still best_val_rmse: 0.463 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.4626 New best_val_rmse: 0.4626
#
# 1 steps took 0.752 seconds
# Epoch: 2 batch_num: 23 val_rmse: 0.462 New best_val_rmse: 0.462
#
# 1 steps took 0.759 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.463 Still best_val_rmse: 0.462 (from epoch 2)
#
# 1 steps took 0.744 seconds
# Epoch: 2 batch_num: 25 val_rmse: 0.4636 Still best_val_rmse: 0.462 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4643 Still best_val_rmse: 0.462 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 27 val_rmse: 0.4639 Still best_val_rmse: 0.462 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4633 Still best_val_rmse: 0.462 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 29 val_rmse: 0.4624 Still best_val_rmse: 0.462 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4619 New best_val_rmse: 0.4619
#
# 1 steps took 0.767 seconds
# Epoch: 2 batch_num: 31 val_rmse: 0.4619 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4625 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.745 seconds
# Epoch: 2 batch_num: 33 val_rmse: 0.4623 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4622 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 35 val_rmse: 0.4628 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 37 val_rmse: 0.4641 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4643 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.745 seconds
# Epoch: 2 batch_num: 39 val_rmse: 0.4645 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 40 val_rmse: 0.4647 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 41 val_rmse: 0.4653 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4662 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 43 val_rmse: 0.4672 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.755 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4702 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4737 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4735 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4689 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 51 val_rmse: 0.4666 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.745 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4648 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 53 val_rmse: 0.4647 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4646 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 55 val_rmse: 0.4648 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4653 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 57 val_rmse: 0.4651 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4651 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.751 seconds
# Epoch: 2 batch_num: 59 val_rmse: 0.465 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4648 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 61 val_rmse: 0.465 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4657 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.745 seconds
# Epoch: 2 batch_num: 63 val_rmse: 0.4674 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4691 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 65 val_rmse: 0.4693 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4694 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 67 val_rmse: 0.4693 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4681 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.751 seconds
# Epoch: 2 batch_num: 69 val_rmse: 0.4663 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4653 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 71 val_rmse: 0.4646 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.745 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4644 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 73 val_rmse: 0.4644 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.465 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 75 val_rmse: 0.4657 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4663 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 77 val_rmse: 0.4665 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4664 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 79 val_rmse: 0.4663 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4661 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 81 val_rmse: 0.4655 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4647 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 83 val_rmse: 0.4641 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.751 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4634 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 85 val_rmse: 0.4631 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 87 val_rmse: 0.4629 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4629 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.744 seconds
# Epoch: 2 batch_num: 89 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.752 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4631 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 91 val_rmse: 0.4632 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4632 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 93 val_rmse: 0.4633 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4633 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 95 val_rmse: 0.4633 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.745 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 97 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.751 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 99 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4636 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 101 val_rmse: 0.4636 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4636 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 103 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 105 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.744 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4634 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 107 val_rmse: 0.4634 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4634 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 109 val_rmse: 0.4633 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4633 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 111 val_rmse: 0.4633 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.751 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4632 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 113 val_rmse: 0.4631 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 115 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 117 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 119 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 121 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.463 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.752 seconds
# Epoch: 2 batch_num: 123 val_rmse: 0.4631 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4631 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 125 val_rmse: 0.4631 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4632 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 127 val_rmse: 0.4632 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4633 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.748 seconds
# Epoch: 2 batch_num: 129 val_rmse: 0.4633 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4633 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 131 val_rmse: 0.4633 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4634 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 133 val_rmse: 0.4634 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4634 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 135 val_rmse: 0.4634 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4634 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 137 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 139 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.746 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 141 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.747 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 143 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.75 seconds
# Epoch: 2 batch_num: 145 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.744 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.448 seconds
# Epoch: 2 batch_num: 147 val_rmse: 0.4635 Still best_val_rmse: 0.4619 (from epoch 2)
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# 16 steps took 13.5 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9711 New best_val_rmse: 0.9711
#
# 16 steps took 12.0 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7132 New best_val_rmse: 0.7132
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7178 Still best_val_rmse: 0.7132 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.8724 Still best_val_rmse: 0.7132 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.7101 New best_val_rmse: 0.7101
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.7539 Still best_val_rmse: 0.7101 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.636 New best_val_rmse: 0.636
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5944 New best_val_rmse: 0.5944
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.543 New best_val_rmse: 0.543
#
# 16 steps took 12.4 seconds
# Epoch: 1 batch_num: 12 val_rmse: 0.5701 Still best_val_rmse: 0.543 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 28 val_rmse: 0.5309 New best_val_rmse: 0.5309
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 44 val_rmse: 0.5087 New best_val_rmse: 0.5087
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 60 val_rmse: 0.5488 Still best_val_rmse: 0.5087 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 76 val_rmse: 0.4945 New best_val_rmse: 0.4945
#
# 8 steps took 6.04 seconds
# Epoch: 1 batch_num: 84 val_rmse: 0.5256 Still best_val_rmse: 0.4945 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 100 val_rmse: 0.5723 Still best_val_rmse: 0.4945 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 116 val_rmse: 0.4933 New best_val_rmse: 0.4933
#
# 8 steps took 6.05 seconds
# Epoch: 1 batch_num: 124 val_rmse: 0.4954 Still best_val_rmse: 0.4933 (from epoch 1)
#
# 8 steps took 6.04 seconds
# Epoch: 1 batch_num: 132 val_rmse: 0.5111 Still best_val_rmse: 0.4933 (from epoch 1)
#
# 16 steps took 12.5 seconds
# Epoch: 2 batch_num: 0 val_rmse: 0.4852 New best_val_rmse: 0.4852
#
# 4 steps took 3.03 seconds
# Epoch: 2 batch_num: 4 val_rmse: 0.487 Still best_val_rmse: 0.4852 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 8 val_rmse: 0.4821 New best_val_rmse: 0.4821
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 12 val_rmse: 0.4983 Still best_val_rmse: 0.4821 (from epoch 2)
#
# 8 steps took 6.03 seconds
# Epoch: 2 batch_num: 20 val_rmse: 0.4823 Still best_val_rmse: 0.4821 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4806 New best_val_rmse: 0.4806
#
# 4 steps took 3.03 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4809 Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4848 Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4857 Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 40 val_rmse: 0.4895 Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4847 Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4767 New best_val_rmse: 0.4767
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4754 New best_val_rmse: 0.4754
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4747 New best_val_rmse: 0.4747
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4746 New best_val_rmse: 0.4746
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4748 Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4761 Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4785 Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4798 Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4781 Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4769 Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.476 Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4755 Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4753 Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4747 Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4741 New best_val_rmse: 0.4741
#
# 2 steps took 1.52 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4737 New best_val_rmse: 0.4737
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4737 Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4734 New best_val_rmse: 0.4734
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.473 New best_val_rmse: 0.473
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4729 New best_val_rmse: 0.4729
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4732 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4735 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4739 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4742 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4742 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4738 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4738 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4736 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4733 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4732 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.473 Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4728 New best_val_rmse: 0.4728
#
# 2 steps took 1.52 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4728 New best_val_rmse: 0.4728
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4729 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.473 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.473 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.473 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.473 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.473 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.473 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.473 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.473 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4731 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4731 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4731 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4731 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4732 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4732 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4732 Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4732 Still best_val_rmse: 0.4728 (from epoch 2)
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# 16 steps took 13.4 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9857 New best_val_rmse: 0.9857
#
# 16 steps took 12.0 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.789 New best_val_rmse: 0.789
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6541 New best_val_rmse: 0.6541
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6124 New best_val_rmse: 0.6124
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.8402 Still best_val_rmse: 0.6124 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.7199 Still best_val_rmse: 0.6124 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5423 New best_val_rmse: 0.5423
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.9919 Still best_val_rmse: 0.5423 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.6023 Still best_val_rmse: 0.5423 (from epoch 0)
#
# 16 steps took 12.4 seconds
# Epoch: 1 batch_num: 12 val_rmse: 0.5344 New best_val_rmse: 0.5344
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 28 val_rmse: 0.5222 New best_val_rmse: 0.5222
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 44 val_rmse: 0.5108 New best_val_rmse: 0.5108
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 60 val_rmse: 0.5256 Still best_val_rmse: 0.5108 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 76 val_rmse: 0.5243 Still best_val_rmse: 0.5108 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 92 val_rmse: 0.5037 New best_val_rmse: 0.5037
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 108 val_rmse: 0.5028 New best_val_rmse: 0.5028
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 124 val_rmse: 0.4911 New best_val_rmse: 0.4911
#
# 8 steps took 6.04 seconds
# Epoch: 1 batch_num: 132 val_rmse: 0.4929 Still best_val_rmse: 0.4911 (from epoch 1)
#
# 8 steps took 6.03 seconds
# Epoch: 1 batch_num: 140 val_rmse: 0.4889 New best_val_rmse: 0.4889
#
# 4 steps took 3.01 seconds
# Epoch: 1 batch_num: 144 val_rmse: 0.491 Still best_val_rmse: 0.4889 (from epoch 1)
#
# 8 steps took 6.37 seconds
# Epoch: 2 batch_num: 4 val_rmse: 0.4877 New best_val_rmse: 0.4877
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 8 val_rmse: 0.4842 New best_val_rmse: 0.4842
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 12 val_rmse: 0.4849 Still best_val_rmse: 0.4842 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 16 val_rmse: 0.4817 New best_val_rmse: 0.4817
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 20 val_rmse: 0.4812 New best_val_rmse: 0.4812
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4809 New best_val_rmse: 0.4809
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4802 New best_val_rmse: 0.4802
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4798 New best_val_rmse: 0.4798
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4808 Still best_val_rmse: 0.4798 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4777 New best_val_rmse: 0.4777
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 40 val_rmse: 0.4811 Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 3.0 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4825 Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4777 Still best_val_rmse: 0.4777 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4767 New best_val_rmse: 0.4767
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4769 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4786 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4799 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.48 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4786 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4781 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4798 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.48 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4792 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4785 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4783 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4786 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4797 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4804 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4822 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4799 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4793 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4791 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4791 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4792 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4792 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4793 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4798 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.48 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4799 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4798 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4797 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4796 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4796 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4796 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4796 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4796 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4796 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4795 Still best_val_rmse: 0.4767 (from epoch 2)
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# 16 steps took 13.5 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.016 New best_val_rmse: 1.016
#
# 16 steps took 12.0 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.769 New best_val_rmse: 0.769
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6263 New best_val_rmse: 0.6263
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.8522 Still best_val_rmse: 0.6263 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6496 Still best_val_rmse: 0.6263 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.6313 Still best_val_rmse: 0.6263 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.7003 Still best_val_rmse: 0.6263 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5344 New best_val_rmse: 0.5344
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5273 New best_val_rmse: 0.5273
#
# 16 steps took 12.3 seconds
# Epoch: 1 batch_num: 12 val_rmse: 0.5559 Still best_val_rmse: 0.5273 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 28 val_rmse: 0.5065 New best_val_rmse: 0.5065
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 44 val_rmse: 0.538 Still best_val_rmse: 0.5065 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 60 val_rmse: 0.6044 Still best_val_rmse: 0.5065 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 76 val_rmse: 0.51 Still best_val_rmse: 0.5065 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 92 val_rmse: 0.5493 Still best_val_rmse: 0.5065 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 108 val_rmse: 0.5101 Still best_val_rmse: 0.5065 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 124 val_rmse: 0.5072 Still best_val_rmse: 0.5065 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 140 val_rmse: 0.5187 Still best_val_rmse: 0.5065 (from epoch 1)
#
# 16 steps took 12.5 seconds
# Epoch: 2 batch_num: 8 val_rmse: 0.4776 New best_val_rmse: 0.4776
#
# 2 steps took 1.52 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.4844 Still best_val_rmse: 0.4776 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 14 val_rmse: 0.4904 Still best_val_rmse: 0.4776 (from epoch 2)
#
# 8 steps took 6.04 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.4773 New best_val_rmse: 0.4773
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4765 New best_val_rmse: 0.4765
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4767 Still best_val_rmse: 0.4765 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4772 Still best_val_rmse: 0.4765 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4785 Still best_val_rmse: 0.4765 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4799 Still best_val_rmse: 0.4765 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4778 Still best_val_rmse: 0.4765 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4762 New best_val_rmse: 0.4762
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4769 Still best_val_rmse: 0.4762 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 40 val_rmse: 0.4765 Still best_val_rmse: 0.4762 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4771 Still best_val_rmse: 0.4762 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4774 Still best_val_rmse: 0.4762 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4766 Still best_val_rmse: 0.4762 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4761 New best_val_rmse: 0.4761
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4768 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.478 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4782 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4784 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.478 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.478 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4778 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4773 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.477 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4766 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4769 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4784 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4793 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4797 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4795 Still best_val_rmse: 0.4761 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4761 New best_val_rmse: 0.4761
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4748 New best_val_rmse: 0.4748
#
# 2 steps took 1.52 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4752 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4762 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4776 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4783 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4783 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.478 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4775 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4775 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4771 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.477 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4772 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4773 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4772 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4771 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4772 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.477 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4767 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4763 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.476 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4758 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4755 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4753 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4752 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4751 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4751 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4751 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4751 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4751 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4751 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4751 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4751 Still best_val_rmse: 0.4748 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4751 Still best_val_rmse: 0.4748 (from epoch 2)
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# 16 steps took 13.5 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9658 New best_val_rmse: 0.9658
#
# 16 steps took 12.0 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.6882 New best_val_rmse: 0.6882
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.8577 Still best_val_rmse: 0.6882 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.8681 Still best_val_rmse: 0.6882 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.7302 Still best_val_rmse: 0.6882 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5942 New best_val_rmse: 0.5942
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5952 Still best_val_rmse: 0.5942 (from epoch 0)
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5557 New best_val_rmse: 0.5557
#
# 16 steps took 12.1 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5374 New best_val_rmse: 0.5374
#
# 16 steps took 12.4 seconds
# Epoch: 1 batch_num: 12 val_rmse: 0.5131 New best_val_rmse: 0.5131
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 28 val_rmse: 0.5123 New best_val_rmse: 0.5123
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 44 val_rmse: 0.5128 Still best_val_rmse: 0.5123 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 60 val_rmse: 0.5461 Still best_val_rmse: 0.5123 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 76 val_rmse: 0.5109 New best_val_rmse: 0.5109
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 92 val_rmse: 0.5595 Still best_val_rmse: 0.5109 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 108 val_rmse: 0.4931 New best_val_rmse: 0.4931
#
# 8 steps took 6.04 seconds
# Epoch: 1 batch_num: 116 val_rmse: 0.5203 Still best_val_rmse: 0.4931 (from epoch 1)
#
# 16 steps took 12.1 seconds
# Epoch: 1 batch_num: 132 val_rmse: 0.4969 Still best_val_rmse: 0.4931 (from epoch 1)
#
# 8 steps took 6.04 seconds
# Epoch: 1 batch_num: 140 val_rmse: 0.4997 Still best_val_rmse: 0.4931 (from epoch 1)
#
# 8 steps took 6.37 seconds
# Epoch: 2 batch_num: 0 val_rmse: 0.4917 New best_val_rmse: 0.4917
#
# 8 steps took 6.04 seconds
# Epoch: 2 batch_num: 8 val_rmse: 0.5012 Still best_val_rmse: 0.4917 (from epoch 2)
#
# 16 steps took 12.1 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4967 Still best_val_rmse: 0.4917 (from epoch 2)
#
# 8 steps took 6.04 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4851 New best_val_rmse: 0.4851
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4836 New best_val_rmse: 0.4836
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 40 val_rmse: 0.504 Still best_val_rmse: 0.4836 (from epoch 2)
#
# 16 steps took 12.1 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4849 Still best_val_rmse: 0.4836 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4908 Still best_val_rmse: 0.4836 (from epoch 2)
#
# 8 steps took 6.04 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4835 New best_val_rmse: 0.4835
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4871 Still best_val_rmse: 0.4835 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4943 Still best_val_rmse: 0.4835 (from epoch 2)
#
# 8 steps took 6.04 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4824 New best_val_rmse: 0.4824
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4816 New best_val_rmse: 0.4816
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4815 New best_val_rmse: 0.4815
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4803 New best_val_rmse: 0.4803
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.481 Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 3.0 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4818 Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4819 Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 3.01 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4801 New best_val_rmse: 0.4801
#
# 4 steps took 3.02 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4791 New best_val_rmse: 0.4791
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4789 New best_val_rmse: 0.4789
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4787 New best_val_rmse: 0.4787
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4786 New best_val_rmse: 0.4786
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4786 New best_val_rmse: 0.4786
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4786 New best_val_rmse: 0.4786
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4786 Still best_val_rmse: 0.4786 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4786 Still best_val_rmse: 0.4786 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4787 Still best_val_rmse: 0.4786 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4787 Still best_val_rmse: 0.4786 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4786 Still best_val_rmse: 0.4786 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4786 Still best_val_rmse: 0.4786 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4786 Still best_val_rmse: 0.4786 (from epoch 2)
#
# 2 steps took 1.51 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4786 Still best_val_rmse: 0.4786 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4786 Still best_val_rmse: 0.4786 (from epoch 2)
#
# 2 steps took 1.5 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4786 Still best_val_rmse: 0.4786 (from epoch 2)
#
#
#
# Performance estimates:
# [tensor(0.4823), tensor(0.4619), tensor(0.4728), tensor(0.4767), tensor(0.4748), tensor(0.4786)]
# Mean: 0.4745271
# CPU times: user 1h 26min 47s, sys: 16min 11s, total: 1h 42min 58s
# Wall time: 1h 47min 6s

# %% [markdown]
# ### Verify the model

# %%
from sklearn.svm import SVR
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
from tqdm.notebook import tqdm

# %%
cfg.model_offset = 0
cfg.model_limit = 6
cfg.n_folds = 5
cfg.svm_kernels = ['rbf']
cfg.svm_c = 5

# %%
num_bins = int(np.ceil(np.log2(len(train_df))))
train_df['bins'] = pd.cut(train_df['target'], bins=num_bins, labels=False)
bins = train_df['bins'].values

# %%
# %%time

inference_models = []
for i in range(1, cfg.NUM_FOLDS + 1):
    print(f'Model {i}')
    inference_model = CommonLitModel()
    inference_model = inference_model.cuda()
    inference_model.load_state_dict(torch.load(str(MODELS_PATH/f"{cfg.model_name.replace('/', '_')}_{i}/model_{i}.pth")))
    inference_model.eval();
    inference_models.append(inference_model)
# Out:
# Model 1
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model 2
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model 3
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model 4
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model 5
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model 6
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# CPU times: user 21.8 s, sys: 6.16 s, total: 28 s
# Wall time: 33.6 s

# %%
from transformers import RobertaTokenizer

tokenizers = []
for i in range(1, cfg.NUM_FOLDS):
    tokenizer = RobertaTokenizer.from_pretrained(MODELS_PATH/f"{cfg.model_name.replace('/', '_')}_{i}")
    tokenizers.append(tokenizer)

# %%
def get_cls_embeddings(dl, transformer_model):
    cls_embeddings = []
    with torch.no_grad():
        for input_features in tqdm(dl, total=len(dl)):
            output, context_vector = transformer_model(input_features['input_ids'].cuda(), input_features['attention_mask'].cuda())
#             cls_embeddings.extend(output['last_hidden_state'][:,0,:].detach().cpu().numpy())
            embedding_out = context_vector.detach().cpu().numpy()
            cls_embeddings.extend(embedding_out)
    return np.array(cls_embeddings)

# %%
def rmse_score(X, y):
    return np.sqrt(mean_squared_error(X, y))

# %%
def convert_to_list(t):
    return t.flatten().long()

class CommonLitDataset(nn.Module):
    def __init__(self, text, test_id, tokenizer, max_len=128):
        self.excerpt = text
        self.test_id = test_id
        self.max_len = max_len
        self.tokenizer = tokenizer
    
    def __getitem__(self,idx):
        encode = self.tokenizer(self.excerpt[idx],
                                return_tensors='pt',
                                max_length=self.max_len,
                                padding='max_length',
                                truncation=True)
        return {'input_ids': convert_to_list(encode['input_ids']),
                'attention_mask': convert_to_list(encode['attention_mask']),
                'id': self.test_id[idx]}
    
    def __len__(self):
        return len(self.excerpt)

# %%
def create_dl(df, tokenizer):
    text = df['excerpt'].values
    ids = df['id'].values
    ds = CommonLitDataset(text, ids, tokenizer, max_len=cfg.MAX_LEN)
    return DataLoader(ds, 
                      batch_size = cfg.BATCH_SIZE,
                      shuffle=False,
                      num_workers = 1,
                      pin_memory=True,
                      drop_last=False
                     )

# %%
train_df = pd.read_csv(DATA_PATH/'train-orig.csv')
test_df = pd.read_csv(DATA_PATH/'test.csv')
remove_unnecessary(train_df)

# %%
train_target_mean = train_df['target'].mean()
train_target_std = train_df['target'].std()
train_df['normalized_target'] = (train_df['target'] - train_target_mean) / train_target_std

# %%
# %%time

train_target = train_df['normalized_target'].values

def calc_mean(scores):
    return np.mean(np.array(scores), axis=0)

final_scores = []
final_rmse = []
kernel_rmse_score_mean = []
final_kernel_predictions_means = []
for j, (inference_model, tokenizer) in enumerate(zip(inference_models, tokenizers)):
    print('Model', j)
    test_dl = create_dl(test_df, tokenizer)
    train_dl = create_dl(train_df, tokenizer)
    transformer_model = inference_model
    transformer_model.cuda()
    X = get_cls_embeddings(train_dl, transformer_model)
    
    y = train_target
    X_test = get_cls_embeddings(test_dl, transformer_model)
    
    kfold = StratifiedKFold(n_splits=cfg.NUM_FOLDS)
    scores = []
    rmse_scores = []
    kernel_predictions_means = []
    for kernel in cfg.svm_kernels:
        print('Kernel', kernel)
        kernel_scores = []
        kernel_rmse_scores = []
        kernel_predictions = []
        for k, (train_idx, valid_idx) in enumerate(kfold.split(X, bins)):

            print('Fold', k, train_idx.shape, valid_idx.shape)
            model = SVR(C=cfg.svm_c, kernel=kernel, gamma='auto')

            X_train, y_train = X[train_idx], y[train_idx]
            X_valid, y_valid = X[valid_idx], y[valid_idx]
            model.fit(X_train, y_train)
            prediction = model.predict(X_valid)
            kernel_predictions.append(prediction)
            kernel_rmse_scores.append(rmse_score(prediction, y_valid))
            print('rmse_score', kernel_rmse_scores[k])
            kernel_scores.append(model.predict(X_test))
        kernel_predictions_means.append(np.array([np.mean(kp) for kp in kernel_predictions]).mean())
        scores.append(calc_mean(kernel_scores))
        kernel_rmse_score = calc_mean(kernel_rmse_scores)
        kernel_rmse_score_mean.append(kernel_rmse_score)
        rmse_scores.append(kernel_rmse_score)
    final_kernel_predictions_means.append(kernel_predictions_means)
    final_scores.append(calc_mean(scores))
    final_rmse.append(calc_mean(rmse_scores))
print('FINAL RMSE score', np.mean(np.array(final_rmse)))
# Out:
# Model 0
# HBox(children=(FloatProgress(value=0.0, max=178.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Kernel rbf
# Fold 0 (2360,) (473,)
# rmse_score 0.28324863964828917
# Fold 1 (2361,) (472,)
# rmse_score 0.26841914727924204
# Fold 2 (2361,) (472,)
# rmse_score 0.2533739187876605
# Fold 3 (2361,) (472,)
# rmse_score 0.22056289042706076
# Fold 4 (2361,) (472,)
# rmse_score 0.2605613215619025
# Fold 5 (2361,) (472,)
# rmse_score 0.2765559437393404
# Model 1
# HBox(children=(FloatProgress(value=0.0, max=178.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Kernel rbf
# Fold 0 (2360,) (473,)
# rmse_score 0.28430267175335816
# Fold 1 (2361,) (472,)
# rmse_score 0.29901413527747545
# Fold 2 (2361,) (472,)
# rmse_score 0.2784529315893369
# Fold 3 (2361,) (472,)
# rmse_score 0.28718327451989784
# Fold 4 (2361,) (472,)
# rmse_score 0.2798942952738696
# Fold 5 (2361,) (472,)
# rmse_score 0.30629605936839704
# Model 2
# HBox(children=(FloatProgress(value=0.0, max=178.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Kernel rbf
# Fold 0 (2360,) (473,)
# rmse_score 0.2656873272359996
# Fold 1 (2361,) (472,)
# rmse_score 0.2606104545594953
# Fold 2 (2361,) (472,)
# rmse_score 0.23876040297908468
# Fold 3 (2361,) (472,)
# rmse_score 0.26160633779324055
# Fold 4 (2361,) (472,)
# rmse_score 0.26335699854383254
# Fold 5 (2361,) (472,)
# rmse_score 0.27483693174127427
# Model 3
# HBox(children=(FloatProgress(value=0.0, max=178.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Kernel rbf
# Fold 0 (2360,) (473,)
# rmse_score 0.2772769350819293
# Fold 1 (2361,) (472,)
# rmse_score 0.294327775384013
# Fold 2 (2361,) (472,)
# rmse_score 0.2839582780677087
# Fold 3 (2361,) (472,)
# rmse_score 0.25797736124278753
# Fold 4 (2361,) (472,)
# rmse_score 0.267610582880688
# Fold 5 (2361,) (472,)
# rmse_score 0.28228418709327097
# Model 4
# HBox(children=(FloatProgress(value=0.0, max=178.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Kernel rbf
# Fold 0 (2360,) (473,)
# rmse_score 0.27107938620374245
# Fold 1 (2361,) (472,)
# rmse_score 0.2610205212830527
# Fold 2 (2361,) (472,)
# rmse_score 0.24059086310610506
# Fold 3 (2361,) (472,)
# rmse_score 0.25220185954038116
# Fold 4 (2361,) (472,)
# rmse_score 0.28956561200359904
# Fold 5 (2361,) (472,)
# rmse_score 0.2900428628822737
# FINAL RMSE score 0.27102199689494366
# CPU times: user 4min 53s, sys: 4.26 s, total: 4min 57s
# Wall time: 4min 55s

# %%
final_kernel_predictions_means
# Out:
# [[0.0003726381269821162],
#  [0.000990276888482543],
#  [0.0017044838414804954],
#  [-0.0004041194470663396],
#  [-0.0018819231666562849]]

# %%
# (train_df['target'] - cfg.train_target_mean) / cfg.train_target_std
final_scores_normalized = np.array(final_scores) * train_target_std + train_target_mean

# %%
kernel_rmse_score_mean_array = np.array(kernel_rmse_score_mean)
kernel_rmse_score_mean_sum = np.sum(kernel_rmse_score_mean_array)
prop_losses = kernel_rmse_score_mean_array / kernel_rmse_score_mean_sum
prop_losses_sum = (1 - prop_losses).sum()
weights = (1 - prop_losses) / prop_losses_sum
weights
# Out:
# array([0.20194972, 0.19664814, 0.20188403, 0.19885301, 0.2006651 ])

# %%
def calc_mean(scores, weights=weights):
    return np.average(np.array(scores), weights=weights, axis=0)

# %%
target_mean = train_df['target'].mean()
final_scores_flat = calc_mean(final_scores_normalized).flatten()
final_scores_mean = final_scores_flat.mean()
target_mean, np.array(final_scores_normalized).mean()
# (-0.9579984513405823, -0.8029817438292849)
# Out:
# (-0.9596573929279916, -0.931538057900588)

# %%
final_scores_flat
# Out:
# array([-0.39430634, -0.4049713 , -0.40267822, -2.35235726, -1.95518216,
#        -1.30780155,  0.29770328])

# %%
mean_diff = target_mean - final_scores_mean
mean_diff, mean_diff / len(final_scores)
# Out:
# (-0.028286885537840978, -0.0056573771075681956)

# %%
sample_df['target'] = final_scores_flat + mean_diff
# sample_df['target'] = len(final_scores) / np.sum(1 / np.array(final_scores), axis=0) # harmonic mean
sample_df
# Out:
#           id    target
# 0  c0f722661 -0.422593
# 1  f0953f0a5 -0.433258
# 2  0df072751 -0.430965
# 3  04caf4e0c -2.380644
# 4  0e63f8bea -1.983469
# 5  12537fe78 -1.336088
# 6  965e592c0  0.269416

# %% [markdown]
# ### Prepare Packaging

# %%
cfg.model_name
# Out:
# 'roberta-large'

# %%
BEST_MODEL_FOLDER = MODELS_PATH/cfg.model_name/'best'
# !rm -rf {BEST_MODEL_FOLDER}
# !mkdir -p {BEST_MODEL_FOLDER}

# %%
BEST_MODEL_FOLDER
# Out:
# PosixPath('/home/commonlit/models/roberta-large/best')

# %%
cfg.NUM_FOLDS
# Out:
# 6

# %%
bestmodels = [MODELS_PATH/f'{cfg.model_name}_{i + 1}' for i in range(0, cfg.NUM_FOLDS)]

# %%
bestmodels
# Out:
# [PosixPath('/home/commonlit/models/roberta-large_1'),
#  PosixPath('/home/commonlit/models/roberta-large_2'),
#  PosixPath('/home/commonlit/models/roberta-large_3'),
#  PosixPath('/home/commonlit/models/roberta-large_4'),
#  PosixPath('/home/commonlit/models/roberta-large_5'),
#  PosixPath('/home/commonlit/models/roberta-large_6')]

# %%
from shutil import copyfile

def normalize_name(path_name):
    return path_name.replace('', '')

for i, best_model in enumerate(bestmodels):
    print(f'Processing {i}th model')
    i = i + 1
    best_model_file = f'{best_model}/model_{i}.pth'
    if Path(best_model_file).exists():
        copyfile(best_model_file, f'{BEST_MODEL_FOLDER}/{i}_pytorch_model.bin')
        tokenizer_path = Path(BEST_MODEL_FOLDER/f'tokenizer-{i}')
        tokenizer_path.mkdir(parents=True, exist_ok=True)
        assert tokenizer_path.exists()

        tokenizer_json = Path(normalize_name(f'{MODELS_PATH/cfg.model_name}_{i}/tokenizer_config.json'))
        assert tokenizer_json.exists(), f'{tokenizer_json} does not exist'
        copyfile(tokenizer_json, tokenizer_path/'tokenizer.json')

        vocab_txt = Path(normalize_name(f'{MODELS_PATH/cfg.model_name}_{i}/vocab.json'))
        assert vocab_txt.exists(), f'{vocab_txt} does not exist'
        copyfile(vocab_txt, tokenizer_path/'vocab.json')

        merges = Path(normalize_name(f'{MODELS_PATH/cfg.model_name}_{i}/merges.txt'))
        assert merges.exists()
        copyfile(merges, tokenizer_path/'merges.txt')
    else:
        print(f'{best_model_file} is missing')
# Out:
# Processing 0th model
# Processing 1th model
# Processing 2th model
# Processing 3th model
# Processing 4th model
# Processing 5th model

# %%
import shutil

shutil.make_archive(MODELS_PATH/cfg.model_name/'best_models', 'zip', BEST_MODEL_FOLDER)
# Out:
# '/home/commonlit/models/roberta-large/best_models.zip'

# %%
# !ls {MODELS_PATH/cfg.model_name}
# Out:
# best  best_models.zip  dataset-metadata.json  lm  lm.zip  roberta-large.yaml

# %%
# !mv {MODELS_PATH}/{cfg.model_name}.yaml {MODELS_PATH/cfg.model_name}
# Out:
# mv: cannot stat '/home/commonlit/models/roberta-large.yaml': No such file or directory

# %%
transformer_model.transformer_model.save_pretrained(save_directory=f'{MODELS_PATH/cfg.model_name}/lm')

# %%
# !du -h {MODELS_PATH/cfg.model_name}/*
# Out:
# 1.3M	/home/commonlit/models/roberta-large/best/tokenizer-1
# 1.3M	/home/commonlit/models/roberta-large/best/tokenizer-2
# 1.3M	/home/commonlit/models/roberta-large/best/tokenizer-3
# 1.3M	/home/commonlit/models/roberta-large/best/tokenizer-4
# 1.3M	/home/commonlit/models/roberta-large/best/tokenizer-5
# 1.3M	/home/commonlit/models/roberta-large/best/tokenizer-6
# 8.0G	/home/commonlit/models/roberta-large/best
# 7.3G	/home/commonlit/models/roberta-large/best_models.zip
# 4.0K	/home/commonlit/models/roberta-large/dataset-metadata.json
# 1.4G	/home/commonlit/models/roberta-large/lm
# 1.3G	/home/commonlit/models/roberta-large/lm.zip
# 4.0K	/home/commonlit/models/roberta-large/roberta-large.yaml

# %%
shutil.make_archive(MODELS_PATH/cfg.model_name/'lm', 'zip', f'{MODELS_PATH/cfg.model_name}/lm')
# Out:
# '/home/commonlit/models/roberta-large/lm.zip'

# %%
# !kaggle datasets init -p {MODELS_PATH/cfg.model_name}
# Out:
# Data package template written to: /home/commonlit/models/roberta-large/dataset-metadata.json

# %%
dataset_json_path = Path(MODELS_PATH/cfg.model_name/'dataset-metadata.json')
assert dataset_json_path.exists()

# %%
# !cat {str(dataset_json_path)}
# Out:
# {
#   "title": "INSERT_TITLE_HERE",
#   "id": "gilfernandes/INSERT_SLUG_HERE",
#   "licenses": [
#     {
#       "name": "CC0-1.0"
#     }
#   ]
# }

# %%
with open(dataset_json_path, 'r') as f:
    dataset_json = f.read()
    dataset_json = dataset_json.replace('INSERT_TITLE_HERE', f'commonlit-{cfg.model_name}-light-2').replace('INSERT_SLUG_HERE', f'commonlit-{cfg.model_name}-light-2')
    print(dataset_json)
with(open(dataset_json_path, 'w')) as f:
    f.write(dataset_json)
# Out:
# {
#   "title": "commonlit-roberta-large-light-2",
#   "id": "gilfernandes/commonlit-roberta-large-light-2",
#   "licenses": [
#     {
#       "name": "CC0-1.0"
#     }
#   ]
# }

# %%
# !rm -rf {MODELS_PATH/cfg.model_name}/best
# !rm -rf {MODELS_PATH/cfg.model_name}/lm

# %%
# !kaggle datasets create -p {MODELS_PATH/cfg.model_name}
# Out:
# Starting upload for file best_models.zip
# 100%|██████████████████████████████████████| 7.24G/7.24G [12:07<00:00, 10.7MB/s]
# Upload successful: best_models.zip (7GB)
# Starting upload for file roberta-large.yaml
# 100%|███████████████████████████████████████████| 115/115 [00:07<00:00, 15.4B/s]
# Upload successful: roberta-large.yaml (115B)
# Starting upload for file lm.zip
# 100%|██████████████████████████████████████| 1.20G/1.20G [02:05<00:00, 10.3MB/s]
# Upload successful: lm.zip (1GB)
# Your private Dataset is being created. Please check progress at /api/v1/datasets/status//gilfernandes/commonlit-roberta-large-light-2

# %%
# !kaggle datasets version -p {MODELS_PATH/cfg.model_name} -m "Version with merges.txt" -d
# Out:
# Starting upload for file best_models.zip
# 100%|██████████████████████████████████████| 7.24G/7.24G [12:39<00:00, 10.2MB/s]
# Upload successful: best_models.zip (7GB)
# Starting upload for file roberta-large.yaml
# 100%|███████████████████████████████████████████| 115/115 [00:08<00:00, 14.4B/s]
# Upload successful: roberta-large.yaml (115B)
# Starting upload for file lm.zip
# 100%|██████████████████████████████████████| 1.20G/1.20G [02:35<00:00, 8.31MB/s]
# Upload successful: lm.zip (1GB)
# Skipping folder: best; use '--dir-mode' to upload folders
# Skipping folder: lm; use '--dir-mode' to upload folders
# Dataset version is being created. Please check progress at /api/v1/datasets/status/gilfernandes/commonlit-roberta-large-light

# %%
state_dict = torch.load(str(MODELS_PATH/f'distilroberta-0/checkpoint-105/pytorch_model.bin'))

# %%
loaded_model = CommonLitModel()

# %%
loaded_model.load_state_dict(state_dict)
