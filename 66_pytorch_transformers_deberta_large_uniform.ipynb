# %%
# !pip install optuna

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import gc, warnings, random, time, os

from pathlib import Path

from tqdm.notebook import tqdm

warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.optim import Adam, lr_scheduler
from torch.utils.data import Dataset, DataLoader
from transformers import AdamW
from transformers import AutoModel, AutoTokenizer, AutoConfig
from transformers import get_cosine_schedule_with_warmup

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

import seaborn as sns

import gc
gc.enable()

import optuna

# %% [markdown]
# ### Folders and Dataframes

# %%
DATA_PATH = Path('/home/commonlit/data/')
assert DATA_PATH.exists()
MODELS_PATH = Path('/home/commonlit/models/')
if not MODELS_PATH.exists():
    os.mkdir(MODELS_PATH)
assert MODELS_PATH.exists()

# %%
train_df = pd.read_csv(DATA_PATH/'train-orig.csv')
test_df = pd.read_csv(DATA_PATH/'test.csv')
sample_df = pd.read_csv(DATA_PATH/'sample_submission.csv')

# %%
def remove_unnecessary(df):
    df.drop(df[df['target'] == 0].index, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
remove_unnecessary(train_df)

# %%
sns.displot(train_df['target'])

# %% [markdown]
# ### Config and Seeding

# %%
class Config(): 
    NUM_FOLDS = 6
    NUM_EPOCHS = 4
    BATCH_SIZE = 16
    MAX_LEN = 248
    EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
    ROBERTA_PATH = 'microsoft/deberta-large'
    TOKENIZER_PATH = 'microsoft/deberta-large'
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    SEED = 1000
    NUM_WORKERS = 2
    MODEL_FOLDER = MODELS_PATH
    model_name = 'deberta-large-uniform'
    svm_kernels = ['rbf']
    svm_c = 5

cfg = Config()

# %%
if not cfg.MODEL_FOLDER.exists():
    os.mkdir(cfg.MODEL_FOLDER)

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ### Dataset

# %%
def add_bins(train_df, num_bins):
    train_df.loc[:, 'bins'] = pd.cut(train_df['target'], bins=num_bins, labels=False)
    return num_bins

# %%
add_bins(train_df, cfg.NUM_FOLDS)
# Out:
# 6

# %%
train_df['bins'].value_counts()
# Out:
# 3    886
# 2    784
# 4    495
# 1    441
# 0    122
# 5    106
# Name: bins, dtype: int64

# %%
train_df.groupby(['bins'])['target'].agg(['count', 'mean'])
# Out:
#       count      mean
# bins
# 0       122 -3.125765
# 1       441 -2.270279
# 2       784 -1.412150
# 3       886 -0.548095
# 4       494  0.289716
# 5       106  1.070237

# %%
tokenizer = AutoTokenizer.from_pretrained(cfg.TOKENIZER_PATH)

# %%
class CommonLitDataset(Dataset):
    def __init__(self, df, tokenizer, inference_only=False):
        super().__init__()
        self.df, self.inference_only = df, inference_only
        self.text = df['excerpt'].tolist()
        self.bins = df['bins']
        if not inference_only:
            self.target = torch.tensor(df['target'].to_numpy(), dtype = torch.float32)
        
        self.encoded = tokenizer.batch_encode_plus(
            self.text,
            padding = 'max_length',
            max_length = cfg.MAX_LEN,
            truncation = True,
            return_attention_mask=True
        )
        
    def __getitem__(self, index):        
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return {'input_ids': input_ids, 'attention_mask': attention_mask}
        else:
            target = self.target[index]
            return {'input_ids': input_ids, 'attention_mask': attention_mask, 'target': target}
    
    def __len__(self):
        return len(self.df)
    
    def __repr__(self):
        return f'{len(self.df)} records'

# %%
sample_ds = CommonLitDataset(train_df, tokenizer)

# %%
sample_ds
# Out:
# 2834 records

# %% [markdown]
# ### Model

# %%
class AttentionHead(nn.Module):
    
    def __init__(self, in_features, hidden_dim, num_targets):
        super().__init__()
        self.in_features = in_features
        
        self.hidden_layer = nn.Linear(in_features, hidden_dim)
        self.final_layer = nn.Linear(hidden_dim, num_targets)
        self.out_features = hidden_dim
        
    def forward(self, features):
        att = torch.tanh(self.hidden_layer(features))
        score = self.final_layer(att)
        attention_weights = torch.softmax(score, dim=1)
        return attention_weights

# %%
class CommonLitModel(nn.Module):
    def __init__(self):
        super(CommonLitModel, self).__init__()
        config = AutoConfig.from_pretrained(cfg.ROBERTA_PATH)
        config.update({
            "output_hidden_states": True,
            "hidden_dropout_prob": 0.0,
            "layer_norm_eps": 1e-7
        })
        self.transformer_model = AutoModel.from_pretrained(cfg.ROBERTA_PATH, config=config)
        self.attention = AttentionHead(config.hidden_size, 512, 1)
        self.regressor = nn.Linear(config.hidden_size, 1)
    
    def forward(self, input_ids, attention_mask):
        last_layer_hidden_states = self.transformer_model(input_ids=input_ids, attention_mask=attention_mask)['last_hidden_state']
        weights = self.attention(last_layer_hidden_states)
        context_vector = torch.sum(weights * last_layer_hidden_states, dim=1) 
        return self.regressor(context_vector), context_vector

# %%
sample_model = CommonLitModel()
# Out:
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaModel: ['config', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import re

for i, (name, param) in enumerate(sample_model.named_parameters()):
    if(name.find('layer') > -1):
        layer_name = re.sub(r'.+(layer\.\d+).+', r'\1', name)

# %%
for i, (name, param) in enumerate(sample_model.named_parameters()):
    print(i, name, param.size())
# Out:
# 0 transformer_model.embeddings.word_embeddings.weight torch.Size([50265, 1024])
# 1 transformer_model.embeddings.LayerNorm.weight torch.Size([1024])
# 2 transformer_model.embeddings.LayerNorm.bias torch.Size([1024])
# 3 transformer_model.encoder.layer.0.attention.self.q_bias torch.Size([1024])
# 4 transformer_model.encoder.layer.0.attention.self.v_bias torch.Size([1024])
# 5 transformer_model.encoder.layer.0.attention.self.in_proj.weight torch.Size([3072, 1024])
# 6 transformer_model.encoder.layer.0.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 7 transformer_model.encoder.layer.0.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 8 transformer_model.encoder.layer.0.attention.self.pos_q_proj.bias torch.Size([1024])
# 9 transformer_model.encoder.layer.0.attention.output.dense.weight torch.Size([1024, 1024])
# 10 transformer_model.encoder.layer.0.attention.output.dense.bias torch.Size([1024])
# 11 transformer_model.encoder.layer.0.attention.output.LayerNorm.weight torch.Size([1024])
# 12 transformer_model.encoder.layer.0.attention.output.LayerNorm.bias torch.Size([1024])
# 13 transformer_model.encoder.layer.0.intermediate.dense.weight torch.Size([4096, 1024])
# 14 transformer_model.encoder.layer.0.intermediate.dense.bias torch.Size([4096])
# 15 transformer_model.encoder.layer.0.output.dense.weight torch.Size([1024, 4096])
# 16 transformer_model.encoder.layer.0.output.dense.bias torch.Size([1024])
# 17 transformer_model.encoder.layer.0.output.LayerNorm.weight torch.Size([1024])
# 18 transformer_model.encoder.layer.0.output.LayerNorm.bias torch.Size([1024])
# 19 transformer_model.encoder.layer.1.attention.self.q_bias torch.Size([1024])
# 20 transformer_model.encoder.layer.1.attention.self.v_bias torch.Size([1024])
# 21 transformer_model.encoder.layer.1.attention.self.in_proj.weight torch.Size([3072, 1024])
# 22 transformer_model.encoder.layer.1.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 23 transformer_model.encoder.layer.1.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 24 transformer_model.encoder.layer.1.attention.self.pos_q_proj.bias torch.Size([1024])
# 25 transformer_model.encoder.layer.1.attention.output.dense.weight torch.Size([1024, 1024])
# 26 transformer_model.encoder.layer.1.attention.output.dense.bias torch.Size([1024])
# 27 transformer_model.encoder.layer.1.attention.output.LayerNorm.weight torch.Size([1024])
# 28 transformer_model.encoder.layer.1.attention.output.LayerNorm.bias torch.Size([1024])
# 29 transformer_model.encoder.layer.1.intermediate.dense.weight torch.Size([4096, 1024])
# 30 transformer_model.encoder.layer.1.intermediate.dense.bias torch.Size([4096])
# 31 transformer_model.encoder.layer.1.output.dense.weight torch.Size([1024, 4096])
# 32 transformer_model.encoder.layer.1.output.dense.bias torch.Size([1024])
# 33 transformer_model.encoder.layer.1.output.LayerNorm.weight torch.Size([1024])
# 34 transformer_model.encoder.layer.1.output.LayerNorm.bias torch.Size([1024])
# 35 transformer_model.encoder.layer.2.attention.self.q_bias torch.Size([1024])
# 36 transformer_model.encoder.layer.2.attention.self.v_bias torch.Size([1024])
# 37 transformer_model.encoder.layer.2.attention.self.in_proj.weight torch.Size([3072, 1024])
# 38 transformer_model.encoder.layer.2.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 39 transformer_model.encoder.layer.2.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 40 transformer_model.encoder.layer.2.attention.self.pos_q_proj.bias torch.Size([1024])
# 41 transformer_model.encoder.layer.2.attention.output.dense.weight torch.Size([1024, 1024])
# 42 transformer_model.encoder.layer.2.attention.output.dense.bias torch.Size([1024])
# 43 transformer_model.encoder.layer.2.attention.output.LayerNorm.weight torch.Size([1024])
# 44 transformer_model.encoder.layer.2.attention.output.LayerNorm.bias torch.Size([1024])
# 45 transformer_model.encoder.layer.2.intermediate.dense.weight torch.Size([4096, 1024])
# 46 transformer_model.encoder.layer.2.intermediate.dense.bias torch.Size([4096])
# 47 transformer_model.encoder.layer.2.output.dense.weight torch.Size([1024, 4096])
# 48 transformer_model.encoder.layer.2.output.dense.bias torch.Size([1024])
# 49 transformer_model.encoder.layer.2.output.LayerNorm.weight torch.Size([1024])
# 50 transformer_model.encoder.layer.2.output.LayerNorm.bias torch.Size([1024])
# 51 transformer_model.encoder.layer.3.attention.self.q_bias torch.Size([1024])
# 52 transformer_model.encoder.layer.3.attention.self.v_bias torch.Size([1024])
# 53 transformer_model.encoder.layer.3.attention.self.in_proj.weight torch.Size([3072, 1024])
# 54 transformer_model.encoder.layer.3.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 55 transformer_model.encoder.layer.3.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 56 transformer_model.encoder.layer.3.attention.self.pos_q_proj.bias torch.Size([1024])
# 57 transformer_model.encoder.layer.3.attention.output.dense.weight torch.Size([1024, 1024])
# 58 transformer_model.encoder.layer.3.attention.output.dense.bias torch.Size([1024])
# 59 transformer_model.encoder.layer.3.attention.output.LayerNorm.weight torch.Size([1024])
# 60 transformer_model.encoder.layer.3.attention.output.LayerNorm.bias torch.Size([1024])
# 61 transformer_model.encoder.layer.3.intermediate.dense.weight torch.Size([4096, 1024])
# 62 transformer_model.encoder.layer.3.intermediate.dense.bias torch.Size([4096])
# 63 transformer_model.encoder.layer.3.output.dense.weight torch.Size([1024, 4096])
# 64 transformer_model.encoder.layer.3.output.dense.bias torch.Size([1024])
# 65 transformer_model.encoder.layer.3.output.LayerNorm.weight torch.Size([1024])
# 66 transformer_model.encoder.layer.3.output.LayerNorm.bias torch.Size([1024])
# 67 transformer_model.encoder.layer.4.attention.self.q_bias torch.Size([1024])
# 68 transformer_model.encoder.layer.4.attention.self.v_bias torch.Size([1024])
# 69 transformer_model.encoder.layer.4.attention.self.in_proj.weight torch.Size([3072, 1024])
# 70 transformer_model.encoder.layer.4.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 71 transformer_model.encoder.layer.4.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 72 transformer_model.encoder.layer.4.attention.self.pos_q_proj.bias torch.Size([1024])
# 73 transformer_model.encoder.layer.4.attention.output.dense.weight torch.Size([1024, 1024])
# 74 transformer_model.encoder.layer.4.attention.output.dense.bias torch.Size([1024])
# 75 transformer_model.encoder.layer.4.attention.output.LayerNorm.weight torch.Size([1024])
# 76 transformer_model.encoder.layer.4.attention.output.LayerNorm.bias torch.Size([1024])
# 77 transformer_model.encoder.layer.4.intermediate.dense.weight torch.Size([4096, 1024])
# 78 transformer_model.encoder.layer.4.intermediate.dense.bias torch.Size([4096])
# 79 transformer_model.encoder.layer.4.output.dense.weight torch.Size([1024, 4096])
# 80 transformer_model.encoder.layer.4.output.dense.bias torch.Size([1024])
# 81 transformer_model.encoder.layer.4.output.LayerNorm.weight torch.Size([1024])
# 82 transformer_model.encoder.layer.4.output.LayerNorm.bias torch.Size([1024])
# 83 transformer_model.encoder.layer.5.attention.self.q_bias torch.Size([1024])
# 84 transformer_model.encoder.layer.5.attention.self.v_bias torch.Size([1024])
# 85 transformer_model.encoder.layer.5.attention.self.in_proj.weight torch.Size([3072, 1024])
# 86 transformer_model.encoder.layer.5.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 87 transformer_model.encoder.layer.5.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 88 transformer_model.encoder.layer.5.attention.self.pos_q_proj.bias torch.Size([1024])
# 89 transformer_model.encoder.layer.5.attention.output.dense.weight torch.Size([1024, 1024])
# 90 transformer_model.encoder.layer.5.attention.output.dense.bias torch.Size([1024])
# 91 transformer_model.encoder.layer.5.attention.output.LayerNorm.weight torch.Size([1024])
# 92 transformer_model.encoder.layer.5.attention.output.LayerNorm.bias torch.Size([1024])
# 93 transformer_model.encoder.layer.5.intermediate.dense.weight torch.Size([4096, 1024])
# 94 transformer_model.encoder.layer.5.intermediate.dense.bias torch.Size([4096])
# 95 transformer_model.encoder.layer.5.output.dense.weight torch.Size([1024, 4096])
# 96 transformer_model.encoder.layer.5.output.dense.bias torch.Size([1024])
# 97 transformer_model.encoder.layer.5.output.LayerNorm.weight torch.Size([1024])
# 98 transformer_model.encoder.layer.5.output.LayerNorm.bias torch.Size([1024])
# 99 transformer_model.encoder.layer.6.attention.self.q_bias torch.Size([1024])
# 100 transformer_model.encoder.layer.6.attention.self.v_bias torch.Size([1024])
# 101 transformer_model.encoder.layer.6.attention.self.in_proj.weight torch.Size([3072, 1024])
# 102 transformer_model.encoder.layer.6.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 103 transformer_model.encoder.layer.6.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 104 transformer_model.encoder.layer.6.attention.self.pos_q_proj.bias torch.Size([1024])
# 105 transformer_model.encoder.layer.6.attention.output.dense.weight torch.Size([1024, 1024])
# 106 transformer_model.encoder.layer.6.attention.output.dense.bias torch.Size([1024])
# 107 transformer_model.encoder.layer.6.attention.output.LayerNorm.weight torch.Size([1024])
# 108 transformer_model.encoder.layer.6.attention.output.LayerNorm.bias torch.Size([1024])
# 109 transformer_model.encoder.layer.6.intermediate.dense.weight torch.Size([4096, 1024])
# 110 transformer_model.encoder.layer.6.intermediate.dense.bias torch.Size([4096])
# 111 transformer_model.encoder.layer.6.output.dense.weight torch.Size([1024, 4096])
# 112 transformer_model.encoder.layer.6.output.dense.bias torch.Size([1024])
# 113 transformer_model.encoder.layer.6.output.LayerNorm.weight torch.Size([1024])
# 114 transformer_model.encoder.layer.6.output.LayerNorm.bias torch.Size([1024])
# 115 transformer_model.encoder.layer.7.attention.self.q_bias torch.Size([1024])
# 116 transformer_model.encoder.layer.7.attention.self.v_bias torch.Size([1024])
# 117 transformer_model.encoder.layer.7.attention.self.in_proj.weight torch.Size([3072, 1024])
# 118 transformer_model.encoder.layer.7.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 119 transformer_model.encoder.layer.7.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 120 transformer_model.encoder.layer.7.attention.self.pos_q_proj.bias torch.Size([1024])
# 121 transformer_model.encoder.layer.7.attention.output.dense.weight torch.Size([1024, 1024])
# 122 transformer_model.encoder.layer.7.attention.output.dense.bias torch.Size([1024])
# 123 transformer_model.encoder.layer.7.attention.output.LayerNorm.weight torch.Size([1024])
# 124 transformer_model.encoder.layer.7.attention.output.LayerNorm.bias torch.Size([1024])
# 125 transformer_model.encoder.layer.7.intermediate.dense.weight torch.Size([4096, 1024])
# 126 transformer_model.encoder.layer.7.intermediate.dense.bias torch.Size([4096])
# 127 transformer_model.encoder.layer.7.output.dense.weight torch.Size([1024, 4096])
# 128 transformer_model.encoder.layer.7.output.dense.bias torch.Size([1024])
# 129 transformer_model.encoder.layer.7.output.LayerNorm.weight torch.Size([1024])
# 130 transformer_model.encoder.layer.7.output.LayerNorm.bias torch.Size([1024])
# 131 transformer_model.encoder.layer.8.attention.self.q_bias torch.Size([1024])
# 132 transformer_model.encoder.layer.8.attention.self.v_bias torch.Size([1024])
# 133 transformer_model.encoder.layer.8.attention.self.in_proj.weight torch.Size([3072, 1024])
# 134 transformer_model.encoder.layer.8.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 135 transformer_model.encoder.layer.8.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 136 transformer_model.encoder.layer.8.attention.self.pos_q_proj.bias torch.Size([1024])
# 137 transformer_model.encoder.layer.8.attention.output.dense.weight torch.Size([1024, 1024])
# 138 transformer_model.encoder.layer.8.attention.output.dense.bias torch.Size([1024])
# 139 transformer_model.encoder.layer.8.attention.output.LayerNorm.weight torch.Size([1024])
# 140 transformer_model.encoder.layer.8.attention.output.LayerNorm.bias torch.Size([1024])
# 141 transformer_model.encoder.layer.8.intermediate.dense.weight torch.Size([4096, 1024])
# 142 transformer_model.encoder.layer.8.intermediate.dense.bias torch.Size([4096])
# 143 transformer_model.encoder.layer.8.output.dense.weight torch.Size([1024, 4096])
# 144 transformer_model.encoder.layer.8.output.dense.bias torch.Size([1024])
# 145 transformer_model.encoder.layer.8.output.LayerNorm.weight torch.Size([1024])
# 146 transformer_model.encoder.layer.8.output.LayerNorm.bias torch.Size([1024])
# 147 transformer_model.encoder.layer.9.attention.self.q_bias torch.Size([1024])
# 148 transformer_model.encoder.layer.9.attention.self.v_bias torch.Size([1024])
# 149 transformer_model.encoder.layer.9.attention.self.in_proj.weight torch.Size([3072, 1024])
# 150 transformer_model.encoder.layer.9.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 151 transformer_model.encoder.layer.9.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 152 transformer_model.encoder.layer.9.attention.self.pos_q_proj.bias torch.Size([1024])
# 153 transformer_model.encoder.layer.9.attention.output.dense.weight torch.Size([1024, 1024])
# 154 transformer_model.encoder.layer.9.attention.output.dense.bias torch.Size([1024])
# 155 transformer_model.encoder.layer.9.attention.output.LayerNorm.weight torch.Size([1024])
# 156 transformer_model.encoder.layer.9.attention.output.LayerNorm.bias torch.Size([1024])
# 157 transformer_model.encoder.layer.9.intermediate.dense.weight torch.Size([4096, 1024])
# 158 transformer_model.encoder.layer.9.intermediate.dense.bias torch.Size([4096])
# 159 transformer_model.encoder.layer.9.output.dense.weight torch.Size([1024, 4096])
# 160 transformer_model.encoder.layer.9.output.dense.bias torch.Size([1024])
# 161 transformer_model.encoder.layer.9.output.LayerNorm.weight torch.Size([1024])
# 162 transformer_model.encoder.layer.9.output.LayerNorm.bias torch.Size([1024])
# 163 transformer_model.encoder.layer.10.attention.self.q_bias torch.Size([1024])
# 164 transformer_model.encoder.layer.10.attention.self.v_bias torch.Size([1024])
# 165 transformer_model.encoder.layer.10.attention.self.in_proj.weight torch.Size([3072, 1024])
# 166 transformer_model.encoder.layer.10.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 167 transformer_model.encoder.layer.10.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 168 transformer_model.encoder.layer.10.attention.self.pos_q_proj.bias torch.Size([1024])
# 169 transformer_model.encoder.layer.10.attention.output.dense.weight torch.Size([1024, 1024])
# 170 transformer_model.encoder.layer.10.attention.output.dense.bias torch.Size([1024])
# 171 transformer_model.encoder.layer.10.attention.output.LayerNorm.weight torch.Size([1024])
# 172 transformer_model.encoder.layer.10.attention.output.LayerNorm.bias torch.Size([1024])
# 173 transformer_model.encoder.layer.10.intermediate.dense.weight torch.Size([4096, 1024])
# 174 transformer_model.encoder.layer.10.intermediate.dense.bias torch.Size([4096])
# 175 transformer_model.encoder.layer.10.output.dense.weight torch.Size([1024, 4096])
# 176 transformer_model.encoder.layer.10.output.dense.bias torch.Size([1024])
# 177 transformer_model.encoder.layer.10.output.LayerNorm.weight torch.Size([1024])
# 178 transformer_model.encoder.layer.10.output.LayerNorm.bias torch.Size([1024])
# 179 transformer_model.encoder.layer.11.attention.self.q_bias torch.Size([1024])
# 180 transformer_model.encoder.layer.11.attention.self.v_bias torch.Size([1024])
# 181 transformer_model.encoder.layer.11.attention.self.in_proj.weight torch.Size([3072, 1024])
# 182 transformer_model.encoder.layer.11.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 183 transformer_model.encoder.layer.11.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 184 transformer_model.encoder.layer.11.attention.self.pos_q_proj.bias torch.Size([1024])
# 185 transformer_model.encoder.layer.11.attention.output.dense.weight torch.Size([1024, 1024])
# 186 transformer_model.encoder.layer.11.attention.output.dense.bias torch.Size([1024])
# 187 transformer_model.encoder.layer.11.attention.output.LayerNorm.weight torch.Size([1024])
# 188 transformer_model.encoder.layer.11.attention.output.LayerNorm.bias torch.Size([1024])
# 189 transformer_model.encoder.layer.11.intermediate.dense.weight torch.Size([4096, 1024])
# 190 transformer_model.encoder.layer.11.intermediate.dense.bias torch.Size([4096])
# 191 transformer_model.encoder.layer.11.output.dense.weight torch.Size([1024, 4096])
# 192 transformer_model.encoder.layer.11.output.dense.bias torch.Size([1024])
# 193 transformer_model.encoder.layer.11.output.LayerNorm.weight torch.Size([1024])
# 194 transformer_model.encoder.layer.11.output.LayerNorm.bias torch.Size([1024])
# 195 transformer_model.encoder.layer.12.attention.self.q_bias torch.Size([1024])
# 196 transformer_model.encoder.layer.12.attention.self.v_bias torch.Size([1024])
# 197 transformer_model.encoder.layer.12.attention.self.in_proj.weight torch.Size([3072, 1024])
# 198 transformer_model.encoder.layer.12.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 199 transformer_model.encoder.layer.12.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 200 transformer_model.encoder.layer.12.attention.self.pos_q_proj.bias torch.Size([1024])
# 201 transformer_model.encoder.layer.12.attention.output.dense.weight torch.Size([1024, 1024])
# 202 transformer_model.encoder.layer.12.attention.output.dense.bias torch.Size([1024])
# 203 transformer_model.encoder.layer.12.attention.output.LayerNorm.weight torch.Size([1024])
# 204 transformer_model.encoder.layer.12.attention.output.LayerNorm.bias torch.Size([1024])
# 205 transformer_model.encoder.layer.12.intermediate.dense.weight torch.Size([4096, 1024])
# 206 transformer_model.encoder.layer.12.intermediate.dense.bias torch.Size([4096])
# 207 transformer_model.encoder.layer.12.output.dense.weight torch.Size([1024, 4096])
# 208 transformer_model.encoder.layer.12.output.dense.bias torch.Size([1024])
# 209 transformer_model.encoder.layer.12.output.LayerNorm.weight torch.Size([1024])
# 210 transformer_model.encoder.layer.12.output.LayerNorm.bias torch.Size([1024])
# 211 transformer_model.encoder.layer.13.attention.self.q_bias torch.Size([1024])
# 212 transformer_model.encoder.layer.13.attention.self.v_bias torch.Size([1024])
# 213 transformer_model.encoder.layer.13.attention.self.in_proj.weight torch.Size([3072, 1024])
# 214 transformer_model.encoder.layer.13.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 215 transformer_model.encoder.layer.13.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 216 transformer_model.encoder.layer.13.attention.self.pos_q_proj.bias torch.Size([1024])
# 217 transformer_model.encoder.layer.13.attention.output.dense.weight torch.Size([1024, 1024])
# 218 transformer_model.encoder.layer.13.attention.output.dense.bias torch.Size([1024])
# 219 transformer_model.encoder.layer.13.attention.output.LayerNorm.weight torch.Size([1024])
# 220 transformer_model.encoder.layer.13.attention.output.LayerNorm.bias torch.Size([1024])
# 221 transformer_model.encoder.layer.13.intermediate.dense.weight torch.Size([4096, 1024])
# 222 transformer_model.encoder.layer.13.intermediate.dense.bias torch.Size([4096])
# 223 transformer_model.encoder.layer.13.output.dense.weight torch.Size([1024, 4096])
# 224 transformer_model.encoder.layer.13.output.dense.bias torch.Size([1024])
# 225 transformer_model.encoder.layer.13.output.LayerNorm.weight torch.Size([1024])
# 226 transformer_model.encoder.layer.13.output.LayerNorm.bias torch.Size([1024])
# 227 transformer_model.encoder.layer.14.attention.self.q_bias torch.Size([1024])
# 228 transformer_model.encoder.layer.14.attention.self.v_bias torch.Size([1024])
# 229 transformer_model.encoder.layer.14.attention.self.in_proj.weight torch.Size([3072, 1024])
# 230 transformer_model.encoder.layer.14.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 231 transformer_model.encoder.layer.14.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 232 transformer_model.encoder.layer.14.attention.self.pos_q_proj.bias torch.Size([1024])
# 233 transformer_model.encoder.layer.14.attention.output.dense.weight torch.Size([1024, 1024])
# 234 transformer_model.encoder.layer.14.attention.output.dense.bias torch.Size([1024])
# 235 transformer_model.encoder.layer.14.attention.output.LayerNorm.weight torch.Size([1024])
# 236 transformer_model.encoder.layer.14.attention.output.LayerNorm.bias torch.Size([1024])
# 237 transformer_model.encoder.layer.14.intermediate.dense.weight torch.Size([4096, 1024])
# 238 transformer_model.encoder.layer.14.intermediate.dense.bias torch.Size([4096])
# 239 transformer_model.encoder.layer.14.output.dense.weight torch.Size([1024, 4096])
# 240 transformer_model.encoder.layer.14.output.dense.bias torch.Size([1024])
# 241 transformer_model.encoder.layer.14.output.LayerNorm.weight torch.Size([1024])
# 242 transformer_model.encoder.layer.14.output.LayerNorm.bias torch.Size([1024])
# 243 transformer_model.encoder.layer.15.attention.self.q_bias torch.Size([1024])
# 244 transformer_model.encoder.layer.15.attention.self.v_bias torch.Size([1024])
# 245 transformer_model.encoder.layer.15.attention.self.in_proj.weight torch.Size([3072, 1024])
# 246 transformer_model.encoder.layer.15.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 247 transformer_model.encoder.layer.15.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 248 transformer_model.encoder.layer.15.attention.self.pos_q_proj.bias torch.Size([1024])
# 249 transformer_model.encoder.layer.15.attention.output.dense.weight torch.Size([1024, 1024])
# 250 transformer_model.encoder.layer.15.attention.output.dense.bias torch.Size([1024])
# 251 transformer_model.encoder.layer.15.attention.output.LayerNorm.weight torch.Size([1024])
# 252 transformer_model.encoder.layer.15.attention.output.LayerNorm.bias torch.Size([1024])
# 253 transformer_model.encoder.layer.15.intermediate.dense.weight torch.Size([4096, 1024])
# 254 transformer_model.encoder.layer.15.intermediate.dense.bias torch.Size([4096])
# 255 transformer_model.encoder.layer.15.output.dense.weight torch.Size([1024, 4096])
# 256 transformer_model.encoder.layer.15.output.dense.bias torch.Size([1024])
# 257 transformer_model.encoder.layer.15.output.LayerNorm.weight torch.Size([1024])
# 258 transformer_model.encoder.layer.15.output.LayerNorm.bias torch.Size([1024])
# 259 transformer_model.encoder.layer.16.attention.self.q_bias torch.Size([1024])
# 260 transformer_model.encoder.layer.16.attention.self.v_bias torch.Size([1024])
# 261 transformer_model.encoder.layer.16.attention.self.in_proj.weight torch.Size([3072, 1024])
# 262 transformer_model.encoder.layer.16.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 263 transformer_model.encoder.layer.16.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 264 transformer_model.encoder.layer.16.attention.self.pos_q_proj.bias torch.Size([1024])
# 265 transformer_model.encoder.layer.16.attention.output.dense.weight torch.Size([1024, 1024])
# 266 transformer_model.encoder.layer.16.attention.output.dense.bias torch.Size([1024])
# 267 transformer_model.encoder.layer.16.attention.output.LayerNorm.weight torch.Size([1024])
# 268 transformer_model.encoder.layer.16.attention.output.LayerNorm.bias torch.Size([1024])
# 269 transformer_model.encoder.layer.16.intermediate.dense.weight torch.Size([4096, 1024])
# 270 transformer_model.encoder.layer.16.intermediate.dense.bias torch.Size([4096])
# 271 transformer_model.encoder.layer.16.output.dense.weight torch.Size([1024, 4096])
# 272 transformer_model.encoder.layer.16.output.dense.bias torch.Size([1024])
# 273 transformer_model.encoder.layer.16.output.LayerNorm.weight torch.Size([1024])
# 274 transformer_model.encoder.layer.16.output.LayerNorm.bias torch.Size([1024])
# 275 transformer_model.encoder.layer.17.attention.self.q_bias torch.Size([1024])
# 276 transformer_model.encoder.layer.17.attention.self.v_bias torch.Size([1024])
# 277 transformer_model.encoder.layer.17.attention.self.in_proj.weight torch.Size([3072, 1024])
# 278 transformer_model.encoder.layer.17.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 279 transformer_model.encoder.layer.17.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 280 transformer_model.encoder.layer.17.attention.self.pos_q_proj.bias torch.Size([1024])
# 281 transformer_model.encoder.layer.17.attention.output.dense.weight torch.Size([1024, 1024])
# 282 transformer_model.encoder.layer.17.attention.output.dense.bias torch.Size([1024])
# 283 transformer_model.encoder.layer.17.attention.output.LayerNorm.weight torch.Size([1024])
# 284 transformer_model.encoder.layer.17.attention.output.LayerNorm.bias torch.Size([1024])
# 285 transformer_model.encoder.layer.17.intermediate.dense.weight torch.Size([4096, 1024])
# 286 transformer_model.encoder.layer.17.intermediate.dense.bias torch.Size([4096])
# 287 transformer_model.encoder.layer.17.output.dense.weight torch.Size([1024, 4096])
# 288 transformer_model.encoder.layer.17.output.dense.bias torch.Size([1024])
# 289 transformer_model.encoder.layer.17.output.LayerNorm.weight torch.Size([1024])
# 290 transformer_model.encoder.layer.17.output.LayerNorm.bias torch.Size([1024])
# 291 transformer_model.encoder.layer.18.attention.self.q_bias torch.Size([1024])
# 292 transformer_model.encoder.layer.18.attention.self.v_bias torch.Size([1024])
# 293 transformer_model.encoder.layer.18.attention.self.in_proj.weight torch.Size([3072, 1024])
# 294 transformer_model.encoder.layer.18.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 295 transformer_model.encoder.layer.18.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 296 transformer_model.encoder.layer.18.attention.self.pos_q_proj.bias torch.Size([1024])
# 297 transformer_model.encoder.layer.18.attention.output.dense.weight torch.Size([1024, 1024])
# 298 transformer_model.encoder.layer.18.attention.output.dense.bias torch.Size([1024])
# 299 transformer_model.encoder.layer.18.attention.output.LayerNorm.weight torch.Size([1024])
# 300 transformer_model.encoder.layer.18.attention.output.LayerNorm.bias torch.Size([1024])
# 301 transformer_model.encoder.layer.18.intermediate.dense.weight torch.Size([4096, 1024])
# 302 transformer_model.encoder.layer.18.intermediate.dense.bias torch.Size([4096])
# 303 transformer_model.encoder.layer.18.output.dense.weight torch.Size([1024, 4096])
# 304 transformer_model.encoder.layer.18.output.dense.bias torch.Size([1024])
# 305 transformer_model.encoder.layer.18.output.LayerNorm.weight torch.Size([1024])
# 306 transformer_model.encoder.layer.18.output.LayerNorm.bias torch.Size([1024])
# 307 transformer_model.encoder.layer.19.attention.self.q_bias torch.Size([1024])
# 308 transformer_model.encoder.layer.19.attention.self.v_bias torch.Size([1024])
# 309 transformer_model.encoder.layer.19.attention.self.in_proj.weight torch.Size([3072, 1024])
# 310 transformer_model.encoder.layer.19.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 311 transformer_model.encoder.layer.19.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 312 transformer_model.encoder.layer.19.attention.self.pos_q_proj.bias torch.Size([1024])
# 313 transformer_model.encoder.layer.19.attention.output.dense.weight torch.Size([1024, 1024])
# 314 transformer_model.encoder.layer.19.attention.output.dense.bias torch.Size([1024])
# 315 transformer_model.encoder.layer.19.attention.output.LayerNorm.weight torch.Size([1024])
# 316 transformer_model.encoder.layer.19.attention.output.LayerNorm.bias torch.Size([1024])
# 317 transformer_model.encoder.layer.19.intermediate.dense.weight torch.Size([4096, 1024])
# 318 transformer_model.encoder.layer.19.intermediate.dense.bias torch.Size([4096])
# 319 transformer_model.encoder.layer.19.output.dense.weight torch.Size([1024, 4096])
# 320 transformer_model.encoder.layer.19.output.dense.bias torch.Size([1024])
# 321 transformer_model.encoder.layer.19.output.LayerNorm.weight torch.Size([1024])
# 322 transformer_model.encoder.layer.19.output.LayerNorm.bias torch.Size([1024])
# 323 transformer_model.encoder.layer.20.attention.self.q_bias torch.Size([1024])
# 324 transformer_model.encoder.layer.20.attention.self.v_bias torch.Size([1024])
# 325 transformer_model.encoder.layer.20.attention.self.in_proj.weight torch.Size([3072, 1024])
# 326 transformer_model.encoder.layer.20.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 327 transformer_model.encoder.layer.20.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 328 transformer_model.encoder.layer.20.attention.self.pos_q_proj.bias torch.Size([1024])
# 329 transformer_model.encoder.layer.20.attention.output.dense.weight torch.Size([1024, 1024])
# 330 transformer_model.encoder.layer.20.attention.output.dense.bias torch.Size([1024])
# 331 transformer_model.encoder.layer.20.attention.output.LayerNorm.weight torch.Size([1024])
# 332 transformer_model.encoder.layer.20.attention.output.LayerNorm.bias torch.Size([1024])
# 333 transformer_model.encoder.layer.20.intermediate.dense.weight torch.Size([4096, 1024])
# 334 transformer_model.encoder.layer.20.intermediate.dense.bias torch.Size([4096])
# 335 transformer_model.encoder.layer.20.output.dense.weight torch.Size([1024, 4096])
# 336 transformer_model.encoder.layer.20.output.dense.bias torch.Size([1024])
# 337 transformer_model.encoder.layer.20.output.LayerNorm.weight torch.Size([1024])
# 338 transformer_model.encoder.layer.20.output.LayerNorm.bias torch.Size([1024])
# 339 transformer_model.encoder.layer.21.attention.self.q_bias torch.Size([1024])
# 340 transformer_model.encoder.layer.21.attention.self.v_bias torch.Size([1024])
# 341 transformer_model.encoder.layer.21.attention.self.in_proj.weight torch.Size([3072, 1024])
# 342 transformer_model.encoder.layer.21.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 343 transformer_model.encoder.layer.21.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 344 transformer_model.encoder.layer.21.attention.self.pos_q_proj.bias torch.Size([1024])
# 345 transformer_model.encoder.layer.21.attention.output.dense.weight torch.Size([1024, 1024])
# 346 transformer_model.encoder.layer.21.attention.output.dense.bias torch.Size([1024])
# 347 transformer_model.encoder.layer.21.attention.output.LayerNorm.weight torch.Size([1024])
# 348 transformer_model.encoder.layer.21.attention.output.LayerNorm.bias torch.Size([1024])
# 349 transformer_model.encoder.layer.21.intermediate.dense.weight torch.Size([4096, 1024])
# 350 transformer_model.encoder.layer.21.intermediate.dense.bias torch.Size([4096])
# 351 transformer_model.encoder.layer.21.output.dense.weight torch.Size([1024, 4096])
# 352 transformer_model.encoder.layer.21.output.dense.bias torch.Size([1024])
# 353 transformer_model.encoder.layer.21.output.LayerNorm.weight torch.Size([1024])
# 354 transformer_model.encoder.layer.21.output.LayerNorm.bias torch.Size([1024])
# 355 transformer_model.encoder.layer.22.attention.self.q_bias torch.Size([1024])
# 356 transformer_model.encoder.layer.22.attention.self.v_bias torch.Size([1024])
# 357 transformer_model.encoder.layer.22.attention.self.in_proj.weight torch.Size([3072, 1024])
# 358 transformer_model.encoder.layer.22.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 359 transformer_model.encoder.layer.22.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 360 transformer_model.encoder.layer.22.attention.self.pos_q_proj.bias torch.Size([1024])
# 361 transformer_model.encoder.layer.22.attention.output.dense.weight torch.Size([1024, 1024])
# 362 transformer_model.encoder.layer.22.attention.output.dense.bias torch.Size([1024])
# 363 transformer_model.encoder.layer.22.attention.output.LayerNorm.weight torch.Size([1024])
# 364 transformer_model.encoder.layer.22.attention.output.LayerNorm.bias torch.Size([1024])
# 365 transformer_model.encoder.layer.22.intermediate.dense.weight torch.Size([4096, 1024])
# 366 transformer_model.encoder.layer.22.intermediate.dense.bias torch.Size([4096])
# 367 transformer_model.encoder.layer.22.output.dense.weight torch.Size([1024, 4096])
# 368 transformer_model.encoder.layer.22.output.dense.bias torch.Size([1024])
# 369 transformer_model.encoder.layer.22.output.LayerNorm.weight torch.Size([1024])
# 370 transformer_model.encoder.layer.22.output.LayerNorm.bias torch.Size([1024])
# 371 transformer_model.encoder.layer.23.attention.self.q_bias torch.Size([1024])
# 372 transformer_model.encoder.layer.23.attention.self.v_bias torch.Size([1024])
# 373 transformer_model.encoder.layer.23.attention.self.in_proj.weight torch.Size([3072, 1024])
# 374 transformer_model.encoder.layer.23.attention.self.pos_proj.weight torch.Size([1024, 1024])
# 375 transformer_model.encoder.layer.23.attention.self.pos_q_proj.weight torch.Size([1024, 1024])
# 376 transformer_model.encoder.layer.23.attention.self.pos_q_proj.bias torch.Size([1024])
# 377 transformer_model.encoder.layer.23.attention.output.dense.weight torch.Size([1024, 1024])
# 378 transformer_model.encoder.layer.23.attention.output.dense.bias torch.Size([1024])
# 379 transformer_model.encoder.layer.23.attention.output.LayerNorm.weight torch.Size([1024])
# 380 transformer_model.encoder.layer.23.attention.output.LayerNorm.bias torch.Size([1024])
# 381 transformer_model.encoder.layer.23.intermediate.dense.weight torch.Size([4096, 1024])
# 382 transformer_model.encoder.layer.23.intermediate.dense.bias torch.Size([4096])
# 383 transformer_model.encoder.layer.23.output.dense.weight torch.Size([1024, 4096])
# 384 transformer_model.encoder.layer.23.output.dense.bias torch.Size([1024])
# 385 transformer_model.encoder.layer.23.output.LayerNorm.weight torch.Size([1024])
# 386 transformer_model.encoder.layer.23.output.LayerNorm.bias torch.Size([1024])
# 387 transformer_model.encoder.rel_embeddings.weight torch.Size([1024, 1024])
# 388 attention.hidden_layer.weight torch.Size([512, 1024])
# 389 attention.hidden_layer.bias torch.Size([512])
# 390 attention.final_layer.weight torch.Size([1, 512])
# 391 attention.final_layer.bias torch.Size([1])
# 392 regressor.weight torch.Size([1, 1024])
# 393 regressor.bias torch.Size([1])

# %%
sample_input_ids = torch.randint(0, 1000, [8, 248])
sample_attention_mask = torch.randint(0, 1000, [8, 248])

# %%
sample_model(sample_input_ids, sample_attention_mask)[1].shape
# Out:
# torch.Size([8, 1024])

# %%
torch.sum(torch.randn([8, 496, 768]), axis=1)
# Out:
# tensor([[-66.3821, -27.3573,  -6.9502,  ...,  39.6213,  -5.2377,  -3.7676],
#         [ -7.1081, -36.6958,   5.8008,  ..., -30.5648,  22.2596,  -3.3595],
#         [ 12.2165,   3.7359,  15.0221,  ...,  -8.2136,  19.6684, -25.9756],
#         ...,
#         [-11.7559,  12.8772, -26.9206,  ...,  14.0972,   9.2270, -15.3310],
#         [-13.1260,   9.6047,  20.1348,  ...,  -2.2969,  24.7611,  21.0514],
#         [ -7.2901,  11.9209, -15.8353,  ..., -52.5437, -13.7529,  22.7274]])

# %% [markdown]
# ### Evaluation and Prediction

# %%
def eval_mse(model, data_loader):
    model.eval()
    mse_sum = 0
    mse_loss = nn.MSELoss(reduction='sum')
    
    with torch.no_grad():
        for batch_num, record in enumerate(data_loader):
            input_ids, attention_mask, target = record['input_ids'].to(cfg.DEVICE), record['attention_mask'].to(cfg.DEVICE), record['target'].to(cfg.DEVICE)
            pred, _ = model(input_ids, attention_mask)
            mse_sum += mse_loss(pred.flatten().cpu(), target.cpu())
            
    return mse_sum / len(data_loader.dataset)

# %%
def predict(model, data_loader):
    model.eval()
    result = []
    
    with torch.no_grad():
        for batch_num, record in tqdm(enumerate(data_loader), total=len(data_loader)):
            input_ids, attention_mask = record['input_ids'].to(cfg.DEVICE), record['attention_mask'].to(cfg.DEVICE)
            pred, _ = model(input_ids, attention_mask)
            result.extend(pred.flatten().to("cpu").tolist())
            
    return np.array(result)

# %%
sample_dl = DataLoader(sample_ds, shuffle=False, batch_size=16, num_workers=1)

# %% [markdown]
# ### Optimizer and Sampler

# %%
def create_optimizer(model, base_lr=5e-5, last_lr=None):
    named_parameters = list(model.named_parameters())
    
    regressor_param_start = 395
    roberta_parameters = named_parameters[:389]
    attention_parameters = named_parameters[391:regressor_param_start]
    regressor_parameters = named_parameters[regressor_param_start:]
    
    attention_group = [params for (name, params) in attention_parameters]
    regressor_group = [params for (name, params) in regressor_parameters]
    
    parameters = []
    if last_lr is not None:
        parameters.append({"params": attention_group, "lr": last_lr})
        parameters.append({"params": regressor_group, "lr": last_lr})
    else:
        parameters.append({"params": attention_group})
        parameters.append({"params": regressor_group})
    
    for layer_num, (name, params) in enumerate(roberta_parameters):
        weight_decay = 0.0 if 'bias' in name else 0.01
        
        lr = base_lr / 2.5 # 2e-05
        if layer_num >= 260:
            lr = base_lr / 0.5 # 1e-4
        elif layer_num >= 132:        
            lr = base_lr    
            
        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})
        
    return AdamW(parameters)

# %%
sample_optimizer = create_optimizer(sample_model)

# %%
from torch.utils.data import Sampler,SequentialSampler,RandomSampler,SubsetRandomSampler
from collections import Counter

class WeightedSampler(Sampler):
    
    def __init__(self, dataset):
        
        len_dataset = len(dataset)
        self.indices = list(range(len_dataset))
        self.num_samples = len_dataset
        self.label_to_count = dict(Counter(dataset.bins))
        weights = [1/self.label_to_count[i] for i in dataset.bins]
        
        self.weights = torch.tensor(weights,dtype=torch.double)
        
    def __iter__(self):
        count = 0
        index = [self.indices[i] for i in torch.multinomial(self.weights, self.num_samples, replacement=True)]
        while count < self.num_samples:
            yield index[count]
            count += 1
    
    def __len__(self):
        return self.num_samples

# %%
indices = list(range(len(sample_ds)))
num_samples = len(sample_ds)
label_to_count = dict(Counter(sample_ds.bins))

# %%
label_to_count
# Out:
# {3: 886, 2: 784, 4: 495, 0: 122, 1: 441, 5: 106}

# %%
weights = [1/label_to_count[i] for i in sample_ds.bins]
sum(weights)
# Out:
# 6.000000000000067

# %%
sns.distplot(torch.multinomial(torch.tensor(weights), num_samples, replacement=True))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
train_df_copy = train_df.copy()

# %%
train_df_copy.sort_values(['target']).reset_index(inplace=True)

# %%
np.random.choice(np.arange(len(train_df_copy)), len(train_df_copy))
# Out:
# array([1600, 1254, 2412, ...,  416,  423, 1965])

# %% [markdown]
# ### Training

# %%
def choose_eval_period(val_rmse):
    for rmse, period in cfg.EVAL_SCHEDULE:
        if val_rmse >= rmse:
            return period

# %%
def serialize_best(best_val_rmse, best_epoch, val_rmse, epoch, model, model_path):
    if not best_val_rmse or val_rmse < best_val_rmse:
        best_val_rmse = val_rmse
        best_epoch = epoch
        if not model_path.parent.exists():
            os.makedirs(model_path.parent)
        
        torch.save(model.state_dict(), model_path)
        print(f"New best_val_rmse: {best_val_rmse:0.4}")
    else:       
        print(f"Still best_val_rmse: {best_val_rmse:0.4}",
              f"(from epoch {best_epoch})")
    return best_epoch, best_val_rmse

# %%
class Trainer():
    def __init__(self, scaler, model, model_path, train_loader, val_loader, optimizer, scheduler=None, num_epochs=cfg.NUM_EPOCHS):
        self.scaler, self.model, self.model_path, self.train_loader, self.val_loader, self.optimizer, self.scheduler, self.num_epochs = (
            scaler, model, model_path, train_loader, val_loader, optimizer, scheduler, num_epochs
        )
            
    def train(self):
        self.model.train()
        
        mse_loss = nn.MSELoss(reduction='mean')
        
        best_val_rmse = None
        best_epoch = 0
        step = 0
        last_eval_step = 0
        eval_period = cfg.EVAL_SCHEDULE[0][1]    

        start = time.time()
        
        tbar = tqdm(range(self.num_epochs), total=self.num_epochs)
        for epoch in tbar:
            tbar.set_description(f'Epoch: {epoch}')
            val_rmse = None
            for batch_num, record in enumerate(self.train_loader):
                input_ids, attention_mask, target = record['input_ids'].to(cfg.DEVICE), record['attention_mask'].to(cfg.DEVICE), record['target'].to(cfg.DEVICE)
                
                self.optimizer.zero_grad()
                
                # Casts operations to mixed precision
                with torch.cuda.amp.autocast():
                    pred, _ = self.model(input_ids, attention_mask)
                    mse = mse_loss(pred.flatten(), target)
                    
                self.scaler.scale(mse).backward()
                self.scaler.step(self.optimizer)
                self.scaler.update()
                
                if self.scheduler:
                    self.scheduler.step()
                    
                if step >= last_eval_step + eval_period:
                    elapsed_seconds = time.time() - start
                    num_steps = step - last_eval_step
                    print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                    last_eval_step = step
                    
                    val_rmse = np.sqrt(eval_mse(self.model, self.val_loader))
                    print(f"Epoch: {epoch} batch_num: {batch_num}", f"val_rmse: {val_rmse:0.4} ", end='')
                    
                    eval_period = choose_eval_period(val_rmse)
                    best_epoch, best_val_rmse = serialize_best(best_val_rmse, best_epoch, val_rmse, epoch, self.model, self.model_path)
                    start = time.time()
                # Finish early on condition
                if epoch > 0 and best_val_rmse > 0.6:
                    return best_val_rmse
                
                step += 1
        return best_val_rmse

# %%
kfold = KFold(n_splits=cfg.NUM_FOLDS, random_state=cfg.SEED, shuffle=True)
splits = list(kfold.split(train_df))

# %% [markdown]
# ### Main Training

# %%
def train_fold(base_lr, last_lr, fold = 0):
    
    print(f'##### Using fold {fold}')
    
    model_path = cfg.MODEL_FOLDER/f"{cfg.model_name.replace('/', '_')}_{fold + 1}/model_{fold + 1}.pth"
    
    set_random_seed(cfg.SEED + fold)
    
    tokenizer = AutoTokenizer.from_pretrained(cfg.TOKENIZER_PATH)
    
    train_indices, val_indices = splits[fold]
    train_dataset = CommonLitDataset(train_df.loc[train_indices], tokenizer)    
    val_dataset = CommonLitDataset(train_df.loc[val_indices], tokenizer)
    
    train_loader = DataLoader(train_dataset, batch_size=cfg.BATCH_SIZE, sampler=WeightedSampler(train_dataset),
                              drop_last=False, shuffle=False, num_workers=cfg.NUM_WORKERS)    
    val_loader = DataLoader(val_dataset, batch_size=cfg.BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=cfg.NUM_WORKERS)
    
    set_random_seed(cfg.SEED + fold)
    
    model = CommonLitModel().to(cfg.DEVICE)
    
    optimizer = create_optimizer(model, base_lr=base_lr, last_lr=last_lr)
    
    scheduler = get_cosine_schedule_with_warmup(optimizer,
                                                num_training_steps=cfg.NUM_EPOCHS * len(train_loader), 
                                                num_warmup_steps=50)
    
    scaler = torch.cuda.amp.GradScaler()
    
    trainer = Trainer(scaler, model, model_path, train_loader, val_loader, optimizer, scheduler = scheduler)
    rmse_val = trainer.train()
    tokenizer.save_pretrained(str(model_path.parent))
    
    return rmse_val

# %%
# Best results
# fold 0: {'base_lr': 4.214048623230046e-05, 'last_lr': 0.00098671139242345}. Best is trial 0 with value: 0.46920305490493774.
# fold 1: {'base_lr': 3.4594372607385946e-05, 'last_lr': 0.0005479134338105077}. Best is trial 0 with value: 0.447492390871048
# fold 2: {'base_lr': 1.777623134028703e-05, 'last_lr': 0.004132549020616918}. Best is trial 0 with value: 0.46756473183631897
# fold 3: {'base_lr': 3.933402254716856e-05, 'last_lr': 0.0018473297738188957}. Best is trial 11 with value: 0.4719877541065216
# fold 4: {'base_lr': 1.845975941382356e-05, 'last_lr': 0.0006309278277674714}. Best is trial 15 with value: 0.46920618414878845
# fold 5: {'base_lr': 4.430444436442592e-05, 'last_lr': 0.000289231685619846}. Best is trial 6 with value: 0.4629150927066803

# %%
lr_list = [
    {'base_lr': 4.214048623230046e-05, 'last_lr': 0.00098671139242345},
    {'base_lr': 3.4594372607385946e-05, 'last_lr': 0.0005479134338105077},
    {'base_lr': 1.777623134028703e-05, 'last_lr': 0.004132549020616918},
    {'base_lr': 3.933402254716856e-05, 'last_lr': 0.0018473297738188957},
    {'base_lr': 1.845975941382356e-05, 'last_lr': 0.0006309278277674714},
    {'base_lr': 4.430444436442592e-05, 'last_lr': 0.000289231685619846}
]

# %%
# %%time

rmse_values = []
for i in range(len(list(splits))):
    fold = i
    lrs = lr_list[fold]
    rmse_val = train_fold(lrs['base_lr'], lrs['last_lr'], fold=fold)
    print(f'Final RMSE: {rmse_val}')
    rmse_values.append(rmse_val)
# Out:
# ##### Using fold 0
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaModel: ['config', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# 16 steps took 9.01 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.848 New best_val_rmse: 0.848
#
# 16 steps took 6.66 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.6306 New best_val_rmse: 0.6306
#
# 16 steps took 6.7 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7049 Still best_val_rmse: 0.6306 (from epoch 0)
#
# 16 steps took 6.7 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.5866 New best_val_rmse: 0.5866
#
# 16 steps took 6.73 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.8332 Still best_val_rmse: 0.5866 (from epoch 0)
#
# 16 steps took 6.75 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.7777 Still best_val_rmse: 0.5866 (from epoch 0)
#
# 16 steps took 6.77 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5762 New best_val_rmse: 0.5762
#
# 16 steps took 6.78 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5438 New best_val_rmse: 0.5438
#
# 16 steps took 6.77 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5663 Still best_val_rmse: 0.5438 (from epoch 0)
#
# 16 steps took 7.31 seconds
# Epoch: 1 batch_num: 12 val_rmse: 0.5958 Still best_val_rmse: 0.5438 (from epoch 0)
#
# 16 steps took 6.79 seconds
# Epoch: 1 batch_num: 28 val_rmse: 0.5535 Still best_val_rmse: 0.5438 (from epoch 0)
#
# 16 steps took 6.82 seconds
# Epoch: 1 batch_num: 44 val_rmse: 0.5474 Still best_val_rmse: 0.5438 (from epoch 0)
#
# 16 steps took 6.8 seconds
# Epoch: 1 batch_num: 60 val_rmse: 0.5461 Still best_val_rmse: 0.5438 (from epoch 0)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 76 val_rmse: 0.5392 New best_val_rmse: 0.5392
#
# 16 steps took 6.81 seconds
# Epoch: 1 batch_num: 92 val_rmse: 0.5189 New best_val_rmse: 0.5189
#
# 16 steps took 6.78 seconds
# Epoch: 1 batch_num: 108 val_rmse: 0.5274 Still best_val_rmse: 0.5189 (from epoch 1)
#
# 16 steps took 6.8 seconds
# Epoch: 1 batch_num: 124 val_rmse: 0.517 New best_val_rmse: 0.517
#
# 16 steps took 6.8 seconds
# Epoch: 1 batch_num: 140 val_rmse: 0.5648 Still best_val_rmse: 0.517 (from epoch 1)
#
# 16 steps took 7.27 seconds
# Epoch: 2 batch_num: 8 val_rmse: 0.4914 New best_val_rmse: 0.4914
#
# 8 steps took 3.4 seconds
# Epoch: 2 batch_num: 16 val_rmse: 0.5242 Still best_val_rmse: 0.4914 (from epoch 2)
#
# 16 steps took 6.79 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.5075 Still best_val_rmse: 0.4914 (from epoch 2)
#
# 16 steps took 6.82 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.522 Still best_val_rmse: 0.4914 (from epoch 2)
#
# 16 steps took 6.83 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.5015 Still best_val_rmse: 0.4914 (from epoch 2)
#
# 16 steps took 6.82 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4894 New best_val_rmse: 0.4894
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4902 Still best_val_rmse: 0.4894 (from epoch 2)
#
# 8 steps took 3.4 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4883 New best_val_rmse: 0.4883
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.495 Still best_val_rmse: 0.4883 (from epoch 2)
#
# 8 steps took 3.39 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4909 Still best_val_rmse: 0.4883 (from epoch 2)
#
# 8 steps took 3.41 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4981 Still best_val_rmse: 0.4883 (from epoch 2)
#
# 8 steps took 3.41 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.493 Still best_val_rmse: 0.4883 (from epoch 2)
#
# 8 steps took 3.41 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4914 Still best_val_rmse: 0.4883 (from epoch 2)
#
# 8 steps took 3.41 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.491 Still best_val_rmse: 0.4883 (from epoch 2)
#
# 8 steps took 3.43 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4886 Still best_val_rmse: 0.4883 (from epoch 2)
#
# 4 steps took 2.16 seconds
# Epoch: 3 batch_num: 0 val_rmse: 0.4904 Still best_val_rmse: 0.4883 (from epoch 2)
#
# 8 steps took 3.42 seconds
# Epoch: 3 batch_num: 8 val_rmse: 0.4867 New best_val_rmse: 0.4867
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 12 val_rmse: 0.4875 Still best_val_rmse: 0.4867 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 16 val_rmse: 0.4856 New best_val_rmse: 0.4856
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 20 val_rmse: 0.4864 Still best_val_rmse: 0.4856 (from epoch 3)
#
# 4 steps took 1.69 seconds
# Epoch: 3 batch_num: 24 val_rmse: 0.4881 Still best_val_rmse: 0.4856 (from epoch 3)
#
# 4 steps took 1.69 seconds
# Epoch: 3 batch_num: 28 val_rmse: 0.4833 New best_val_rmse: 0.4833
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 32 val_rmse: 0.4838 Still best_val_rmse: 0.4833 (from epoch 3)
#
# 4 steps took 1.69 seconds
# Epoch: 3 batch_num: 36 val_rmse: 0.4847 Still best_val_rmse: 0.4833 (from epoch 3)
#
# 4 steps took 1.69 seconds
# Epoch: 3 batch_num: 40 val_rmse: 0.4858 Still best_val_rmse: 0.4833 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 44 val_rmse: 0.4907 Still best_val_rmse: 0.4833 (from epoch 3)
#
# 8 steps took 3.39 seconds
# Epoch: 3 batch_num: 52 val_rmse: 0.4849 Still best_val_rmse: 0.4833 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 56 val_rmse: 0.489 Still best_val_rmse: 0.4833 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 60 val_rmse: 0.4898 Still best_val_rmse: 0.4833 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 64 val_rmse: 0.4864 Still best_val_rmse: 0.4833 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 68 val_rmse: 0.4838 Still best_val_rmse: 0.4833 (from epoch 3)
#
# 4 steps took 1.72 seconds
# Epoch: 3 batch_num: 72 val_rmse: 0.4829 New best_val_rmse: 0.4829
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 76 val_rmse: 0.483 Still best_val_rmse: 0.4829 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 80 val_rmse: 0.4832 Still best_val_rmse: 0.4829 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 84 val_rmse: 0.4839 Still best_val_rmse: 0.4829 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 88 val_rmse: 0.484 Still best_val_rmse: 0.4829 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 92 val_rmse: 0.483 Still best_val_rmse: 0.4829 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 96 val_rmse: 0.4827 New best_val_rmse: 0.4827
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 100 val_rmse: 0.4825 New best_val_rmse: 0.4825
#
# 4 steps took 1.71 seconds
# Epoch: 3 batch_num: 104 val_rmse: 0.4825 Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 1.69 seconds
# Epoch: 3 batch_num: 108 val_rmse: 0.4828 Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 112 val_rmse: 0.4832 Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 116 val_rmse: 0.4833 Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 120 val_rmse: 0.4834 Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 124 val_rmse: 0.4834 Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 1.69 seconds
# Epoch: 3 batch_num: 128 val_rmse: 0.4834 Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 1.71 seconds
# Epoch: 3 batch_num: 132 val_rmse: 0.4834 Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 1.7 seconds
# Epoch: 3 batch_num: 136 val_rmse: 0.4834 Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 1.71 seconds
# Epoch: 3 batch_num: 140 val_rmse: 0.4834 Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 1.71 seconds
# Epoch: 3 batch_num: 144 val_rmse: 0.4834 Still best_val_rmse: 0.4825 (from epoch 3)
#
# Final RMSE: 0.48245617747306824
# ##### Using fold 1
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaModel: ['config', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# 16 steps took 8.05 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.7818 New best_val_rmse: 0.7818
#
# 16 steps took 6.78 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.715 New best_val_rmse: 0.715
#
# 16 steps took 6.8 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.5701 New best_val_rmse: 0.5701
#
# 16 steps took 6.79 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7245 Still best_val_rmse: 0.5701 (from epoch 0)
#
# 16 steps took 6.81 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6227 Still best_val_rmse: 0.5701 (from epoch 0)
#
# 16 steps took 6.81 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.612 Still best_val_rmse: 0.5701 (from epoch 0)
#
# 16 steps took 6.81 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5728 Still best_val_rmse: 0.5701 (from epoch 0)
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5112 New best_val_rmse: 0.5112
#
# 16 steps took 6.82 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5026 New best_val_rmse: 0.5026
#
# 16 steps took 7.27 seconds
# Epoch: 1 batch_num: 12 val_rmse: 0.4683 New best_val_rmse: 0.4683
#
# 1 steps took 0.428 seconds
# Epoch: 1 batch_num: 13 val_rmse: 0.5817 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 16 steps took 6.8 seconds
# Epoch: 1 batch_num: 29 val_rmse: 0.5047 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 16 steps took 6.82 seconds
# Epoch: 1 batch_num: 45 val_rmse: 0.5989 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 16 steps took 6.8 seconds
# Epoch: 1 batch_num: 61 val_rmse: 0.4955 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 8 steps took 3.41 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.5183 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.5385 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 101 val_rmse: 0.6006 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 16 steps took 6.85 seconds
# Epoch: 1 batch_num: 117 val_rmse: 0.491 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 8 steps took 3.42 seconds
# Epoch: 1 batch_num: 125 val_rmse: 0.4862 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 4 steps took 1.72 seconds
# Epoch: 1 batch_num: 129 val_rmse: 0.4824 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 4 steps took 1.71 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.4959 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 8 steps took 3.41 seconds
# Epoch: 1 batch_num: 141 val_rmse: 0.5018 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 16 steps took 7.34 seconds
# Epoch: 2 batch_num: 9 val_rmse: 0.4779 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 2 steps took 0.852 seconds
# Epoch: 2 batch_num: 11 val_rmse: 0.4901 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 8 steps took 3.4 seconds
# Epoch: 2 batch_num: 19 val_rmse: 0.4828 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 4 steps took 1.7 seconds
# Epoch: 2 batch_num: 23 val_rmse: 0.4854 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 4 steps took 1.7 seconds
# Epoch: 2 batch_num: 27 val_rmse: 0.4752 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 2 steps took 0.848 seconds
# Epoch: 2 batch_num: 29 val_rmse: 0.4706 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 2 steps took 0.849 seconds
# Epoch: 2 batch_num: 31 val_rmse: 0.4807 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 4 steps took 1.7 seconds
# Epoch: 2 batch_num: 35 val_rmse: 0.4734 Still best_val_rmse: 0.4683 (from epoch 1)
#
# 2 steps took 0.847 seconds
# Epoch: 2 batch_num: 37 val_rmse: 0.4653 New best_val_rmse: 0.4653
#
# 1 steps took 0.428 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.461 New best_val_rmse: 0.461
#
# 1 steps took 0.428 seconds
# Epoch: 2 batch_num: 39 val_rmse: 0.4799 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.842 seconds
# Epoch: 2 batch_num: 41 val_rmse: 0.4836 Still best_val_rmse: 0.461 (from epoch 2)
#
# 4 steps took 1.69 seconds
# Epoch: 2 batch_num: 45 val_rmse: 0.4773 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.847 seconds
# Epoch: 2 batch_num: 47 val_rmse: 0.4642 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.419 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4713 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.843 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4815 Still best_val_rmse: 0.461 (from epoch 2)
#
# 4 steps took 1.7 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4691 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 55 val_rmse: 0.4698 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.418 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4713 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.847 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4632 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.427 seconds
# Epoch: 2 batch_num: 59 val_rmse: 0.4628 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4641 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 61 val_rmse: 0.4666 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.424 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4651 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 63 val_rmse: 0.4644 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4656 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 65 val_rmse: 0.4668 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.467 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 67 val_rmse: 0.467 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4675 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 69 val_rmse: 0.4671 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4675 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 71 val_rmse: 0.4677 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.425 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4687 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.426 seconds
# Epoch: 2 batch_num: 73 val_rmse: 0.4677 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4681 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 75 val_rmse: 0.4691 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.418 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4671 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 77 val_rmse: 0.4636 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.462 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 79 val_rmse: 0.4616 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.424 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4615 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 81 val_rmse: 0.4618 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4618 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 83 val_rmse: 0.4628 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4643 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 85 val_rmse: 0.465 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.419 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4639 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 87 val_rmse: 0.4645 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4655 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 89 val_rmse: 0.4673 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4669 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.417 seconds
# Epoch: 2 batch_num: 91 val_rmse: 0.4659 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4659 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.424 seconds
# Epoch: 2 batch_num: 93 val_rmse: 0.4672 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4709 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.848 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4683 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 97 val_rmse: 0.4709 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.847 seconds
# Epoch: 2 batch_num: 99 val_rmse: 0.4844 Still best_val_rmse: 0.461 (from epoch 2)
#
# 4 steps took 1.7 seconds
# Epoch: 2 batch_num: 103 val_rmse: 0.4653 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4663 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 105 val_rmse: 0.4682 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4673 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 107 val_rmse: 0.4652 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.425 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4652 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.419 seconds
# Epoch: 2 batch_num: 109 val_rmse: 0.4698 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4742 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.851 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4739 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.847 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4694 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 115 val_rmse: 0.4698 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.418 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.472 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.852 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4723 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.843 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4677 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 121 val_rmse: 0.4684 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.418 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4707 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.845 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4733 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.848 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4683 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 127 val_rmse: 0.4655 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4683 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 129 val_rmse: 0.4707 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.853 seconds
# Epoch: 2 batch_num: 131 val_rmse: 0.4732 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.851 seconds
# Epoch: 2 batch_num: 133 val_rmse: 0.4704 Still best_val_rmse: 0.461 (from epoch 2)
#
# 2 steps took 0.846 seconds
# Epoch: 2 batch_num: 135 val_rmse: 0.4658 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.424 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4645 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.424 seconds
# Epoch: 2 batch_num: 137 val_rmse: 0.4642 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4643 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 139 val_rmse: 0.4638 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4631 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 141 val_rmse: 0.4632 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4646 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.425 seconds
# Epoch: 2 batch_num: 143 val_rmse: 0.465 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.465 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 145 val_rmse: 0.4643 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4626 Still best_val_rmse: 0.461 (from epoch 2)
#
# 1 steps took 0.276 seconds
# Epoch: 2 batch_num: 147 val_rmse: 0.4605 New best_val_rmse: 0.4605
#
# 1 steps took 1.06 seconds
# Epoch: 3 batch_num: 0 val_rmse: 0.4615 Still best_val_rmse: 0.4605 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 1 val_rmse: 0.4651 Still best_val_rmse: 0.4605 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 2 val_rmse: 0.4672 Still best_val_rmse: 0.4605 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 3 val_rmse: 0.4657 Still best_val_rmse: 0.4605 (from epoch 2)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 4 val_rmse: 0.463 Still best_val_rmse: 0.4605 (from epoch 2)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 5 val_rmse: 0.4597 New best_val_rmse: 0.4597
#
# 1 steps took 0.427 seconds
# Epoch: 3 batch_num: 6 val_rmse: 0.4593 New best_val_rmse: 0.4593
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 7 val_rmse: 0.4595 Still best_val_rmse: 0.4593 (from epoch 3)
#
# 1 steps took 0.415 seconds
# Epoch: 3 batch_num: 8 val_rmse: 0.4595 Still best_val_rmse: 0.4593 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 9 val_rmse: 0.4594 Still best_val_rmse: 0.4593 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 10 val_rmse: 0.4589 New best_val_rmse: 0.4589
#
# 1 steps took 0.412 seconds
# Epoch: 3 batch_num: 11 val_rmse: 0.4583 New best_val_rmse: 0.4583
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 12 val_rmse: 0.4581 New best_val_rmse: 0.4581
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 13 val_rmse: 0.4586 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 14 val_rmse: 0.4601 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 15 val_rmse: 0.4603 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 16 val_rmse: 0.4601 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 17 val_rmse: 0.46 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 18 val_rmse: 0.4598 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 19 val_rmse: 0.4599 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 20 val_rmse: 0.4614 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 21 val_rmse: 0.4626 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 22 val_rmse: 0.4636 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 23 val_rmse: 0.4648 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 24 val_rmse: 0.4652 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 25 val_rmse: 0.4642 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 26 val_rmse: 0.4624 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 27 val_rmse: 0.4619 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 28 val_rmse: 0.4618 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 29 val_rmse: 0.4619 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 30 val_rmse: 0.4615 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 31 val_rmse: 0.4611 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 32 val_rmse: 0.4606 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 33 val_rmse: 0.4603 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 34 val_rmse: 0.4593 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 35 val_rmse: 0.4586 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 36 val_rmse: 0.4582 Still best_val_rmse: 0.4581 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 37 val_rmse: 0.4579 New best_val_rmse: 0.4579
#
# 1 steps took 0.426 seconds
# Epoch: 3 batch_num: 38 val_rmse: 0.4579 New best_val_rmse: 0.4579
#
# 1 steps took 0.429 seconds
# Epoch: 3 batch_num: 39 val_rmse: 0.458 Still best_val_rmse: 0.4579 (from epoch 3)
#
# 1 steps took 0.416 seconds
# Epoch: 3 batch_num: 40 val_rmse: 0.4579 Still best_val_rmse: 0.4579 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 41 val_rmse: 0.4578 New best_val_rmse: 0.4578
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 42 val_rmse: 0.4576 New best_val_rmse: 0.4576
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 43 val_rmse: 0.4574 New best_val_rmse: 0.4574
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 44 val_rmse: 0.4573 New best_val_rmse: 0.4573
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 45 val_rmse: 0.4576 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 46 val_rmse: 0.4579 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.414 seconds
# Epoch: 3 batch_num: 47 val_rmse: 0.4586 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.414 seconds
# Epoch: 3 batch_num: 48 val_rmse: 0.4594 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 49 val_rmse: 0.4602 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 50 val_rmse: 0.4598 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 51 val_rmse: 0.4595 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 52 val_rmse: 0.4593 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 53 val_rmse: 0.4594 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 54 val_rmse: 0.4595 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 55 val_rmse: 0.4598 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 56 val_rmse: 0.4598 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 57 val_rmse: 0.4597 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 58 val_rmse: 0.4594 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 59 val_rmse: 0.4608 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 60 val_rmse: 0.4624 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 61 val_rmse: 0.4632 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 62 val_rmse: 0.4632 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 63 val_rmse: 0.4618 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 64 val_rmse: 0.4605 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 65 val_rmse: 0.4591 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 66 val_rmse: 0.4579 Still best_val_rmse: 0.4573 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 67 val_rmse: 0.4569 New best_val_rmse: 0.4569
#
# 1 steps took 0.426 seconds
# Epoch: 3 batch_num: 68 val_rmse: 0.4558 New best_val_rmse: 0.4558
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 69 val_rmse: 0.4552 New best_val_rmse: 0.4552
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 70 val_rmse: 0.4551 New best_val_rmse: 0.4551
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 71 val_rmse: 0.4553 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 72 val_rmse: 0.4557 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 73 val_rmse: 0.4563 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 74 val_rmse: 0.4567 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 75 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 76 val_rmse: 0.4567 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 77 val_rmse: 0.4566 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 78 val_rmse: 0.4565 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 79 val_rmse: 0.4563 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 80 val_rmse: 0.4561 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 81 val_rmse: 0.4559 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 82 val_rmse: 0.4559 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 83 val_rmse: 0.4562 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 84 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 85 val_rmse: 0.458 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 86 val_rmse: 0.4593 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 87 val_rmse: 0.4608 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 88 val_rmse: 0.4623 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 89 val_rmse: 0.4636 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 90 val_rmse: 0.4643 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 91 val_rmse: 0.4643 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 92 val_rmse: 0.4637 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 93 val_rmse: 0.4627 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 94 val_rmse: 0.4618 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 95 val_rmse: 0.461 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.427 seconds
# Epoch: 3 batch_num: 96 val_rmse: 0.4605 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 97 val_rmse: 0.4598 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 98 val_rmse: 0.4591 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 99 val_rmse: 0.4586 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 100 val_rmse: 0.4581 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 101 val_rmse: 0.4577 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 102 val_rmse: 0.4575 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 103 val_rmse: 0.4573 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 104 val_rmse: 0.4572 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 105 val_rmse: 0.4572 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 106 val_rmse: 0.4571 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 107 val_rmse: 0.457 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 108 val_rmse: 0.457 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 109 val_rmse: 0.457 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 110 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 111 val_rmse: 0.457 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 112 val_rmse: 0.457 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 113 val_rmse: 0.457 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 114 val_rmse: 0.457 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 115 val_rmse: 0.457 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 116 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 117 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 118 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 119 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.416 seconds
# Epoch: 3 batch_num: 120 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 121 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 122 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 123 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 124 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 125 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 126 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 127 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 128 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 129 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 130 val_rmse: 0.4569 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 131 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 132 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 133 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 134 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 135 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 136 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 137 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 138 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 139 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 140 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 141 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 142 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 143 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 144 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 145 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 146 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# 1 steps took 0.273 seconds
# Epoch: 3 batch_num: 147 val_rmse: 0.4568 Still best_val_rmse: 0.4551 (from epoch 3)
#
# Final RMSE: 0.45506757497787476
# ##### Using fold 2
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaModel: ['config', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# 16 steps took 8.51 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.6871 New best_val_rmse: 0.6871
#
# 16 steps took 6.79 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.6642 New best_val_rmse: 0.6642
#
# 16 steps took 6.81 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.601 New best_val_rmse: 0.601
#
# 16 steps took 6.81 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6706 Still best_val_rmse: 0.601 (from epoch 0)
#
# 16 steps took 6.82 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6193 Still best_val_rmse: 0.601 (from epoch 0)
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5929 New best_val_rmse: 0.5929
#
# 16 steps took 6.85 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.515 New best_val_rmse: 0.515
#
# 16 steps took 6.8 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5723 Still best_val_rmse: 0.515 (from epoch 0)
#
# 16 steps took 6.83 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5169 Still best_val_rmse: 0.515 (from epoch 0)
#
# 16 steps took 7.39 seconds
# Epoch: 1 batch_num: 12 val_rmse: 0.4952 New best_val_rmse: 0.4952
#
# 8 steps took 3.41 seconds
# Epoch: 1 batch_num: 20 val_rmse: 0.5032 Still best_val_rmse: 0.4952 (from epoch 1)
#
# 16 steps took 6.8 seconds
# Epoch: 1 batch_num: 36 val_rmse: 0.5153 Still best_val_rmse: 0.4952 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 52 val_rmse: 0.5107 Still best_val_rmse: 0.4952 (from epoch 1)
#
# 16 steps took 6.82 seconds
# Epoch: 1 batch_num: 68 val_rmse: 0.5158 Still best_val_rmse: 0.4952 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 84 val_rmse: 0.5444 Still best_val_rmse: 0.4952 (from epoch 1)
#
# 16 steps took 6.85 seconds
# Epoch: 1 batch_num: 100 val_rmse: 0.5229 Still best_val_rmse: 0.4952 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 116 val_rmse: 0.4961 Still best_val_rmse: 0.4952 (from epoch 1)
#
# 8 steps took 3.42 seconds
# Epoch: 1 batch_num: 124 val_rmse: 0.5048 Still best_val_rmse: 0.4952 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 140 val_rmse: 0.5128 Still best_val_rmse: 0.4952 (from epoch 1)
#
# 16 steps took 7.41 seconds
# Epoch: 2 batch_num: 8 val_rmse: 0.5052 Still best_val_rmse: 0.4952 (from epoch 1)
#
# 16 steps took 6.86 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4944 New best_val_rmse: 0.4944
#
# 8 steps took 3.41 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4766 New best_val_rmse: 0.4766
#
# 2 steps took 0.854 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.483 Still best_val_rmse: 0.4766 (from epoch 2)
#
# 4 steps took 1.7 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.5154 Still best_val_rmse: 0.4766 (from epoch 2)
#
# 16 steps took 6.81 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4766 New best_val_rmse: 0.4766
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4713 New best_val_rmse: 0.4713
#
# 2 steps took 0.853 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4718 Still best_val_rmse: 0.4713 (from epoch 2)
#
# 2 steps took 0.841 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4713 Still best_val_rmse: 0.4713 (from epoch 2)
#
# 2 steps took 0.844 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4706 New best_val_rmse: 0.4706
#
# 2 steps took 0.851 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4716 Still best_val_rmse: 0.4706 (from epoch 2)
#
# 2 steps took 0.847 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4737 Still best_val_rmse: 0.4706 (from epoch 2)
#
# 2 steps took 0.844 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4868 Still best_val_rmse: 0.4706 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4754 Still best_val_rmse: 0.4706 (from epoch 2)
#
# 2 steps took 0.847 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4782 Still best_val_rmse: 0.4706 (from epoch 2)
#
# 2 steps took 0.842 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4677 New best_val_rmse: 0.4677
#
# 1 steps took 0.425 seconds
# Epoch: 2 batch_num: 77 val_rmse: 0.4734 Still best_val_rmse: 0.4677 (from epoch 2)
#
# 2 steps took 0.844 seconds
# Epoch: 2 batch_num: 79 val_rmse: 0.4886 Still best_val_rmse: 0.4677 (from epoch 2)
#
# 4 steps took 1.7 seconds
# Epoch: 2 batch_num: 83 val_rmse: 0.4894 Still best_val_rmse: 0.4677 (from epoch 2)
#
# 4 steps took 1.7 seconds
# Epoch: 2 batch_num: 87 val_rmse: 0.4833 Still best_val_rmse: 0.4677 (from epoch 2)
#
# 4 steps took 1.7 seconds
# Epoch: 2 batch_num: 91 val_rmse: 0.4878 Still best_val_rmse: 0.4677 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 95 val_rmse: 0.4665 New best_val_rmse: 0.4665
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4705 Still best_val_rmse: 0.4665 (from epoch 2)
#
# 2 steps took 0.849 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4692 Still best_val_rmse: 0.4665 (from epoch 2)
#
# 1 steps took 0.418 seconds
# Epoch: 2 batch_num: 99 val_rmse: 0.4674 Still best_val_rmse: 0.4665 (from epoch 2)
#
# 1 steps took 0.418 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4646 New best_val_rmse: 0.4646
#
# 1 steps took 0.415 seconds
# Epoch: 2 batch_num: 101 val_rmse: 0.4654 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4704 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 2 steps took 0.85 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4646 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 105 val_rmse: 0.4634 New best_val_rmse: 0.4634
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4646 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.417 seconds
# Epoch: 2 batch_num: 107 val_rmse: 0.4671 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4674 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.419 seconds
# Epoch: 2 batch_num: 109 val_rmse: 0.4655 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.465 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 111 val_rmse: 0.4658 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.467 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.419 seconds
# Epoch: 2 batch_num: 113 val_rmse: 0.4669 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4669 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 115 val_rmse: 0.4675 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.427 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4685 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 2 batch_num: 117 val_rmse: 0.4694 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.419 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4704 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 2 steps took 0.849 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.469 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 121 val_rmse: 0.4692 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4697 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 123 val_rmse: 0.4701 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 2 steps took 0.847 seconds
# Epoch: 2 batch_num: 125 val_rmse: 0.4702 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 2 steps took 0.851 seconds
# Epoch: 2 batch_num: 127 val_rmse: 0.4701 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 2 steps took 0.849 seconds
# Epoch: 2 batch_num: 129 val_rmse: 0.4702 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 131 val_rmse: 0.4711 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 2 steps took 0.848 seconds
# Epoch: 2 batch_num: 133 val_rmse: 0.4713 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 2 steps took 0.846 seconds
# Epoch: 2 batch_num: 135 val_rmse: 0.4696 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4701 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 2 steps took 0.849 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4726 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 2 steps took 0.853 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4728 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 2 steps took 0.851 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4688 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 143 val_rmse: 0.4685 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.425 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4663 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 145 val_rmse: 0.4652 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4649 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.274 seconds
# Epoch: 2 batch_num: 147 val_rmse: 0.4646 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 1.13 seconds
# Epoch: 3 batch_num: 0 val_rmse: 0.4645 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 1 val_rmse: 0.4641 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 2 val_rmse: 0.4636 Still best_val_rmse: 0.4634 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 3 val_rmse: 0.4634 New best_val_rmse: 0.4634
#
# 1 steps took 0.422 seconds
# ...
# Epoch: 2 batch_num: 143 val_rmse: 0.4676 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4669 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 0.422 seconds
# Epoch: 2 batch_num: 145 val_rmse: 0.466 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 0.424 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4651 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 0.274 seconds
# Epoch: 2 batch_num: 147 val_rmse: 0.4648 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 1.07 seconds
# Epoch: 3 batch_num: 0 val_rmse: 0.4653 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 1 val_rmse: 0.4662 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 2 val_rmse: 0.4663 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 3 val_rmse: 0.4658 Still best_val_rmse: 0.4646 (from epoch 2)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 4 val_rmse: 0.4643 New best_val_rmse: 0.4643
#
# 1 steps took 0.427 seconds
# Epoch: 3 batch_num: 5 val_rmse: 0.4638 New best_val_rmse: 0.4638
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 6 val_rmse: 0.4636 New best_val_rmse: 0.4636
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 7 val_rmse: 0.4636 New best_val_rmse: 0.4636
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 8 val_rmse: 0.4636 Still best_val_rmse: 0.4636 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 9 val_rmse: 0.4639 Still best_val_rmse: 0.4636 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 10 val_rmse: 0.4655 Still best_val_rmse: 0.4636 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 11 val_rmse: 0.4681 Still best_val_rmse: 0.4636 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 12 val_rmse: 0.4713 Still best_val_rmse: 0.4636 (from epoch 3)
#
# 2 steps took 0.843 seconds
# Epoch: 3 batch_num: 14 val_rmse: 0.4745 Still best_val_rmse: 0.4636 (from epoch 3)
#
# 2 steps took 0.843 seconds
# Epoch: 3 batch_num: 16 val_rmse: 0.4663 Still best_val_rmse: 0.4636 (from epoch 3)
#
# 1 steps took 0.416 seconds
# Epoch: 3 batch_num: 17 val_rmse: 0.4632 New best_val_rmse: 0.4632
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 18 val_rmse: 0.4624 New best_val_rmse: 0.4624
#
# 1 steps took 0.427 seconds
# Epoch: 3 batch_num: 19 val_rmse: 0.463 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 20 val_rmse: 0.4642 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 21 val_rmse: 0.464 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 22 val_rmse: 0.4635 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 23 val_rmse: 0.4628 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 24 val_rmse: 0.463 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 25 val_rmse: 0.465 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 26 val_rmse: 0.4679 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 27 val_rmse: 0.4717 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 2 steps took 0.849 seconds
# Epoch: 3 batch_num: 29 val_rmse: 0.4766 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 2 steps took 0.844 seconds
# Epoch: 3 batch_num: 31 val_rmse: 0.4741 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 2 steps took 0.848 seconds
# Epoch: 3 batch_num: 33 val_rmse: 0.4702 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 2 steps took 0.85 seconds
# Epoch: 3 batch_num: 35 val_rmse: 0.465 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 36 val_rmse: 0.4635 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 37 val_rmse: 0.4629 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 38 val_rmse: 0.4628 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 39 val_rmse: 0.4629 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 40 val_rmse: 0.4633 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 41 val_rmse: 0.4635 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 42 val_rmse: 0.4634 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 43 val_rmse: 0.463 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 44 val_rmse: 0.4629 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 45 val_rmse: 0.4634 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 46 val_rmse: 0.4643 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 47 val_rmse: 0.4657 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 48 val_rmse: 0.4668 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 49 val_rmse: 0.4688 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 50 val_rmse: 0.4703 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 2 steps took 0.849 seconds
# Epoch: 3 batch_num: 52 val_rmse: 0.4715 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 2 steps took 0.849 seconds
# Epoch: 3 batch_num: 54 val_rmse: 0.4716 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 2 steps took 0.848 seconds
# Epoch: 3 batch_num: 56 val_rmse: 0.47 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 57 val_rmse: 0.4682 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 58 val_rmse: 0.4667 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 59 val_rmse: 0.4656 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 60 val_rmse: 0.4649 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 61 val_rmse: 0.4643 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 62 val_rmse: 0.464 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 63 val_rmse: 0.464 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 64 val_rmse: 0.4641 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 65 val_rmse: 0.4642 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 66 val_rmse: 0.4645 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 67 val_rmse: 0.4646 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 68 val_rmse: 0.4645 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 69 val_rmse: 0.4643 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 70 val_rmse: 0.4639 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 71 val_rmse: 0.4635 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 72 val_rmse: 0.4632 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 73 val_rmse: 0.463 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 74 val_rmse: 0.4629 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 75 val_rmse: 0.4628 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 76 val_rmse: 0.4628 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 77 val_rmse: 0.4628 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 78 val_rmse: 0.4628 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 79 val_rmse: 0.4627 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 80 val_rmse: 0.4627 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 81 val_rmse: 0.4627 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 82 val_rmse: 0.4627 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 83 val_rmse: 0.4628 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 84 val_rmse: 0.4629 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 85 val_rmse: 0.4629 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 86 val_rmse: 0.4631 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 87 val_rmse: 0.4632 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 88 val_rmse: 0.4632 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 89 val_rmse: 0.4634 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 90 val_rmse: 0.4635 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 91 val_rmse: 0.4638 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 92 val_rmse: 0.4639 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 93 val_rmse: 0.4641 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 94 val_rmse: 0.4644 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 95 val_rmse: 0.4646 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 96 val_rmse: 0.4646 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 97 val_rmse: 0.4649 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 98 val_rmse: 0.4651 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 99 val_rmse: 0.4652 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 100 val_rmse: 0.465 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 101 val_rmse: 0.4649 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 102 val_rmse: 0.4647 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 103 val_rmse: 0.4647 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 104 val_rmse: 0.4647 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 105 val_rmse: 0.4647 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 106 val_rmse: 0.4648 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 107 val_rmse: 0.4649 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 108 val_rmse: 0.465 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 109 val_rmse: 0.4651 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 110 val_rmse: 0.4651 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 111 val_rmse: 0.465 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 112 val_rmse: 0.4649 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 113 val_rmse: 0.4648 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.425 seconds
# Epoch: 3 batch_num: 114 val_rmse: 0.4647 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 115 val_rmse: 0.4647 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 116 val_rmse: 0.4647 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 117 val_rmse: 0.4647 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 118 val_rmse: 0.4646 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 119 val_rmse: 0.4645 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 120 val_rmse: 0.4644 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.418 seconds
# Epoch: 3 batch_num: 121 val_rmse: 0.4642 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.426 seconds
# Epoch: 3 batch_num: 122 val_rmse: 0.4641 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 123 val_rmse: 0.464 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 124 val_rmse: 0.464 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 125 val_rmse: 0.4639 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 126 val_rmse: 0.4639 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.42 seconds
# Epoch: 3 batch_num: 127 val_rmse: 0.4639 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 128 val_rmse: 0.4638 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 129 val_rmse: 0.4638 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 130 val_rmse: 0.4638 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 131 val_rmse: 0.4638 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 132 val_rmse: 0.4638 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 133 val_rmse: 0.4638 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 134 val_rmse: 0.4637 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 135 val_rmse: 0.4637 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 136 val_rmse: 0.4637 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.424 seconds
# Epoch: 3 batch_num: 137 val_rmse: 0.4637 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.422 seconds
# Epoch: 3 batch_num: 138 val_rmse: 0.4636 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.417 seconds
# Epoch: 3 batch_num: 139 val_rmse: 0.4636 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 140 val_rmse: 0.4636 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 141 val_rmse: 0.4636 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 142 val_rmse: 0.4636 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.421 seconds
# Epoch: 3 batch_num: 143 val_rmse: 0.4636 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 144 val_rmse: 0.4636 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.423 seconds
# Epoch: 3 batch_num: 145 val_rmse: 0.4636 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.419 seconds
# Epoch: 3 batch_num: 146 val_rmse: 0.4636 Still best_val_rmse: 0.4624 (from epoch 3)
#
# 1 steps took 0.276 seconds
# Epoch: 3 batch_num: 147 val_rmse: 0.4636 Still best_val_rmse: 0.4624 (from epoch 3)
#
# Final RMSE: 0.4623505175113678
# CPU times: user 1h 35min 28s, sys: 21min 23s, total: 1h 56min 52s
# Wall time: 2h 11min 21s

# %%
f'mean RMSE values: {np.mean(np.array(rmse_values))}'
# Out:
# 'mean RMSE values: 0.4690800607204437'

# %% [markdown]
# ### Verify the model

# %%
from sklearn.svm import SVR
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
from tqdm.notebook import tqdm

# %%
cfg.model_offset = 0
cfg.model_limit = 6
cfg.n_folds = 5
cfg.svm_kernels = ['rbf']
cfg.svm_c = 5

# %%
num_bins = int(np.ceil(np.log2(len(train_df))))
train_df['bins'] = pd.cut(train_df['target'], bins=num_bins, labels=False)
bins = train_df['bins'].values

# %%
# %%time

inference_models = []
for i in range(1, cfg.NUM_FOLDS + 1):
    print(f'Model {i}')
    inference_model = CommonLitModel()
    inference_model = inference_model.cuda()
    inference_model.load_state_dict(torch.load(str(MODELS_PATH/f"{cfg.model_name.replace('/', '_')}_{i}/model_{i}.pth")))
    inference_model.eval();
    inference_models.append(inference_model)
# Out:
# Model 1
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaModel: ['config', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model 2
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaModel: ['config', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model 3
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaModel: ['config', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model 4
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaModel: ['config', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model 5
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaModel: ['config', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model 6
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaModel: ['config', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# CPU times: user 25.5 s, sys: 6.82 s, total: 32.3 s
# Wall time: 36.1 s

# %%
from transformers import RobertaTokenizer

tokenizers = []
for i in range(1, cfg.NUM_FOLDS):
    tokenizer = RobertaTokenizer.from_pretrained(MODELS_PATH/f"{cfg.model_name.replace('/', '_')}_{i}")
    tokenizers.append(tokenizer)

# %%
def get_cls_embeddings(dl, transformer_model):
    cls_embeddings = []
    with torch.no_grad():
        for input_features in tqdm(dl, total=len(dl)):
            output, context_vector = transformer_model(input_features['input_ids'].cuda(), input_features['attention_mask'].cuda())
#             cls_embeddings.extend(output['last_hidden_state'][:,0,:].detach().cpu().numpy())
            embedding_out = context_vector.detach().cpu().numpy()
            cls_embeddings.extend(embedding_out)
    return np.array(cls_embeddings)

# %%
def rmse_score(X, y):
    return np.sqrt(mean_squared_error(X, y))

# %%
def convert_to_list(t):
    return t.flatten().long()

class CommonLitDataset(nn.Module):
    def __init__(self, text, test_id, tokenizer, max_len=128):
        self.excerpt = text
        self.test_id = test_id
        self.max_len = max_len
        self.tokenizer = tokenizer
    
    def __getitem__(self,idx):
        encode = self.tokenizer(self.excerpt[idx],
                                return_tensors='pt',
                                max_length=self.max_len,
                                padding='max_length',
                                truncation=True)
        return {'input_ids': convert_to_list(encode['input_ids']),
                'attention_mask': convert_to_list(encode['attention_mask']),
                'id': self.test_id[idx]}
    
    def __len__(self):
        return len(self.excerpt)

# %%
def create_dl(df, tokenizer):
    text = df['excerpt'].values
    ids = df['id'].values
    ds = CommonLitDataset(text, ids, tokenizer, max_len=cfg.MAX_LEN)
    return DataLoader(ds, 
                      batch_size = cfg.BATCH_SIZE,
                      shuffle=False,
                      num_workers = 1,
                      pin_memory=True,
                      drop_last=False
                     )

# %%
train_df = pd.read_csv(DATA_PATH/'train-orig.csv')
test_df = pd.read_csv(DATA_PATH/'test.csv')
remove_unnecessary(train_df)

# %%
train_target_mean = train_df['target'].mean()
train_target_std = train_df['target'].std()
train_df['normalized_target'] = (train_df['target'] - train_target_mean) / train_target_std

# %%
# %%time

train_target = train_df['normalized_target'].values

def calc_mean(scores):
    return np.mean(np.array(scores), axis=0)

final_scores = []
final_rmse = []
kernel_rmse_score_mean = []
final_kernel_predictions_means = []
for j, (inference_model, tokenizer) in enumerate(zip(inference_models, tokenizers)):
    print('Model', j)
    test_dl = create_dl(test_df, tokenizer)
    train_dl = create_dl(train_df, tokenizer)
    transformer_model = inference_model
    transformer_model.cuda()
    X = get_cls_embeddings(train_dl, transformer_model)
    
    y = train_target
    X_test = get_cls_embeddings(test_dl, transformer_model)
    
    kfold = StratifiedKFold(n_splits=cfg.NUM_FOLDS)
    scores = []
    rmse_scores = []
    kernel_predictions_means = []
    for kernel in cfg.svm_kernels:
        print('Kernel', kernel)
        kernel_scores = []
        kernel_rmse_scores = []
        kernel_predictions = []
        for k, (train_idx, valid_idx) in enumerate(kfold.split(X, bins)):

            print('Fold', k, train_idx.shape, valid_idx.shape)
            model = SVR(C=cfg.svm_c, kernel=kernel, gamma='auto')

            X_train, y_train = X[train_idx], y[train_idx]
            X_valid, y_valid = X[valid_idx], y[valid_idx]
            model.fit(X_train, y_train)
            prediction = model.predict(X_valid)
            kernel_predictions.append(prediction)
            kernel_rmse_scores.append(rmse_score(prediction, y_valid))
            print('rmse_score', kernel_rmse_scores[k])
            kernel_scores.append(model.predict(X_test))
        kernel_predictions_means.append(np.array([np.mean(kp) for kp in kernel_predictions]).mean())
        scores.append(calc_mean(kernel_scores))
        kernel_rmse_score = calc_mean(kernel_rmse_scores)
        kernel_rmse_score_mean.append(kernel_rmse_score)
        rmse_scores.append(kernel_rmse_score)
    final_kernel_predictions_means.append(kernel_predictions_means)
    final_scores.append(calc_mean(scores))
    final_rmse.append(calc_mean(rmse_scores))
print('FINAL RMSE score', np.mean(np.array(final_rmse)))
# Out:
# Model 0
# HBox(children=(FloatProgress(value=0.0, max=178.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Kernel rbf
# Fold 0 (2360,) (473,)
# rmse_score 0.27921876522261996
# Fold 1 (2361,) (472,)
# rmse_score 0.26759372771068
# Fold 2 (2361,) (472,)
# rmse_score 0.26838923804458503
# Fold 3 (2361,) (472,)
# rmse_score 0.2398236595065085
# Fold 4 (2361,) (472,)
# rmse_score 0.28060849518805003
# Fold 5 (2361,) (472,)
# rmse_score 0.2980943508715811
# Model 1
# HBox(children=(FloatProgress(value=0.0, max=178.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Kernel rbf
# Fold 0 (2360,) (473,)
# rmse_score 0.2527378207669351
# Fold 1 (2361,) (472,)
# rmse_score 0.29772772745214215
# Fold 2 (2361,) (472,)
# rmse_score 0.25498869603160007
# Fold 3 (2361,) (472,)
# rmse_score 0.2618868658234885
# Fold 4 (2361,) (472,)
# rmse_score 0.272889328514013
# Fold 5 (2361,) (472,)
# rmse_score 0.2848910181069653
# Model 2
# HBox(children=(FloatProgress(value=0.0, max=178.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Kernel rbf
# Fold 0 (2360,) (473,)
# rmse_score 0.28464019379177613
# Fold 1 (2361,) (472,)
# rmse_score 0.2903573747291792
# Fold 2 (2361,) (472,)
# rmse_score 0.26194430272976077
# Fold 3 (2361,) (472,)
# rmse_score 0.2713776109341518
# Fold 4 (2361,) (472,)
# rmse_score 0.295220419745551
# Fold 5 (2361,) (472,)
# rmse_score 0.29991462512330863
# Model 3
# HBox(children=(FloatProgress(value=0.0, max=178.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Kernel rbf
# Fold 0 (2360,) (473,)
# rmse_score 0.27012430054216563
# Fold 1 (2361,) (472,)
# rmse_score 0.286773294145828
# Fold 2 (2361,) (472,)
# rmse_score 0.27668130176787264
# Fold 3 (2361,) (472,)
# rmse_score 0.2697277642950733
# Fold 4 (2361,) (472,)
# rmse_score 0.2854695552719421
# Fold 5 (2361,) (472,)
# rmse_score 0.2702248648788704
# Model 4
# HBox(children=(FloatProgress(value=0.0, max=178.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Kernel rbf
# Fold 0 (2360,) (473,)
# rmse_score 0.29065119260020383
# Fold 1 (2361,) (472,)
# rmse_score 0.26966675006387564
# Fold 2 (2361,) (472,)
# rmse_score 0.24498928716821528
# Fold 3 (2361,) (472,)
# rmse_score 0.2744693764620091
# Fold 4 (2361,) (472,)
# rmse_score 0.3137778004880542
# Fold 5 (2361,) (472,)
# rmse_score 0.3025074327296033
# FINAL RMSE score 0.277245571356887
# CPU times: user 3min 21s, sys: 9.04 s, total: 3min 30s
# Wall time: 3min 28s

# %%
final_kernel_predictions_means
# Out:
# [[0.006651664768055396],
#  [-2.426751680239166e-05],
#  [0.0046250219716952885],
#  [-0.005404893296113431],
#  [0.0003357669996718591]]

# %%
# (train_df['target'] - cfg.train_target_mean) / cfg.train_target_std
final_scores_normalized = np.array(final_scores) * train_target_std + train_target_mean

# %%
kernel_rmse_score_mean_array = np.array(kernel_rmse_score_mean)
kernel_rmse_score_mean_sum = np.sum(kernel_rmse_score_mean_array)
prop_losses = kernel_rmse_score_mean_array / kernel_rmse_score_mean_sum
prop_losses_sum = (1 - prop_losses).sum()
weights = (1 - prop_losses) / prop_losses_sum
weights
# Out:
# array([0.20089407, 0.20115277, 0.19879826, 0.20013443, 0.19902047])

# %%
def calc_mean(scores, weights=weights):
    return np.average(np.array(scores), weights=weights, axis=0)

# %%
target_mean = train_df['target'].mean()
final_scores_flat = calc_mean(final_scores_normalized).flatten()
final_scores_mean = final_scores_flat.mean()
target_mean, np.array(final_scores_normalized).mean()
# (-0.9579984513405823, -0.8029817438292849)
# Out:
# (-0.9596573929279916, -0.8666817185248221)

# %%
final_scores_flat
# Out:
# array([-0.23132951, -0.46568355, -0.5403577 , -2.1645003 , -1.88049672,
#        -1.23033584,  0.44635419])

# %%
mean_diff = target_mean - final_scores_mean
mean_diff, mean_diff / len(final_scores)
# Out:
# (-0.09303604551979772, -0.018607209103959542)

# %%
sample_df['target'] = final_scores_flat + mean_diff
# sample_df['target'] = len(final_scores) / np.sum(1 / np.array(final_scores), axis=0) # harmonic mean
sample_df
# Out:
#           id    target
# 0  c0f722661 -0.324366
# 1  f0953f0a5 -0.558720
# 2  0df072751 -0.633394
# 3  04caf4e0c -2.257536
# 4  0e63f8bea -1.973533
# 5  12537fe78 -1.323372
# 6  965e592c0  0.353318

# %% [markdown]
# ### Prepare Packaging

# %%
cfg.model_name
# Out:
# 'deberta-large-uniform'

# %%
BEST_MODEL_FOLDER = MODELS_PATH/cfg.model_name/'best'
# !rm -rf {BEST_MODEL_FOLDER}
# !mkdir -p {BEST_MODEL_FOLDER}

# %%
BEST_MODEL_FOLDER
# Out:
# PosixPath('/home/commonlit/models/deberta-large-uniform/best')

# %%
cfg.NUM_FOLDS
# Out:
# 6

# %%
bestmodels = [MODELS_PATH/f'{cfg.model_name}_{i + 1}' for i in range(0, cfg.NUM_FOLDS)]

# %%
bestmodels
# Out:
# [PosixPath('/home/commonlit/models/deberta-large-uniform_1'),
#  PosixPath('/home/commonlit/models/deberta-large-uniform_2'),
#  PosixPath('/home/commonlit/models/deberta-large-uniform_3'),
#  PosixPath('/home/commonlit/models/deberta-large-uniform_4'),
#  PosixPath('/home/commonlit/models/deberta-large-uniform_5'),
#  PosixPath('/home/commonlit/models/deberta-large-uniform_6')]

# %%
from shutil import copyfile

def normalize_name(path_name):
    return path_name.replace('', '')

for i, best_model in enumerate(bestmodels):
    print(f'Processing {i}th model')
    i = i + 1
    best_model_file = f'{best_model}/model_{i}.pth'
    if Path(best_model_file).exists():
        copyfile(best_model_file, f'{BEST_MODEL_FOLDER}/{i}_pytorch_model.bin')
        tokenizer_path = Path(BEST_MODEL_FOLDER/f'tokenizer-{i}')
        tokenizer_path.mkdir(parents=True, exist_ok=True)
        assert tokenizer_path.exists()

        tokenizer_json = Path(normalize_name(f'{MODELS_PATH/cfg.model_name}_{i}/tokenizer_config.json'))
        assert tokenizer_json.exists(), f'{tokenizer_json} does not exist'
        copyfile(tokenizer_json, tokenizer_path/'tokenizer.json')

        vocab_txt = Path(normalize_name(f'{MODELS_PATH/cfg.model_name}_{i}/vocab.json'))
        assert vocab_txt.exists(), f'{vocab_txt} does not exist'
        copyfile(vocab_txt, tokenizer_path/'vocab.json')

        merges = Path(normalize_name(f'{MODELS_PATH/cfg.model_name}_{i}/merges.txt'))
        assert merges.exists()
        copyfile(merges, tokenizer_path/'merges.txt')
    else:
        print(f'{best_model_file} is missing')
# Out:
# Processing 0th model
# Processing 1th model
# Processing 2th model
# Processing 3th model
# Processing 4th model
# Processing 5th model

# %%
import shutil

shutil.make_archive(MODELS_PATH/cfg.model_name/'best_models', 'zip', BEST_MODEL_FOLDER)
# Out:
# '/home/commonlit/models/deberta-large-uniform/best_models.zip'

# %%
# !ls {MODELS_PATH/cfg.model_name}
# Out:
# best  best_models.zip

# %%
# !mv {MODELS_PATH}/{cfg.model_name}.yaml {MODELS_PATH/cfg.model_name}
# Out:
# mv: cannot stat '/home/commonlit/models/deberta-large-uniform.yaml': No such file or directory

# %%
transformer_model.transformer_model.save_pretrained(save_directory=f'{MODELS_PATH/cfg.model_name}/lm')

# %%
# !du -h {MODELS_PATH/cfg.model_name}/*
# Out:
# 1.3M	/home/commonlit/models/deberta-large-uniform/best/tokenizer-1
# 1.3M	/home/commonlit/models/deberta-large-uniform/best/tokenizer-2
# 1.3M	/home/commonlit/models/deberta-large-uniform/best/tokenizer-3
# 1.3M	/home/commonlit/models/deberta-large-uniform/best/tokenizer-4
# 1.3M	/home/commonlit/models/deberta-large-uniform/best/tokenizer-5
# 1.3M	/home/commonlit/models/deberta-large-uniform/best/tokenizer-6
# 9.1G	/home/commonlit/models/deberta-large-uniform/best
# 8.5G	/home/commonlit/models/deberta-large-uniform/best_models.zip
# 1.6G	/home/commonlit/models/deberta-large-uniform/lm

# %%
shutil.make_archive(MODELS_PATH/cfg.model_name/'lm', 'zip', f'{MODELS_PATH/cfg.model_name}/lm')
# Out:
# '/home/commonlit/models/deberta-large-uniform/lm.zip'

# %%
# !kaggle datasets init -p {MODELS_PATH/cfg.model_name}
# Out:
# Data package template written to: /home/commonlit/models/deberta-large-uniform/dataset-metadata.json

# %%
dataset_json_path = Path(MODELS_PATH/cfg.model_name/'dataset-metadata.json')
assert dataset_json_path.exists()

# %%
# !cat {str(dataset_json_path)}
# Out:
# {
#   "title": "INSERT_TITLE_HERE",
#   "id": "gilfernandes/INSERT_SLUG_HERE",
#   "licenses": [
#     {
#       "name": "CC0-1.0"
#     }
#   ]
# }

# %%
with open(dataset_json_path, 'r') as f:
    dataset_json = f.read()
    dataset_json = dataset_json.replace('INSERT_TITLE_HERE', f'commonlit-{cfg.model_name}').replace('INSERT_SLUG_HERE', f'commonlit-{cfg.model_name}')
    print(dataset_json)
with(open(dataset_json_path, 'w')) as f:
    f.write(dataset_json)
# Out:
# {
#   "title": "commonlit-deberta-large-uniform",
#   "id": "gilfernandes/commonlit-deberta-large-uniform",
#   "licenses": [
#     {
#       "name": "CC0-1.0"
#     }
#   ]
# }

# %%
# !rm -rf {MODELS_PATH/cfg.model_name}/best
# !rm -rf {MODELS_PATH/cfg.model_name}/lm

# %%
# !kaggle datasets create -p {MODELS_PATH/cfg.model_name}
# Out:
# Starting upload for file best_models.zip
# 100%|██████████████████████████████████████| 8.43G/8.43G [14:43<00:00, 10.2MB/s]
# Upload successful: best_models.zip (8GB)
# Starting upload for file lm.zip
# 100%|██████████████████████████████████████| 1.40G/1.40G [02:28<00:00, 10.2MB/s]
# Upload successful: lm.zip (1GB)
# Your private Dataset is being created. Please check progress at /api/v1/datasets/status//gilfernandes/commonlit-deberta-large-uniform

# %%
# !kaggle datasets version -p {MODELS_PATH/cfg.model_name} -m "Version with merges.txt" -d

# %%
state_dict = torch.load(str(MODELS_PATH/f'distilroberta-0/checkpoint-105/pytorch_model.bin'))

# %%
loaded_model = CommonLitModel()

# %%
loaded_model.load_state_dict(state_dict)
